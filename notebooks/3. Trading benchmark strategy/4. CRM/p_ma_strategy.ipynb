# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Kreiraj Kupnju, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Kreiraj Prodaju, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "Izvršena KUPNJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "Izvršena PRODAJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Narudžba je otkazana/margina/odbijena")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0.0002)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Početno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Završno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'CRM', '2024-01-01', '2024-07-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Početno stanje portfelja: 100000.00
# 2024-01-16, Kreiraj Kupnju, 269.19
# 2024-01-17, Izvršena KUPNJA (Cijena: 268.29, Vrijednost: 99535.59, Provizija 19.91)
# 2024-02-13, Kreiraj Prodaju, 281.15
# 2024-02-14, Izvršena PRODAJA (Cijena: 285.00, Vrijednost: 99535.59, Provizija 21.15)
# 2024-02-14, Kreiraj Kupnju, 289.15
# 2024-02-15, Narudžba je otkazana/margina/odbijena
# 2024-02-15, Kreiraj Kupnju, 291.94
# 2024-02-16, Izvršena KUPNJA (Cijena: 292.00, Vrijednost: 105996.00, Provizija 21.20)
# 2024-02-20, Kreiraj Prodaju, 286.39
# 2024-02-21, Izvršena PRODAJA (Cijena: 280.07, Vrijednost: 105996.00, Provizija 20.33)
# 2024-02-22, Kreiraj Kupnju, 293.65
# 2024-02-23, Narudžba je otkazana/margina/odbijena
# 2024-02-23, Kreiraj Kupnju, 292.80
# 2024-02-26, Narudžba je otkazana/margina/odbijena
# 2024-02-26, Kreiraj Kupnju, 300.39
# 2024-02-27, Narudžba je otkazana/margina/odbijena
# 2024-02-27, Kreiraj Kupnju, 299.50
# 2024-02-28, Izvršena KUPNJA (Cijena: 299.58, Vrijednost: 101557.62, Provizija 20.31)
# 2024-03-05, Kreiraj Prodaju, 298.75
# 2024-03-06, Izvršena PRODAJA (Cijena: 304.65, Vrijednost: 101557.62, Provizija 20.66)
# 2024-03-06, Kreiraj Kupnju, 303.77
# 2024-03-07, Narudžba je otkazana/margina/odbijena
# 2024-03-08, Kreiraj Kupnju, 305.28
# 2024-03-11, Izvršena KUPNJA (Cijena: 302.64, Vrijednost: 102292.32, Provizija 20.46)
# 2024-03-13, Kreiraj Prodaju, 304.68
# 2024-03-14, Izvršena PRODAJA (Cijena: 305.00, Vrijednost: 102292.32, Provizija 20.62)
# 2024-03-20, Kreiraj Kupnju, 306.08
# 2024-03-21, Narudžba je otkazana/margina/odbijena
# 2024-03-21, Kreiraj Kupnju, 308.39
# 2024-03-22, Narudžba je otkazana/margina/odbijena
# 2024-03-22, Kreiraj Kupnju, 307.77
# 2024-03-25, Izvršena KUPNJA (Cijena: 303.70, Vrijednost: 102650.60, Provizija 20.53)
# 2024-03-27, Kreiraj Prodaju, 301.38
# 2024-03-28, Izvršena PRODAJA (Cijena: 300.00, Vrijednost: 102650.60, Provizija 20.28)
# 2024-04-09, Kreiraj Kupnju, 302.37
# 2024-04-10, Izvršena KUPNJA (Cijena: 298.45, Vrijednost: 101473.00, Provizija 20.29)
# 2024-04-10, Kreiraj Prodaju, 299.62
# 2024-04-11, Izvršena PRODAJA (Cijena: 299.47, Vrijednost: 101473.00, Provizija 20.36)
# 2024-04-29, Kreiraj Kupnju, 275.74
# 2024-04-30, Izvršena KUPNJA (Cijena: 274.51, Vrijednost: 102666.74, Provizija 20.53)
# 2024-04-30, Kreiraj Prodaju, 268.94
# 2024-05-01, Izvršena PRODAJA (Cijena: 269.02, Vrijednost: 102666.74, Provizija 20.12)
# 2024-05-03, Kreiraj Kupnju, 273.66
# 2024-05-06, Narudžba je otkazana/margina/odbijena
# 2024-05-06, Kreiraj Kupnju, 275.63
# 2024-05-07, Izvršena KUPNJA (Cijena: 275.59, Vrijednost: 100865.94, Provizija 20.17)
# 2024-05-23, Kreiraj Prodaju, 278.57
# 2024-05-24, Izvršena PRODAJA (Cijena: 270.93, Vrijednost: 100865.94, Provizija 19.83)
# 2024-06-11, Kreiraj Kupnju, 240.99
# 2024-06-12, Izvršena KUPNJA (Cijena: 240.56, Vrijednost: 99110.72, Provizija 19.82)
# 2024-06-12, Kreiraj Prodaju, 235.80
# 2024-06-13, Izvršena PRODAJA (Cijena: 235.52, Vrijednost: 99110.72, Provizija 19.41)
# 2024-06-20, Kreiraj Kupnju, 241.80
# 2024-06-21, Izvršena KUPNJA (Cijena: 240.57, Vrijednost: 96709.14, Provizija 19.34)
# 2024-07-09, Kreiraj Prodaju, 252.43
# 2024-07-10, Izvršena PRODAJA (Cijena: 251.20, Vrijednost: 96709.14, Provizija 20.20)
# 2024-07-16, Kreiraj Kupnju, 256.03
# 2024-07-17, Izvršena KUPNJA (Cijena: 254.00, Vrijednost: 100584.00, Provizija 20.12)
# 2024-07-17, Kreiraj Prodaju, 251.22
# 2024-07-18, Izvršena PRODAJA (Cijena: 252.14, Vrijednost: 100584.00, Provizija 19.97)
# 2024-07-22, Kreiraj Kupnju, 254.08
# 2024-07-23, Narudžba je otkazana/margina/odbijena
# 2024-07-23, Kreiraj Kupnju, 256.06
# 2024-07-24, Izvršena KUPNJA (Cijena: 253.63, Vrijednost: 99676.59, Provizija 19.94)
# 2024-07-24, Kreiraj Prodaju, 249.78
# 2024-07-25, Izvršena PRODAJA (Cijena: 254.74, Vrijednost: 99676.59, Provizija 20.02)
# 2024-07-25, Kreiraj Kupnju, 256.52
# 2024-07-26, Narudžba je otkazana/margina/odbijena
# 2024-07-26, Kreiraj Kupnju, 262.71
# 2024-07-29, Izvršena KUPNJA (Cijena: 262.71, Vrijednost: 100880.64, Provizija 20.18)
# Završno stanje portfelja: 99277.77
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1.252%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-07-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>6</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-1.252%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-0.722%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.931%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.12</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.804%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.05</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>4.20</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.258%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('crm_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
