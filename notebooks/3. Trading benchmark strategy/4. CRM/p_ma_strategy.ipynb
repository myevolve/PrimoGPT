# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Create Buy, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Create Sell, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "BUY EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "SELL EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Order is canceled/margin/rejected")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date, multi_level_index=False)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Initial portfolio value: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Final portfolio value: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'CRM', '2024-04-01', '2025-02-28')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Initial portfolio value: 100000.00
# 2024-04-29, Create Buy, 274.57
# 2024-04-30, BUY EXECUTED (Price: 273.34, Value: 99496.44, Commission 0.00)
# 2024-04-30, Create Sell, 267.80
# 2024-05-01, SELL EXECUTED (Price: 267.88, Value: 99496.44, Commission 0.00)
# 2024-05-03, Create Buy, 272.50
# 2024-05-06, Order is canceled/margin/rejected
# 2024-05-06, Create Buy, 274.46
# 2024-05-07, BUY EXECUTED (Price: 274.42, Value: 97966.96, Commission 0.00)
# 2024-05-23, Create Sell, 277.38
# 2024-05-24, SELL EXECUTED (Price: 269.78, Value: 97966.96, Commission 0.00)
# 2024-06-11, Create Buy, 239.96
# 2024-06-12, BUY EXECUTED (Price: 239.54, Value: 96054.07, Commission 0.00)
# 2024-06-12, Create Sell, 234.80
# 2024-06-13, SELL EXECUTED (Price: 234.52, Value: 96054.07, Commission 0.00)
# 2024-06-20, Create Buy, 240.77
# 2024-06-21, BUY EXECUTED (Price: 239.55, Value: 93662.60, Commission 0.00)
# 2024-07-09, Create Sell, 251.75
# 2024-07-10, SELL EXECUTED (Price: 250.52, Value: 93662.60, Commission 0.00)
# 2024-07-16, Create Buy, 255.34
# 2024-07-17, BUY EXECUTED (Price: 253.31, Value: 97778.75, Commission 0.00)
# 2024-07-17, Create Sell, 250.54
# 2024-07-18, SELL EXECUTED (Price: 251.46, Value: 97778.75, Commission 0.00)
# 2024-07-22, Create Buy, 253.39
# 2024-07-23, Order is canceled/margin/rejected
# 2024-07-23, Create Buy, 255.37
# 2024-07-24, BUY EXECUTED (Price: 252.94, Value: 96877.49, Commission 0.00)
# 2024-07-24, Create Sell, 249.10
# 2024-07-25, SELL EXECUTED (Price: 254.05, Value: 96877.49, Commission 0.00)
# 2024-07-25, Create Buy, 255.83
# 2024-07-26, Order is canceled/margin/rejected
# 2024-07-26, Create Buy, 262.00
# 2024-07-29, BUY EXECUTED (Price: 262.00, Value: 98249.72, Commission 0.00)
# 2024-08-01, Create Sell, 252.38
# 2024-08-02, SELL EXECUTED (Price: 247.12, Value: 98249.72, Commission 0.00)
# 2024-08-09, Create Buy, 251.85
# 2024-08-12, BUY EXECUTED (Price: 251.92, Value: 92705.32, Commission 0.00)
# 2024-08-22, Create Sell, 257.89
# 2024-08-23, SELL EXECUTED (Price: 261.28, Value: 92705.32, Commission 0.00)
# 2024-08-23, Create Buy, 263.29
# 2024-08-26, BUY EXECUTED (Price: 263.23, Value: 96077.46, Commission 0.00)
# 2024-08-28, Create Sell, 258.20
# 2024-08-29, SELL EXECUTED (Price: 270.28, Value: 96077.46, Commission 0.00)
# 2024-09-12, Create Buy, 252.68
# 2024-09-13, BUY EXECUTED (Price: 251.86, Value: 98224.14, Commission 0.00)
# 2024-10-22, Create Sell, 288.00
# 2024-10-23, SELL EXECUTED (Price: 287.40, Value: 98224.14, Commission 0.00)
# 2024-10-25, Create Buy, 290.13
# 2024-10-28, Order is canceled/margin/rejected
# 2024-10-28, Create Buy, 293.44
# 2024-10-29, BUY EXECUTED (Price: 293.66, Value: 112473.67, Commission 0.00)
# 2024-10-31, Create Sell, 291.04
# 2024-11-01, SELL EXECUTED (Price: 289.90, Value: 112473.67, Commission 0.00)
# 2024-11-01, Create Buy, 294.38
# 2024-11-04, Order is canceled/margin/rejected
# 2024-11-04, Create Buy, 297.67
# 2024-11-05, BUY EXECUTED (Price: 297.10, Value: 110818.68, Commission 0.00)
# 2024-11-18, Create Sell, 321.88
# 2024-11-19, SELL EXECUTED (Price: 318.64, Value: 110818.68, Commission 0.00)
# 2024-11-21, Create Buy, 335.40
# 2024-11-22, Order is canceled/margin/rejected
# 2024-11-22, Create Buy, 341.63
# 2024-11-25, Order is canceled/margin/rejected
# 2024-11-25, Create Buy, 338.72
# 2024-11-26, Order is canceled/margin/rejected
# 2024-11-26, Create Buy, 342.79
# 2024-11-27, BUY EXECUTED (Price: 336.08, Value: 116618.56, Commission 0.00)
# 2024-11-27, Create Sell, 329.63
# 2024-11-29, SELL EXECUTED (Price: 328.96, Value: 116618.56, Commission 0.00)
# 2024-12-04, Create Buy, 367.45
# 2024-12-05, BUY EXECUTED (Price: 360.37, Value: 114236.92, Commission 0.00)
# 2024-12-17, Create Sell, 350.57
# 2024-12-18, SELL EXECUTED (Price: 354.50, Value: 114236.92, Commission 0.00)
# 2025-01-17, Create Buy, 324.56
# 2025-01-21, Order is canceled/margin/rejected
# 2025-01-21, Create Buy, 326.84
# 2025-01-22, Order is canceled/margin/rejected
# 2025-01-22, Create Buy, 332.62
# 2025-01-23, BUY EXECUTED (Price: 332.33, Value: 114653.85, Commission 0.00)
# 2025-02-03, Create Sell, 339.24
# 2025-02-04, SELL EXECUTED (Price: 345.62, Value: 114653.85, Commission 0.00)
# 2025-02-04, Create Buy, 344.14
# 2025-02-05, Order is canceled/margin/rejected
# 2025-02-05, Create Buy, 347.93
# 2025-02-06, BUY EXECUTED (Price: 337.48, Value: 115755.64, Commission 0.00)
# 2025-02-06, Create Sell, 330.81
# 2025-02-07, SELL EXECUTED (Price: 332.00, Value: 115755.64, Commission 0.00)
# Final portfolio value: 117610.16
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.542%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-04-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-02-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>10</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.542%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>17.61%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.121%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.69</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.53%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.74</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>4.75</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.456%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('results/crm_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
