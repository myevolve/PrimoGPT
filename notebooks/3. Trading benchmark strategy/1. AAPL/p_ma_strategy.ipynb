# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Kreiraj Kupnju, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Kreiraj Prodaju, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "Izvršena KUPNJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "Izvršena PRODAJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Narudžba je otkazana/margina/odbijena")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0.0002)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Početno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Završno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'AAPL', '2024-01-01', '2024-07-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Početno stanje portfelja: 100000.00
# 2024-01-18, Kreiraj Kupnju, 188.63
# 2024-01-19, Narudžba je otkazana/margina/odbijena
# 2024-01-19, Kreiraj Kupnju, 191.56
# 2024-01-22, Narudžba je otkazana/margina/odbijena
# 2024-01-22, Kreiraj Kupnju, 193.89
# 2024-01-23, Narudžba je otkazana/margina/odbijena
# 2024-01-23, Kreiraj Kupnju, 195.18
# 2024-01-24, Narudžba je otkazana/margina/odbijena
# 2024-01-24, Kreiraj Kupnju, 194.50
# 2024-01-25, Narudžba je otkazana/margina/odbijena
# 2024-01-25, Kreiraj Kupnju, 194.17
# 2024-01-26, Narudžba je otkazana/margina/odbijena
# 2024-01-26, Kreiraj Kupnju, 192.42
# 2024-01-29, Izvršena KUPNJA (Cijena: 192.01, Vrijednost: 99653.19, Provizija 19.93)
# 2024-01-30, Kreiraj Prodaju, 188.04
# 2024-01-31, Izvršena PRODAJA (Cijena: 187.04, Vrijednost: 99653.19, Provizija 19.41)
# 2024-02-07, Kreiraj Kupnju, 189.41
# 2024-02-08, Izvršena KUPNJA (Cijena: 189.39, Vrijednost: 97346.46, Provizija 19.47)
# 2024-02-08, Kreiraj Prodaju, 188.32
# 2024-02-09, Izvršena PRODAJA (Cijena: 188.65, Vrijednost: 97346.46, Provizija 19.39)
# 2024-02-09, Kreiraj Kupnju, 188.85
# 2024-02-12, Izvršena KUPNJA (Cijena: 188.42, Vrijednost: 96659.46, Provizija 19.33)
# 2024-02-12, Kreiraj Prodaju, 187.15
# 2024-02-13, Izvršena PRODAJA (Cijena: 185.77, Vrijednost: 96659.46, Provizija 19.06)
# 2024-03-14, Kreiraj Kupnju, 173.00
# 2024-03-15, Izvršena KUPNJA (Cijena: 171.17, Vrijednost: 94485.84, Provizija 18.90)
# 2024-03-21, Kreiraj Prodaju, 171.37
# 2024-03-22, Izvršena PRODAJA (Cijena: 171.76, Vrijednost: 94485.84, Provizija 18.96)
# 2024-03-27, Kreiraj Kupnju, 173.31
# 2024-03-28, Narudžba je otkazana/margina/odbijena
# 2024-04-11, Kreiraj Kupnju, 175.04
# 2024-04-12, Izvršena KUPNJA (Cijena: 174.26, Vrijednost: 95320.22, Provizija 19.06)
# 2024-04-16, Kreiraj Prodaju, 169.38
# 2024-04-17, Izvršena PRODAJA (Cijena: 169.61, Vrijednost: 95320.22, Provizija 18.56)
# 2024-04-25, Kreiraj Kupnju, 169.89
# 2024-04-26, Narudžba je otkazana/margina/odbijena
# 2024-04-26, Kreiraj Kupnju, 169.30
# 2024-04-29, Narudžba je otkazana/margina/odbijena
# 2024-04-29, Kreiraj Kupnju, 173.50
# 2024-04-30, Izvršena KUPNJA (Cijena: 173.33, Vrijednost: 93078.21, Provizija 18.62)
# 2024-05-23, Kreiraj Prodaju, 186.88
# 2024-05-24, Izvršena PRODAJA (Cijena: 188.82, Vrijednost: 93078.21, Provizija 20.28)
# 2024-05-24, Kreiraj Kupnju, 189.98
# 2024-05-28, Narudžba je otkazana/margina/odbijena
# 2024-05-28, Kreiraj Kupnju, 189.99
# 2024-05-29, Izvršena KUPNJA (Cijena: 189.61, Vrijednost: 101251.74, Provizija 20.25)
# 2024-06-10, Kreiraj Prodaju, 193.12
# 2024-06-11, Izvršena PRODAJA (Cijena: 193.65, Vrijednost: 101251.74, Provizija 20.68)
# 2024-06-11, Kreiraj Kupnju, 207.15
# 2024-06-12, Narudžba je otkazana/margina/odbijena
# 2024-06-12, Kreiraj Kupnju, 213.07
# 2024-06-13, Narudžba je otkazana/margina/odbijena
# 2024-06-13, Kreiraj Kupnju, 214.24
# 2024-06-14, Izvršena KUPNJA (Cijena: 213.85, Vrijednost: 103289.55, Provizija 20.66)
# 2024-06-21, Kreiraj Prodaju, 207.49
# 2024-06-24, Izvršena PRODAJA (Cijena: 207.72, Vrijednost: 103289.55, Provizija 20.07)
# 2024-06-26, Kreiraj Kupnju, 213.25
# 2024-06-27, Narudžba je otkazana/margina/odbijena
# 2024-06-27, Kreiraj Kupnju, 214.10
# 2024-06-28, Narudžba je otkazana/margina/odbijena
# 2024-07-01, Kreiraj Kupnju, 216.75
# 2024-07-02, Izvršena KUPNJA (Cijena: 216.15, Vrijednost: 100293.60, Provizija 20.06)
# 2024-07-17, Kreiraj Prodaju, 228.88
# 2024-07-18, Izvršena PRODAJA (Cijena: 230.28, Vrijednost: 100293.60, Provizija 21.37)
# Završno stanje portfelja: 107179.85
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.807%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-07-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>6</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.807%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>7.18%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.821%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.44</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.912%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.24</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.74</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>9.93</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.94%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('aapl_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
