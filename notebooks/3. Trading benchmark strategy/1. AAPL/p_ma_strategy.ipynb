# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Create Buy, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Create Sell, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "BUY EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "SELL EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Order is canceled/margin/rejected")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date, multi_level_index=False)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Initial portfolio value: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Final portfolio value: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'AAPL', '2024-08-01', '2025-02-28')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Initial portfolio value: 100000.00
# 2024-08-14, Create Buy, 221.23
# 2024-08-15, Order is canceled/margin/rejected
# 2024-08-15, Create Buy, 224.23
# 2024-08-16, BUY EXECUTED (Price: 223.43, Value: 99425.58, Commission 0.00)
# 2024-09-03, Create Sell, 222.28
# 2024-09-04, SELL EXECUTED (Price: 221.17, Value: 99425.58, Commission 0.00)
# 2024-09-13, Create Buy, 222.01
# 2024-09-16, BUY EXECUTED (Price: 216.06, Value: 96148.68, Commission 0.00)
# 2024-09-16, Create Sell, 215.84
# 2024-09-17, SELL EXECUTED (Price: 215.28, Value: 96148.68, Commission 0.00)
# 2024-09-18, Create Buy, 220.21
# 2024-09-19, Order is canceled/margin/rejected
# 2024-09-19, Create Buy, 228.37
# 2024-09-20, Order is canceled/margin/rejected
# 2024-09-20, Create Buy, 227.70
# 2024-09-23, BUY EXECUTED (Price: 226.84, Value: 98222.04, Commission 0.00)
# 2024-10-01, Create Sell, 225.71
# 2024-10-02, SELL EXECUTED (Price: 225.39, Value: 98222.04, Commission 0.00)
# 2024-10-09, Create Buy, 229.04
# 2024-10-10, BUY EXECUTED (Price: 227.28, Value: 97048.47, Commission 0.00)
# 2024-10-23, Create Sell, 230.25
# 2024-10-24, SELL EXECUTED (Price: 229.47, Value: 97048.47, Commission 0.00)
# 2024-10-28, Create Buy, 232.89
# 2024-10-29, BUY EXECUTED (Price: 232.59, Value: 98617.36, Commission 0.00)
# 2024-10-30, Create Sell, 229.59
# 2024-10-31, SELL EXECUTED (Price: 228.84, Value: 98617.36, Commission 0.00)
# 2024-11-07, Create Buy, 226.98
# 2024-11-08, BUY EXECUTED (Price: 226.92, Value: 97121.97, Commission 0.00)
# 2024-11-11, Create Sell, 223.98
# 2024-11-12, SELL EXECUTED (Price: 224.30, Value: 97121.97, Commission 0.00)
# 2024-11-13, Create Buy, 224.87
# 2024-11-14, BUY EXECUTED (Price: 224.77, Value: 96202.79, Commission 0.00)
# 2024-12-30, Create Sell, 251.92
# 2024-12-31, SELL EXECUTED (Price: 252.16, Value: 96202.79, Commission 0.00)
# 2025-01-27, Create Buy, 229.61
# 2025-01-28, Order is canceled/margin/rejected
# 2025-01-28, Create Buy, 238.00
# 2025-01-29, BUY EXECUTED (Price: 233.86, Value: 105939.88, Commission 0.00)
# 2025-02-03, Create Sell, 227.76
# 2025-02-04, SELL EXECUTED (Price: 227.00, Value: 105939.88, Commission 0.00)
# 2025-02-04, Create Buy, 232.54
# 2025-02-05, BUY EXECUTED (Price: 228.28, Value: 102725.56, Commission 0.00)
# 2025-02-07, Create Sell, 227.38
# 2025-02-10, SELL EXECUTED (Price: 229.57, Value: 102725.56, Commission 0.00)
# 2025-02-11, Create Buy, 232.62
# 2025-02-12, BUY EXECUTED (Price: 231.20, Value: 104733.60, Commission 0.00)
# 2025-02-26, Create Sell, 240.36
# 2025-02-27, SELL EXECUTED (Price: 239.41, Value: 104733.60, Commission 0.00)
# Final portfolio value: 109159.99
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.577%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-08-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-02-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>6</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>16.577%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>9.16%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.563%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.62</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-6.332%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.56</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.72</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.74</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.77%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('results/aapl_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
