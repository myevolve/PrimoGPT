# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Kreiraj Kupnju, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Kreiraj Prodaju, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "Izvršena KUPNJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "Izvršena PRODAJA (Cijena: %.2f, Vrijednost: %.2f, Provizija %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Narudžba je otkazana/margina/odbijena")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0.0002)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Početno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Završno stanje portfelja: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'MSFT', '2024-01-01', '2024-07-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Početno stanje portfelja: 100000.00
# 2024-01-16, Kreiraj Kupnju, 390.27
# 2024-01-17, Izvršena KUPNJA (Cijena: 387.98, Vrijednost: 99322.88, Provizija 19.86)
# 2024-01-31, Kreiraj Prodaju, 397.58
# 2024-02-01, Izvršena PRODAJA (Cijena: 401.83, Vrijednost: 99322.88, Provizija 20.57)
# 2024-02-01, Kreiraj Kupnju, 403.78
# 2024-02-02, Izvršena KUPNJA (Cijena: 403.81, Vrijednost: 103375.36, Provizija 20.68)
# 2024-02-13, Kreiraj Prodaju, 406.32
# 2024-02-14, Izvršena PRODAJA (Cijena: 408.07, Vrijednost: 103375.36, Provizija 20.89)
# 2024-02-22, Kreiraj Kupnju, 411.65
# 2024-02-23, Narudžba je otkazana/margina/odbijena
# 2024-02-23, Kreiraj Kupnju, 410.34
# 2024-02-26, Izvršena KUPNJA (Cijena: 411.46, Vrijednost: 104510.84, Provizija 20.90)
# 2024-02-26, Kreiraj Prodaju, 407.54
# 2024-02-27, Izvršena PRODAJA (Cijena: 407.99, Vrijednost: 104510.84, Provizija 20.73)
# 2024-02-27, Kreiraj Kupnju, 407.48
# 2024-02-28, Narudžba je otkazana/margina/odbijena
# 2024-02-28, Kreiraj Kupnju, 407.72
# 2024-02-29, Narudžba je otkazana/margina/odbijena
# 2024-02-29, Kreiraj Kupnju, 413.64
# 2024-03-01, Izvršena KUPNJA (Cijena: 411.27, Vrijednost: 102817.50, Provizija 20.56)
# 2024-03-05, Kreiraj Prodaju, 402.65
# 2024-03-06, Izvršena PRODAJA (Cijena: 402.97, Vrijednost: 102817.50, Provizija 20.15)
# 2024-03-07, Kreiraj Kupnju, 409.14
# 2024-03-08, Izvršena KUPNJA (Cijena: 407.96, Vrijednost: 101174.08, Provizija 20.23)
# 2024-03-08, Kreiraj Prodaju, 406.22
# 2024-03-11, Izvršena PRODAJA (Cijena: 403.76, Vrijednost: 101174.08, Provizija 20.03)
# 2024-03-12, Kreiraj Kupnju, 415.28
# 2024-03-13, Narudžba je otkazana/margina/odbijena
# 2024-03-13, Kreiraj Kupnju, 415.10
# 2024-03-14, Narudžba je otkazana/margina/odbijena
# 2024-03-14, Kreiraj Kupnju, 425.22
# 2024-03-15, Izvršena KUPNJA (Cijena: 419.29, Vrijednost: 98952.44, Provizija 19.79)
# 2024-03-26, Kreiraj Prodaju, 421.65
# 2024-03-27, Izvršena PRODAJA (Cijena: 424.44, Vrijednost: 98952.44, Provizija 20.03)
# 2024-04-01, Kreiraj Kupnju, 424.57
# 2024-04-02, Izvršena KUPNJA (Cijena: 420.11, Vrijednost: 100406.29, Provizija 20.08)
# 2024-04-02, Kreiraj Prodaju, 421.44
# 2024-04-03, Izvršena PRODAJA (Cijena: 419.73, Vrijednost: 100406.29, Provizija 20.06)
# 2024-04-05, Kreiraj Kupnju, 425.52
# 2024-04-08, Izvršena KUPNJA (Cijena: 425.17, Vrijednost: 101190.46, Provizija 20.24)
# 2024-04-12, Kreiraj Prodaju, 421.90
# 2024-04-15, Izvršena PRODAJA (Cijena: 426.60, Vrijednost: 101190.46, Provizija 20.31)
# 2024-05-03, Kreiraj Kupnju, 406.66
# 2024-05-06, Narudžba je otkazana/margina/odbijena
# 2024-05-06, Kreiraj Kupnju, 413.54
# 2024-05-07, Narudžba je otkazana/margina/odbijena
# 2024-05-07, Kreiraj Kupnju, 409.34
# 2024-05-08, Izvršena KUPNJA (Cijena: 408.17, Vrijednost: 101226.16, Provizija 20.25)
# 2024-05-30, Kreiraj Prodaju, 414.67
# 2024-05-31, Izvršena PRODAJA (Cijena: 416.75, Vrijednost: 101226.16, Provizija 20.67)
# 2024-06-05, Kreiraj Kupnju, 424.01
# 2024-06-06, Izvršena KUPNJA (Cijena: 424.01, Vrijednost: 103458.44, Provizija 20.69)
# 2024-06-28, Kreiraj Prodaju, 446.95
# 2024-07-01, Izvršena PRODAJA (Cijena: 448.66, Vrijednost: 103458.44, Provizija 21.89)
# 2024-07-01, Kreiraj Kupnju, 456.73
# 2024-07-02, Izvršena KUPNJA (Cijena: 453.20, Vrijednost: 108768.00, Provizija 21.75)
# 2024-07-11, Kreiraj Prodaju, 454.70
# 2024-07-12, Izvršena PRODAJA (Cijena: 454.33, Vrijednost: 108768.00, Provizija 21.81)
# Završno stanje portfelja: 110064.55
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.136%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-07-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>6</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>18.136%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>10.065%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.197%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.43</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.52</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.454%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.82</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.01</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.56</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.593%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('msft_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
