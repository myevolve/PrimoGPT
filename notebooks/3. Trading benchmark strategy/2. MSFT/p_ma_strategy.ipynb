# %%
import backtrader as bt
import yfinance as yf
import pyfolio as pf
import pandas as pd
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
class PMAStrategy(bt.Strategy):

    def __init__(self):
        # Initialize SMA indicator
        self.sma = bt.indicators.SMA(self.data.close, period=10)  # You can change the period as desired
        self.order = None

    def next(self):
        if self.order:  # If there is an open order, do nothing
            return

        # Buy if Pt is greater than MAt(n)
        if not self.position and self.data.close[0] > self.sma[0]:
            cash = self.broker.get_cash()
            price = self.data.close[0]
            shares_to_buy = cash // price
            if shares_to_buy > 0:            
                self.log('Create Buy, %.2f' % self.data.close[0])
                self.order = self.buy(size=shares_to_buy)

        # Sell if Pt is less than MAt(n)
        elif self.position and self.data.close[0] < self.sma[0]:
            self.log('Create Sell, %.2f' % self.data.close[0])
            self.order = self.sell(size=self.position.size)

    def log(self, txt):
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.isbuy():
                self.log(
                "BUY EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            else:
                self.log(
                "SELL EXECUTED (Price: %.2f, Value: %.2f, Commission %.2f)" %
                (order.executed.price, order.executed.value, order.executed.comm))
            self.bar_executed = len(self)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log("Order is canceled/margin/rejected")
        self.order = None

# %%
def test_strategy(strategy_class, ticker, start_date, end_date, starting_cash=100000):
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class)
    
    # Download data and store it in a variable
    yf_data = yf.download(ticker, start=start_date, end=end_date, multi_level_index=False)
    data = bt.feeds.PandasData(dataname=yf_data)
    cerebro.adddata(data)
    
    cerebro.broker.setcash(starting_cash)
    cerebro.broker.setcommission(commission=0)
    
    # Add observer to track portfolio value
    cerebro.addobserver(bt.observers.Value)
    
    # Add analyzer to track returns
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    
    print('Initial portfolio value: %.2f' % cerebro.broker.getvalue())
    results = cerebro.run()
    print('Final portfolio value: %.2f' % cerebro.broker.getvalue())
    
    strat = results[0]
    
    # Get data from PyFolio analyzer
    portfolio_value = strat.analyzers.pyfolio.get_pf_items()
    returns, positions, transactions, gross_lev = portfolio_value

    # Get portfolio values
    portfolio_values = strat.observers.value.get(size=len(strat))
    
    # Create DataFrame with dates and portfolio values
    df_portfolio = pd.DataFrame({
        'Date': yf_data.index,
        'Value': portfolio_values
    })    
    
    # Use pyfolio to generate report
    pf.create_simple_tear_sheet(returns)

    return df_portfolio

# %%
results = test_strategy(PMAStrategy, 'MSFT', '2024-04-01', '2025-02-28')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Initial portfolio value: 100000.00
# 2024-05-03, Create Buy, 403.58
# 2024-05-06, Order is canceled/margin/rejected
# 2024-05-06, Create Buy, 410.41
# 2024-05-07, BUY EXECUTED (Price: 411.52, Value: 99998.92, Commission 0.00)
# 2024-05-30, Create Sell, 412.27
# 2024-05-31, SELL EXECUTED (Price: 414.34, Value: 99998.92, Commission 0.00)
# 2024-06-05, Create Buy, 421.56
# 2024-06-06, BUY EXECUTED (Price: 421.56, Value: 100330.41, Commission 0.00)
# 2024-06-28, Create Sell, 444.36
# 2024-07-01, SELL EXECUTED (Price: 446.06, Value: 100330.41, Commission 0.00)
# 2024-07-01, Create Buy, 454.09
# 2024-07-02, BUY EXECUTED (Price: 450.58, Value: 105435.12, Commission 0.00)
# 2024-07-11, Create Sell, 452.07
# 2024-07-12, SELL EXECUTED (Price: 451.70, Value: 105435.12, Commission 0.00)
# 2024-08-13, Create Buy, 411.61
# 2024-08-14, Order is canceled/margin/rejected
# 2024-08-14, Create Buy, 414.45
# 2024-08-15, Order is canceled/margin/rejected
# 2024-08-15, Create Buy, 419.35
# 2024-08-16, BUY EXECUTED (Price: 418.92, Value: 106405.63, Commission 0.00)
# 2024-08-22, Create Sell, 413.89
# 2024-08-23, SELL EXECUTED (Price: 415.31, Value: 106405.63, Commission 0.00)
# 2024-08-30, Create Buy, 415.47
# 2024-09-03, BUY EXECUTED (Price: 416.24, Value: 105725.10, Commission 0.00)
# 2024-09-03, Create Sell, 407.80
# 2024-09-04, SELL EXECUTED (Price: 404.29, Value: 105725.10, Commission 0.00)
# 2024-09-10, Create Buy, 412.55
# 2024-09-11, Order is canceled/margin/rejected
# 2024-09-11, Create Buy, 421.35
# 2024-09-12, Order is canceled/margin/rejected
# 2024-09-12, Create Buy, 425.29
# 2024-09-13, BUY EXECUTED (Price: 424.13, Value: 102215.07, Commission 0.00)
# 2024-09-24, Create Sell, 427.46
# 2024-09-25, SELL EXECUTED (Price: 428.11, Value: 102215.07, Commission 0.00)
# 2024-10-14, Create Buy, 417.47
# 2024-10-15, Order is canceled/margin/rejected
# 2024-10-15, Create Buy, 417.07
# 2024-10-16, BUY EXECUTED (Price: 413.51, Value: 102550.86, Commission 0.00)
# 2024-10-31, Create Sell, 404.73
# 2024-11-01, SELL EXECUTED (Price: 407.38, Value: 102550.86, Commission 0.00)
# 2024-11-06, Create Buy, 418.50
# 2024-11-07, Order is canceled/margin/rejected
# 2024-11-07, Create Buy, 423.73
# 2024-11-08, BUY EXECUTED (Price: 423.62, Value: 102092.65, Commission 0.00)
# 2024-11-11, Create Sell, 416.34
# 2024-11-12, SELL EXECUTED (Price: 416.58, Value: 102092.65, Commission 0.00)
# 2024-11-12, Create Buy, 421.34
# 2024-11-13, BUY EXECUTED (Price: 419.96, Value: 99949.45, Commission 0.00)
# 2024-11-15, Create Sell, 413.34
# 2024-11-18, SELL EXECUTED (Price: 413.21, Value: 99949.45, Commission 0.00)
# 2024-11-25, Create Buy, 417.95
# 2024-11-26, BUY EXECUTED (Price: 418.75, Value: 98825.08, Commission 0.00)
# 2024-12-18, Create Sell, 436.51
# 2024-12-19, SELL EXECUTED (Price: 440.74, Value: 98825.08, Commission 0.00)
# 2025-01-15, Create Buy, 425.46
# 2025-01-16, Order is canceled/margin/rejected
# 2025-01-16, Create Buy, 423.73
# 2025-01-17, Order is canceled/margin/rejected
# 2025-01-17, Create Buy, 428.17
# 2025-01-21, Order is canceled/margin/rejected
# 2025-01-21, Create Buy, 427.64
# 2025-01-22, Order is canceled/margin/rejected
# 2025-01-22, Create Buy, 445.31
# 2025-01-23, BUY EXECUTED (Price: 441.12, Value: 102779.91, Commission 0.00)
# 2025-01-30, Create Sell, 414.16
# 2025-01-31, SELL EXECUTED (Price: 418.14, Value: 102779.91, Commission 0.00)
# 2025-02-19, Create Buy, 413.94
# 2025-02-20, Order is canceled/margin/rejected
# 2025-02-20, Create Buy, 416.13
# 2025-02-21, Order is canceled/margin/rejected
# Final portfolio value: 98801.76
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1.318%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-04-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-02-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>10</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-1.318%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-1.198%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.998%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.01</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.12</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.909%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.02</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-2.66</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>15.50</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.89%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

# Za df_account_value_sac
with open('results/msft_p_ma_strategy.pkl', 'wb') as f:
    pickle.dump(results, f)
