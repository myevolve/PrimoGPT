# %% [markdown]
# ## 1. Loading Required Packages

# %%
# Standard libraries
import sys
sys.path.append('../../')

import itertools

# Data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL and stable_baselines3 for machine learning and trading
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Configuration files and helper functions from FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Enabling chart display within Jupyter notebook
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_AAPL'
RESULTS_DIR = 'files/results_AAPL'
DATA_DIR = 'files/data_AAPL'

# Checking and creating directories
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Data Retrieval

# %% [markdown]
# We have a class called YahooDownloader that uses yfinance to fetch data from Yahoo Finance.
#
# In the YahooDownloader of FinRL, we modified the data frame into a format suitable for further data processing. We use a custom closing price instead of the regular closing price and add a column that represents the day of the week (0-4 corresponding to Monday-Friday).

# %%
# Training and trading intervals
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2023-12-31'
TRADE_START_DATE = '2024-01-01'
TRADE_END_DATE = '2024-07-31'

# %%
# Fetching all data
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['AAPL']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (731, 8)

# %%
df_raw.head()
# Out:
#          date        open        high         low       close    volume   tic  \
# 0  2021-09-01  152.830002  154.979996  152.339996  149.998199  80313700  AAPL
# 1  2021-09-02  153.869995  154.720001  152.399994  151.119446  71115500  AAPL
# 2  2021-09-03  153.759995  154.630005  153.089996  151.758743  57808700  AAPL
# 3  2021-09-07  154.970001  157.259995  154.389999  154.109360  82278300  AAPL
# 4  2021-09-08  156.979996  157.039993  153.979996  152.555374  74420200  AAPL
#
#    day
# 0    2
# 1    3
# 2    4
# 3    1
# 4    2

# %% [markdown]
# ## 3. Data Processing

# %% [markdown]
# We use the defined class FeatureEngineer to process data and add technical indicators.
#
# The use_vix option includes the VIX index, known as the "fear index," which represents the expected volatility of the stock market based on S&P 500 options. The VIX helps the model understand market uncertainty, with higher values indicating greater uncertainty.
#
# The use_turbulence option includes the turbulence index, which measures unusual market fluctuations and serves as an indicator of risk and market shocks. It is useful for identifying periods of high volatility, helping the model to adapt to financial crises.
#
# Overall, a quite handy class that contains useful methods for processing financial data and can be applied to numerous other purposes.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (730, 8)
# Successfully added vix

# %%
# Creates a list of unique stock tickers from the 'tic' column of the 'processed' DataFrame.
list_ticker = processed["tic"].unique().tolist()

# Creates a list of dates between the earliest and latest dates in the 'processed' DataFrame, converting them to strings.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Creates combinations of all dates and stock tickers using the Cartesian product.
combination = list(itertools.product(list_date,list_ticker))

# Creates a new DataFrame 'processed_full' with columns "date" and "tic", containing all combinations of dates and stock tickers.
# Merges this DataFrame with the original 'processed' DataFrame based on the "date" and "tic" columns, using a 'left' join.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filters the 'processed_full' DataFrame to only include rows where the dates are present in the original 'processed' DataFrame.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sorts the 'processed_full' DataFrame by date and stock ticker.
processed_full = processed_full.sort_values(['date','tic'])

# Replaces all missing values (NaN) with 0 in the 'processed_full' DataFrame.
processed_full = processed_full.fillna(0)

# %%
processed_full.head(30)
# Out:
#           date   tic        open        high         low       close  \
# 0   2021-09-01  AAPL  152.830002  154.979996  152.339996  149.998199
# 1   2021-09-02  AAPL  153.869995  154.720001  152.399994  151.119446
# 2   2021-09-03  AAPL  153.759995  154.630005  153.089996  151.758743
# 6   2021-09-07  AAPL  154.970001  157.259995  154.389999  154.109360
# 7   2021-09-08  AAPL  156.979996  157.039993  153.979996  152.555374
# 8   2021-09-09  AAPL  155.490005  156.110001  153.949997  151.532516
# 9   2021-09-10  AAPL  155.000000  155.479996  148.699997  146.516510
# 12  2021-09-13  AAPL  150.630005  151.419998  148.750000  147.086990
# 13  2021-09-14  AAPL  150.350006  151.070007  146.910004  145.680481
# 14  2021-09-15  AAPL  148.559998  149.440002  146.369995  146.575516
# 15  2021-09-16  AAPL  148.440002  148.970001  147.220001  146.339478
# 16  2021-09-17  AAPL  148.820007  148.820007  145.759995  143.654434
# 19  2021-09-20  AAPL  143.800003  144.839996  141.270004  140.585815
# 20  2021-09-21  AAPL  143.929993  144.600006  142.779999  141.067749
# 21  2021-09-22  AAPL  144.449997  146.429993  143.699997  143.447861
# 22  2021-09-23  AAPL  146.649994  147.080002  145.639999  144.411758
# 23  2021-09-24  AAPL  145.660004  147.470001  145.559998  144.500290
# 26  2021-09-27  AAPL  145.470001  145.960007  143.820007  142.975769
# 27  2021-09-28  AAPL  143.250000  144.750000  141.690002  139.572784
# 28  2021-09-29  AAPL  142.470001  144.449997  142.029999  140.477615
# 29  2021-09-30  AAPL  143.660004  144.380005  141.279999  139.169510
# 30  2021-10-01  AAPL  141.899994  142.919998  139.110001  140.300598
# 33  2021-10-04  AAPL  141.759995  142.210007  138.270004  136.848404
# 34  2021-10-05  AAPL  139.490005  142.240005  139.360001  138.785934
# 35  2021-10-06  AAPL  139.470001  142.149994  138.369995  139.661316
# 36  2021-10-07  AAPL  143.059998  144.220001  142.720001  140.930054
# 37  2021-10-08  AAPL  144.029999  144.179993  142.559998  140.546478
# 40  2021-10-11  AAPL  142.270004  144.809998  141.809998  140.457947
# 41  2021-10-12  AAPL  143.229996  143.250000  141.039993  139.179337
# 42  2021-10-13  AAPL  141.240005  141.399994  139.199997  138.589249
#
#          volume  day      macd     boll_ub     boll_lb      rsi_30  \
# 0    80313700.0  2.0  0.000000  152.144504  148.973141  100.000000
# 1    71115500.0  3.0  0.025156  152.144504  148.973141  100.000000
# 2    57808700.0  4.0  0.051879  152.741193  149.176399  100.000000
# 6    82278300.0  1.0  0.147629  155.216885  148.275989  100.000000
# 7    74420200.0  2.0  0.134714  154.999585  148.816864   71.415455
# 8    57305700.0  3.0  0.080680  154.627569  149.063644   59.780105
# 9   140893200.0  4.0 -0.182596  155.846405  146.322209   32.728963
# 12  102404300.0  0.0 -0.329062  155.821741  145.347544   36.129408
# 13  109296300.0  1.0 -0.495263  155.929391  144.150080   32.003409
# 14   83281300.0  2.0 -0.559853  155.662748  143.723880   36.757809
# 15   68034100.0  3.0 -0.611251  155.401820  143.375019   36.069763
# 16  129868800.0  4.0 -0.788109  155.531249  142.289926   29.558779
# 19  123478900.0  0.0 -1.082157  156.112671  140.427770   24.360058
# 20   75834000.0  1.0 -1.260271  156.217114  139.294402   26.461382
# 21   76404300.0  2.0 -1.237276  155.920159  139.016970   35.601485
# 22   64838200.0  3.0 -1.145816  155.584349  138.970680   38.788788
# 23   53477900.0  4.0 -1.056367  155.269245  138.959052   39.075293
# 26   74150700.0  0.0 -1.071016  155.032816  138.735660   36.067966
# 27  108972300.0  1.0 -1.287544  155.099696  137.899154   30.625332
# 28   74602000.0  2.0 -1.379915  154.991753  137.404916   33.390089
# 29   89056700.0  3.0 -1.521287  154.792054  136.521746   31.511941
# 30   94639600.0  4.0 -1.536744  154.170071  136.061844   34.792780
# 33   98322000.0  0.0 -1.765047  153.575708  135.165173   30.221772
# 34   80861100.0  1.0 -1.788333  151.902656  135.305883   35.167098
# 35   83221100.0  2.0 -1.724570  150.275189  135.643944   37.245789
# 36   61732700.0  3.0 -1.565636  148.571874  136.287012   40.124141
# 37   58773200.0  4.0 -1.450698  148.011764  136.250120   39.556697
# 40   64452200.0  0.0 -1.350500  147.234534  136.364446   39.423577
# 41   73035900.0  1.0 -1.348787  146.705986  136.242879   37.536286
# 42   78762700.0  2.0 -1.374653  145.868045  136.282193   36.697557
#
#         cci_30       dx_30  close_30_sma  close_60_sma        vix
# 0    66.666667  100.000000    149.998199    149.998199  16.110001
# 1    66.666667  100.000000    150.558823    150.558823  16.410000
# 2   100.000000  100.000000    150.958796    150.958796  16.410000
# 6   133.333333  100.000000    151.746437    151.746437  18.139999
# 7    59.342758   72.225050    151.908224    151.908224  17.959999
# 8    15.067269   70.433548    151.845606    151.845606  18.799999
# 9  -166.643825   40.887693    151.084307    151.084307  20.950001
# 12 -153.072930   40.887693    150.584642    150.584642  19.370001
# 13 -138.553544   52.519397    150.039736    150.039736  19.459999
# 14 -116.812894   55.196030    149.693314    149.693314  18.180000
# 15  -97.125841   55.196030    149.388419    149.388419  18.690001
# 16 -113.249971   61.479074    148.910587    148.910587  20.809999
# 19 -165.103407   73.362863    148.270220    148.270220  25.709999
# 20 -130.034025   73.362863    147.755758    147.755758  24.360001
# 21  -88.889166   52.802211    147.468565    147.468565  20.870001
# 22  -63.226366   46.421340    147.277514    147.277514  18.629999
# 23  -57.673451   42.722126    147.114148    147.114148  17.750000
# 26  -82.023014   48.703475    146.884238    146.884238  18.760000
# 27 -114.058987   54.694732    146.499425    146.499425  23.250000
# 28 -101.410089   54.694732    146.198335    146.198335  22.559999
# 29 -106.578555   56.604590    145.863629    145.863629  23.139999
# 30 -112.595158   61.466551    145.610764    145.610764  21.100000
# 33 -129.153372   63.121127    145.229791    145.229791  22.959999
# 34 -105.420981   62.862770    144.961297    144.961297  21.299999
# 35 -100.615828   64.767821    144.749298    144.749298  21.000000
# 36  -58.559487   48.311612    144.602404    144.602404  19.540001
# 37  -59.907218   48.721134    144.452185    144.452185  18.770000
# 40  -59.394050   50.618298    144.309533    144.309533  20.000000
# 41  -76.157746   52.485319    144.132630    144.132630  19.850000
# 42  -94.958065   56.546524    143.947851    143.947851  18.639999

# %%
# Preparing the training and trade set according to the defined dates
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 586
# 144

# %%
# Saving the data
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Preparing the environment

# %% [markdown]
# stock_dimension represents the number of unique stocks in the dataset. This value is used to determine how many different stocks the model can trade.
#
# state_space denotes the total size of the state space that the model uses for decision-making. The state space includes current stock data (such as prices and technical indicators) and information about the current portfolio (such as the number of shares owned). The size of the state space is determined by a formula that takes into account the number of stocks and the number of technical indicators.

# %%
# Calculating the dimension (number of unique stocks) from the 'train' DataFrame.
stock_dimension = len(train.tic.unique())

# Calculating the state size based on the dimension and the number of technical indicators.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Creates lists of buy and sell costs for each stock.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Initializes the number of shares for each stock to 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym is an instance of the StockTradingEnv class, which represents the trading environment. This environment uses the data and parameters defined to simulate the stock market. The model learns how to trade within this environment, trying to maximize the total reward (profit) through a series of trading decisions.
#
# env_train is obtained by calling the get_sb_env() method on the e_train_gym instance. This method returns an environment compatible with the Stable Baselines 3 library, which is used for implementing reinforcement learning algorithms. The second return element, which is ignored here (_), can be used for additional information or functionalities provided by the environment.

# %%
# Define arguments for the trading environment.
env_kwargs = {
    "hmax": 1000,  # Maximum number of shares that can be bought or sold in a single transaction.
    "initial_amount": 100000,  # Initial amount of capital.
    "num_stock_shares": num_stock_shares,  # Initial number of shares for each stock in the portfolio, initially set to 0.
    "buy_cost_pct": buy_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "sell_cost_pct": sell_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "state_space": state_space,  # Previously defined sizes that affect the structure of the environment.
    "stock_dim": stock_dimension,  # Previously defined sizes that affect the structure of the environment.
    "tech_indicator_list": INDICATORS,  # List of technical indicators to be used for market state analysis.
    "action_space": stock_dimension,  # Size of the action space, i.e., the number of different actions the model can take.
    "reward_scaling": 1e-4  # Scaling factor for the reward, used to adjust the reward size to facilitate learning.
}

# Create the training environment.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Retrieve the environment suitable for Stable Baselines and an unused object.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Training DRL Agents

# %% [markdown]
# Here are the deep reinforcement learning (DRL) algorithms from the Stable Baselines 3 library. This is a library that has implemented popular DRL algorithms using PyTorch.
#
# As an alternative, the ElegantRL and Ray RLlib libraries can be used.

# %% [markdown]
# ### Training 5 different DRL agents (A2C, DDPG, PPO, TD3, SAC)

# %%
# Setting the appropriate values to 'True' for the algorithms you want to use
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# A new instance of the DRL agent is created with the given environment (it is not necessary to do this again, but for easier instructions, it remains)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Setting up the logger to monitor and record information during training
  tmp_path = RESULTS_DIR + '/a2c'
  # Configures a new logger that will print information to standard output, log to a CSV file, and TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Sets the new logger for the A2C model.
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Train the A2C model with the defined total number of time steps, only if if_using_a2c is set to True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Save the trained A2C model to the defined directory, only if if_using_a2c is set to True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_AAPL/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3670 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# | train/             |      |
# |    reward          | 0.0  |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3092          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.005289209   |
# |    clip_fraction        | 0.025         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.955        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0416        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00288      |
# |    reward               | -0.0077569657 |
# |    std                  | 0.999         |
# |    value_loss           | 0.138         |
# -------------------------------------------
# day: 585, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 92456.54
# total_reward: -7543.46
# total_cost: 0.00
# total_trades: 454
# Sharpe: -0.076
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2827         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0024415804 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0334      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0267       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0018      |
# |    reward               | 0.0          |
# |    std                  | 0.996        |
# |    value_loss           | 0.0987       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2777         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0024750913 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00584     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0611       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00261     |
# |    reward               | 0.0          |
# |    std                  | 0.993        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2763         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0032396584 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0313       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0268       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00213     |
# |    reward               | 0.0          |
# |    std                  | 0.99         |
# |    value_loss           | 0.098        |
# ------------------------------------------
# day: 585, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 98824.47
# total_reward: -1175.53
# total_cost: 0.00
# total_trades: 447
# Sharpe: 0.068
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2567         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0062514883 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0174      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0441       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00545     |
# |    reward               | 0.0          |
# |    std                  | 0.995        |
# |    value_loss           | 0.148        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2574         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0012183484 |
# |    clip_fraction        | 0.00679      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00434     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0252       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000911    |
# |    reward               | -0.26668295  |
# |    std                  | 0.992        |
# |    value_loss           | 0.103        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2551         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0016783283 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0272       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0578       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00246     |
# |    reward               | -0.010742259 |
# |    std                  | 0.99         |
# |    value_loss           | 0.122        |
# ------------------------------------------
# day: 585, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 103686.47
# total_reward: 3686.47
# total_cost: 0.00
# total_trades: 462
# Sharpe: 0.177
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2569         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.005069501  |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0306       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0186       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00591     |
# |    reward               | -0.028011868 |
# |    std                  | 0.99         |
# |    value_loss           | 0.0744       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2581         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0027206582 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0347       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0429       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00242     |
# |    reward               | 0.11126875   |
# |    std                  | 0.995        |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2549         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0033232064 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00686     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0558       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00511     |
# |    reward               | 0.0          |
# |    std                  | 0.995        |
# |    value_loss           | 0.126        |
# ------------------------------------------
# day: 585, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 151172.24
# total_reward: 51172.24
# total_cost: 0.00
# total_trades: 510
# Sharpe: 0.908
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2527        |
# |    iterations           | 12          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.002749908 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0358      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0389      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00127    |
# |    reward               | 0.016713113 |
# |    std                  | 0.992       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2495        |
# |    iterations           | 13          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.00428435  |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0514      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00359    |
# |    reward               | -0.08279383 |
# |    std                  | 0.993       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2500         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0074698785 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0363       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00648     |
# |    reward               | 0.0          |
# |    std                  | 0.987        |
# |    value_loss           | 0.128        |
# ------------------------------------------
# day: 585, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 84559.87
# total_reward: -15440.13
# total_cost: 0.00
# total_trades: 523
# Sharpe: -0.215
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2511         |
# |    iterations           | 15           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0056744153 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0645       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0055      |
# |    reward               | -0.30874518  |
# |    std                  | 0.988        |
# |    value_loss           | 0.144        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2507         |
# |    iterations           | 16           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033595157 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0913       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0547       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00425     |
# |    reward               | 0.01123267   |
# |    std                  | 0.979        |
# |    value_loss           | 0.148        |
# ------------------------------------------
# day: 585, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 150009.68
# total_reward: 50009.68
# total_cost: 0.00
# total_trades: 548
# Sharpe: 0.847
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2519         |
# |    iterations           | 17           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0056634652 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0618       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0049      |
# |    reward               | -0.026107544 |
# |    std                  | 0.977        |
# |    value_loss           | 0.167        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2530        |
# |    iterations           | 18          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006865034 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.104       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00696    |
# |    reward               | 0.0         |
# |    std                  | 0.974       |
# |    value_loss           | 0.202       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2540         |
# |    iterations           | 19           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0042675687 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0937       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0648       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00285     |
# |    reward               | 0.0          |
# |    std                  | 0.978        |
# |    value_loss           | 0.178        |
# ------------------------------------------
# day: 585, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 149937.64
# total_reward: 49937.64
# total_cost: 0.00
# total_trades: 566
# Sharpe: 0.810
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2539         |
# |    iterations           | 20           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0059692534 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0509       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00448     |
# |    reward               | 0.09401781   |
# |    std                  | 0.976        |
# |    value_loss           | 0.174        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2538         |
# |    iterations           | 21           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0054683164 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0977       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00295     |
# |    reward               | -0.09422574  |
# |    std                  | 0.972        |
# |    value_loss           | 0.188        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2545         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0041365274 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0398       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00404     |
# |    reward               | 0.0          |
# |    std                  | 0.972        |
# |    value_loss           | 0.167        |
# ------------------------------------------
# day: 585, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 125342.39
# total_reward: 25342.39
# total_cost: 0.00
# total_trades: 546
# Sharpe: 0.521
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2552         |
# |    iterations           | 23           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059147393 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0753       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00388     |
# |    reward               | -0.04312315  |
# |    std                  | 0.964        |
# |    value_loss           | 0.186        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2558         |
# |    iterations           | 24           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035521954 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0812       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00398     |
# |    reward               | 0.07157416   |
# |    std                  | 0.963        |
# |    value_loss           | 0.17         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2565        |
# |    iterations           | 25          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008449383 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0651      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00852    |
# |    reward               | 0.12340881  |
# |    std                  | 0.971       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# day: 585, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 173008.94
# total_reward: 73008.94
# total_cost: 0.00
# total_trades: 569
# Sharpe: 1.049
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2571         |
# |    iterations           | 26           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0035492338 |
# |    clip_fraction        | 0.0577       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.35         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0689       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00568     |
# |    reward               | 0.07642714   |
# |    std                  | 0.976        |
# |    value_loss           | 0.193        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2576        |
# |    iterations           | 27          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007002821 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0672      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00476    |
# |    reward               | 0.0         |
# |    std                  | 0.977       |
# |    value_loss           | 0.166       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2579         |
# |    iterations           | 28           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0054944693 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.341        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.079        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00404     |
# |    reward               | 0.01190747   |
# |    std                  | 0.971        |
# |    value_loss           | 0.219        |
# ------------------------------------------
# day: 585, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 122745.37
# total_reward: 22745.37
# total_cost: 0.00
# total_trades: 560
# Sharpe: 0.481
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2584         |
# |    iterations           | 29           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0044915597 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0464       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0049      |
# |    reward               | -0.33301827  |
# |    std                  | 0.962        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2583         |
# |    iterations           | 30           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0075725894 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0539       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00477     |
# |    reward               | 0.21789189   |
# |    std                  | 0.96         |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2587        |
# |    iterations           | 31          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007134445 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.05        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00425    |
# |    reward               | 0.102519184 |
# |    std                  | 0.956       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# day: 585, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 123505.99
# total_reward: 23505.99
# total_cost: 0.00
# total_trades: 545
# Sharpe: 0.506
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2591        |
# |    iterations           | 32          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008965309 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0501      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00167    |
# |    reward               | -0.12418484 |
# |    std                  | 0.963       |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2595        |
# |    iterations           | 33          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.0078244   |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0482      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00183    |
# |    reward               | -0.35624897 |
# |    std                  | 0.963       |
# |    value_loss           | 0.143       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2598         |
# |    iterations           | 34           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0056291795 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0578       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00294     |
# |    reward               | -0.2564473   |
# |    std                  | 0.953        |
# |    value_loss           | 0.163        |
# ------------------------------------------
# day: 585, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 159992.22
# total_reward: 59992.22
# total_cost: 0.00
# total_trades: 566
# Sharpe: 0.916
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2601          |
# |    iterations           | 35            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.004529167   |
# |    clip_fraction        | 0.0456        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.355         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0378        |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00309      |
# |    reward               | -8.987122e-05 |
# |    std                  | 0.957         |
# |    value_loss           | 0.162         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2599        |
# |    iterations           | 36          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006348207 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.102       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00264    |
# |    reward               | 0.07312783  |
# |    std                  | 0.949       |
# |    value_loss           | 0.187       |
# -----------------------------------------
# day: 585, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 136019.42
# total_reward: 36019.42
# total_cost: 0.00
# total_trades: 551
# Sharpe: 0.679
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2602        |
# |    iterations           | 37          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007691349 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0458      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00282    |
# |    reward               | 0.42307252  |
# |    std                  | 0.948       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2596         |
# |    iterations           | 38           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0063554887 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.38         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0512       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00281     |
# |    reward               | 0.0          |
# |    std                  | 0.948        |
# |    value_loss           | 0.139        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2598         |
# |    iterations           | 39           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0062370836 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.414        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.102        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00241     |
# |    reward               | 0.0          |
# |    std                  | 0.95         |
# |    value_loss           | 0.213        |
# ------------------------------------------
# day: 585, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 127119.81
# total_reward: 27119.81
# total_cost: 0.00
# total_trades: 572
# Sharpe: 0.526
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2600         |
# |    iterations           | 40           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0059904875 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.313        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0774       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00392     |
# |    reward               | 0.0          |
# |    std                  | 0.946        |
# |    value_loss           | 0.203        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2595        |
# |    iterations           | 41          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.00530724  |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0713      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00158    |
# |    reward               | -0.64587826 |
# |    std                  | 0.938       |
# |    value_loss           | 0.186       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2598         |
# |    iterations           | 42           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0046226596 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.107        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00164     |
# |    reward               | 0.0          |
# |    std                  | 0.948        |
# |    value_loss           | 0.231        |
# ------------------------------------------
# day: 585, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 135076.68
# total_reward: 35076.68
# total_cost: 0.00
# total_trades: 566
# Sharpe: 0.624
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2599         |
# |    iterations           | 43           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.011932282  |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0536       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00356     |
# |    reward               | -0.016899368 |
# |    std                  | 0.952        |
# |    value_loss           | 0.158        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2598         |
# |    iterations           | 44           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.005434188  |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0736       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00298     |
# |    reward               | -0.025179015 |
# |    std                  | 0.953        |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2599       |
# |    iterations           | 45         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00581318 |
# |    clip_fraction        | 0.0429     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0743     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00184   |
# |    reward               | 0.14200723 |
# |    std                  | 0.948      |
# |    value_loss           | 0.177      |
# ----------------------------------------
# day: 585, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 148052.35
# total_reward: 48052.35
# total_cost: 0.00
# total_trades: 576
# Sharpe: 0.777
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2595         |
# |    iterations           | 46           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0069157495 |
# |    clip_fraction        | 0.0809       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0388       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00575     |
# |    reward               | 0.0007630371 |
# |    std                  | 0.941        |
# |    value_loss           | 0.162        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2580        |
# |    iterations           | 47          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004591758 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0507      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00256    |
# |    reward               | -0.07440073 |
# |    std                  | 0.938       |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2578         |
# |    iterations           | 48           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.008881979  |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0638       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00166     |
# |    reward               | -0.029298896 |
# |    std                  | 0.926        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# day: 585, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 141366.29
# total_reward: 41366.29
# total_cost: 0.00
# total_trades: 571
# Sharpe: 0.713
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2577         |
# |    iterations           | 49           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0062790853 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0578       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000522    |
# |    reward               | -0.1464734   |
# |    std                  | 0.926        |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2580        |
# |    iterations           | 50          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007095569 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0706      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00344    |
# |    reward               | 0.21721739  |
# |    std                  | 0.914       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2582         |
# |    iterations           | 51           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0071028452 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0853       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00155     |
# |    reward               | 0.0          |
# |    std                  | 0.909        |
# |    value_loss           | 0.2          |
# ------------------------------------------
# day: 585, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 134623.09
# total_reward: 34623.09
# total_cost: 0.00
# total_trades: 573
# Sharpe: 0.641
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2584         |
# |    iterations           | 52           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0047603194 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0665       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00227     |
# |    reward               | 0.196966     |
# |    std                  | 0.915        |
# |    value_loss           | 0.172        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2586       |
# |    iterations           | 53         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.012671   |
# |    clip_fraction        | 0.0679     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.478      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0598     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00275   |
# |    reward               | 0.31343627 |
# |    std                  | 0.918      |
# |    value_loss           | 0.198      |
# ...
# | train/                  |             |
# |    approx_kl            | 0.010971891 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.066       |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.000318   |
# |    reward               | 0.2294051   |
# |    std                  | 0.944       |
# |    value_loss           | 0.119       |
# -----------------------------------------
# day: 585, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 171249.86
# total_reward: 71249.86
# total_cost: 0.00
# total_trades: 561
# Sharpe: 1.024
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2593        |
# |    iterations           | 180         |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.011016828 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0263      |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.000305    |
# |    reward               | 0.035634644 |
# |    std                  | 0.943       |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2593        |
# |    iterations           | 181         |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.007412711 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.035       |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00188     |
# |    reward               | -0.393841   |
# |    std                  | 0.941       |
# |    value_loss           | 0.0976      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2594        |
# |    iterations           | 182         |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.012905683 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0447      |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.00179     |
# |    reward               | 0.24330603  |
# |    std                  | 0.951       |
# |    value_loss           | 0.132       |
# -----------------------------------------
# day: 585, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 182256.82
# total_reward: 82256.82
# total_cost: 0.00
# total_trades: 543
# Sharpe: 1.190
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2594        |
# |    iterations           | 183         |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.014005341 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0283      |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00157    |
# |    reward               | -0.26955777 |
# |    std                  | 0.94        |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2594        |
# |    iterations           | 184         |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.008711444 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0509      |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.000371   |
# |    reward               | 0.03432593  |
# |    std                  | 0.942       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2594        |
# |    iterations           | 185         |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.012356985 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0406      |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00142    |
# |    reward               | -0.19165304 |
# |    std                  | 0.939       |
# |    value_loss           | 0.115       |
# -----------------------------------------
# day: 585, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 152173.75
# total_reward: 52173.75
# total_cost: 0.00
# total_trades: 538
# Sharpe: 0.838
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2593        |
# |    iterations           | 186         |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.012787069 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0603      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.004      |
# |    reward               | -0.08643302 |
# |    std                  | 0.941       |
# |    value_loss           | 0.124       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2590       |
# |    iterations           | 187        |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 382976     |
# | train/                  |            |
# |    approx_kl            | 0.0080384  |
# |    clip_fraction        | 0.069      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.748      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0481     |
# |    n_updates            | 1860       |
# |    policy_gradient_loss | -0.000121  |
# |    reward               | -0.2848798 |
# |    std                  | 0.937      |
# |    value_loss           | 0.106      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2588        |
# |    iterations           | 188         |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.015235877 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0517      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00127    |
# |    reward               | -0.23785618 |
# |    std                  | 0.941       |
# |    value_loss           | 0.11        |
# -----------------------------------------
# day: 585, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 168202.41
# total_reward: 68202.41
# total_cost: 0.00
# total_trades: 565
# Sharpe: 1.014
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2588        |
# |    iterations           | 189         |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.016398486 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0362      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00333    |
# |    reward               | -0.32911238 |
# |    std                  | 0.937       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2588         |
# |    iterations           | 190          |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 389120       |
# | train/                  |              |
# |    approx_kl            | 0.0102532245 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0213       |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.00061     |
# |    reward               | 0.006028995  |
# |    std                  | 0.937        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2588       |
# |    iterations           | 191        |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 391168     |
# | train/                  |            |
# |    approx_kl            | 0.01328312 |
# |    clip_fraction        | 0.0666     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0346     |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | 0.000723   |
# |    reward               | 0.15257902 |
# |    std                  | 0.933      |
# |    value_loss           | 0.0922     |
# ----------------------------------------
# day: 585, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 183224.48
# total_reward: 83224.48
# total_cost: 0.00
# total_trades: 556
# Sharpe: 1.168
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2589         |
# |    iterations           | 192          |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.011609606  |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0518       |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.00174      |
# |    reward               | -0.016263032 |
# |    std                  | 0.933        |
# |    value_loss           | 0.118        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2588        |
# |    iterations           | 193         |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.011898177 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0542      |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00154     |
# |    reward               | -0.38804907 |
# |    std                  | 0.936       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2588         |
# |    iterations           | 194          |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.008380108  |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0291       |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 0.000342     |
# |    reward               | -0.102719456 |
# |    std                  | 0.939        |
# |    value_loss           | 0.113        |
# ------------------------------------------
# day: 585, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 151854.13
# total_reward: 51854.13
# total_cost: 0.00
# total_trades: 540
# Sharpe: 0.890
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2588        |
# |    iterations           | 195         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.014286349 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0191      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00173    |
# |    reward               | -0.22587836 |
# |    std                  | 0.939       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2589        |
# |    iterations           | 196         |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.018159889 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0893      |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.000361   |
# |    reward               | 0.0         |
# |    std                  | 0.941       |
# |    value_loss           | 0.113       |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Preparation for backtest

# %%
# If necessary, we load the delayed data if we have restarted the process (not needed)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# If necessary, we load the delayed training data if we have restarted the process (not needed)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trading (data outside the training set)

# %% [markdown]
# Here we now use the trade dataset for trading, which has never been used for training. Additionally, with a similar approach, we could fine-tune the existing saved model.
#
# Numerous hyperparameters, such as the learning rate and the total number of training samples, affect the learning process and are usually determined by testing some variations.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# This section relates to the use of deep reinforcement learning (DRL) for simulating real-time trading using a previously trained model (in this case, A2C). StockTradingEnv is an environment that simulates the stock market based on historical data, a turbulence threshold (which is used to determine market volatility), and 'VIX' as a risk indicator. After initializing the environment, the get_sb_env() method is used to retrieve the environment and initial observations that are compatible with the Stable Baselines library.

# %%
# Initialization of the trading environment with the defined DataFrame 'trade', turbulence threshold, and risk indicator 'vix',
# along with other environment parameters ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Retrieving the environment compatible with Stable Baselines and initial observations.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# The DRL agent is then used to predict trading actions and changes in account value based on the trained model. This allows for the evaluation of the model's performance in an out-of-sample scenario, providing insight into how the model might perform in real trading conditions. If the use of the A2C algorithm is selected (as indicated by the variable if_using_a2c), predictions are made; otherwise, the result is set to None.

# %%
# Using the DRL agent for prediction using the trained model 'trained_a2c' and the defined trading environment 'e_trade_gym'.
# The results are two DataFrames: 'df_account_value_a2c' with account values and 'df_actions_a2c' with the actions taken,
# if 'if_using_a2c' is set to True; otherwise, it returns (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H for comparison

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['AAPL']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (145, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Backtesting models

# %%
# Setting the index of the account value DataFrames for each of the DRL strategies, if selected.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Creating an empty DataFrame for results.
result = pd.DataFrame()

# Merging the results of all DRL strategies into one DataFrame, if selected.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Merging the results of the mean variance optimization and the DJIA index with the main results.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Adding column names based on the selected strategies.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Displaying the results
result.head()
# Out:
#                       PPO            B&H
# date
# 2024-01-02  100000.000000  100000.000000
# 2024-01-03   99939.070984   99251.236230
# 2024-01-04   99733.930115   97990.744474
# 2024-01-05   99637.935242   97597.497251
# 2024-01-08  100405.899597   99956.906335

# %% [markdown]
# ### Here we plot a graph that shows the total portfolio value over time for each strategy and the benchmark

# %%
# Setting the figure size for the plots and drawing the performance charts of the trading strategies.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Based on the portfolio values, we calculate daily returns

# %%
from pyfolio import timeseries
import pandas as pd

# List of strategies for which you want to generate statistics
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Calculating daily returns from portfolio values
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_9794/728507394.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                       PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-01-02  100000.000000  100000.000000          NaN          NaN
# 2024-01-03   99939.070984   99251.236230    -0.000609    -0.007488
# 2024-01-04   99733.930115   97990.744474    -0.002053    -0.012700
# 2024-01-05   99637.935242   97597.497251    -0.000963    -0.004013
# 2024-01-08  100405.899597   99956.906335     0.007708     0.024175

# %% [markdown]
# ### Calculating returns for the selected strategy

# %%
# We assume that the result DataFrame already contains portfolio values for each strategy
for strategy in strategies:
    # Check if the strategy exists in the DataFrame
    if f'{strategy}_returns' in result.columns:
        # Extract daily returns for the current strategy
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Calculate performance statistics for the current strategy
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Print performance statistics
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategija {strategy} nije pronađena u rezultatima.\n")
# Out:
# Strategija A2C nije pronađena u rezultatima.
#
# Strategija DDPG nije pronađena u rezultatima.
#
# ==============Strategy Stats (PPO)==============
# Annual return          0.244817
# Cumulative returns     0.133303
# Annual volatility      0.171009
# Sharpe ratio           1.364992
# Calmar ratio           2.274378
# Stability              0.374526
# Max drawdown          -0.107641
# Omega ratio            1.324935
# Sortino ratio          2.484339
# Skew                   1.670595
# Kurtosis               7.676004
# Tail ratio             1.072351
# Daily value at risk   -0.020619
# dtype: float64
#
#
# Strategija TD3 nije pronađena u rezultatima.
#
# Strategija SAC nije pronađena u rezultatima.
#
# ==============Strategy Stats (B&H)==============
# Annual return          0.339390
# Cumulative returns     0.181730
# Annual volatility      0.242216
# Sharpe ratio           1.326098
# Calmar ratio           2.210321
# Stability              0.406826
# Max drawdown          -0.153548
# Omega ratio            1.260606
# Sortino ratio          2.238701
# Skew                   1.004166
# Kurtosis               3.931368
# Tail ratio             1.112326
# Daily value at risk   -0.029242
# dtype: float64

# %% [markdown]
# ### Plotting cumulative returns for each strategy

# %%
import matplotlib.pyplot as plt

# Setting the figure size for the plot
plt.figure(figsize=(14, 7))

# Iterating through each strategy and plotting its cumulative returns
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Extracting daily returns for the current strategy and converting to decimal format if necessary
        returns = result[f'{strategy}_returns'].dropna() + 1  # Adds 1 for using cumprod()

        # Calculating cumulative returns
        cumulative_returns = returns.cumprod() - 1  # Subtracts 1 at the end to show the true cumulative return

        # Plotting cumulative returns
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Adding title and legend to the plot
plt.title('Kumulativni povrati DRL strategija')
plt.legend()

# Adding labels to the plot
plt.xlabel('Datum')
plt.ylabel('Kumulativni povrati')

# Displaying the plot
plt.show()

# %% [markdown]
# ### Saving results to CSV
# Needs to be changed for each agent

# %%
import pickle

# For df_account_value_sac
with open('results/1. AAPL/aapl_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)
    
# For df_actions_td3
with open('results/1. AAPL/aapl_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# For buy_and_hold
with open('results/1. AAPL/aapl_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
