# %% [markdown]
# ## 1. Loading Required Packages

# %%
# Standard libraries
import sys
sys.path.append('../../')

import itertools

# Data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL and stable_baselines3 for machine learning and trading
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Configuration files and helper functions from FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Enabling chart display within Jupyter notebook
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_MSFT'
RESULTS_DIR = 'files/results_MSFT'
DATA_DIR = 'files/data_MSFT'

# Checking and creating directories
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Data Retrieval

# %% [markdown]
# We have a class called YahooDownloader that uses yfinance to fetch data from Yahoo Finance.
#
# In the YahooDownloader of FinRL, we modified the data frame into a format suitable for further data processing. We use a custom closing price instead of the regular closing price and add a column that represents the day of the week (0-4 corresponding to Monday-Friday).

# %%
# Training and trading intervals
TRAIN_START_DATE = '2022-04-01'
TRAIN_END_DATE = '2024-07-31'
TRADE_START_DATE = '2024-08-01'
TRADE_END_DATE = '2025-02-28'

# %%
# Fetching all data
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['MSFT']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (729, 8)

# %%
df_raw.head()
# Out:
#          date        open        high         low       close    volume   tic  \
# 0  2022-04-01  301.616882  309.420013  310.130005  309.369995  27110500  MSFT
# 1  2022-04-04  307.026886  314.970001  315.109985  310.089996  24289600  MSFT
# 2  2022-04-05  303.040070  310.880005  314.869995  313.269989  23156700  MSFT
# 3  2022-04-06  291.947021  299.500000  307.000000  305.190002  40110400  MSFT
# 4  2022-04-07  293.769928  301.369995  303.649994  296.660004  31411200  MSFT
#
#    day
# 0    4
# 1    0
# 2    1
# 3    2
# 4    3

# %% [markdown]
# ## 3. Data Processing

# %% [markdown]
# We use the defined class FeatureEngineer to process data and add technical indicators.
#
# The use_vix option includes the VIX index, known as the "fear index," which represents the expected volatility of the stock market based on S&P 500 options. The VIX helps the model understand market uncertainty, with higher values indicating greater uncertainty.
#
# The use_turbulence option includes the turbulence index, which measures unusual market fluctuations and serves as an indicator of risk and market shocks. It is useful for identifying periods of high volatility, helping the model to adapt to financial crises.
#
# Overall, a quite handy class that contains useful methods for processing financial data and can be applied to numerous other purposes.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (728, 8)
# Successfully added vix

# %%
# Creates a list of unique stock tickers from the 'tic' column of the 'processed' DataFrame.
list_ticker = processed["tic"].unique().tolist()

# Creates a list of dates between the earliest and latest dates in the 'processed' DataFrame, converting them to strings.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Creates combinations of all dates and stock tickers using the Cartesian product.
combination = list(itertools.product(list_date,list_ticker))

# Creates a new DataFrame 'processed_full' with columns "date" and "tic", containing all combinations of dates and stock tickers.
# Merges this DataFrame with the original 'processed' DataFrame based on the "date" and "tic" columns, using a 'left' join.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filters the 'processed_full' DataFrame to only include rows where the dates are present in the original 'processed' DataFrame.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sorts the 'processed_full' DataFrame by date and stock ticker.
processed_full = processed_full.sort_values(['date','tic'])

# Replaces all missing values (NaN) with 0 in the 'processed_full' DataFrame.
processed_full = processed_full.fillna(0)

# %%
processed_full.head(30)
# Out:
#           date   tic        open        high         low       close  \
# 0   2022-04-01  MSFT  301.616882  309.420013  310.130005  309.369995
# 3   2022-04-04  MSFT  307.026886  314.970001  315.109985  310.089996
# 4   2022-04-05  MSFT  303.040070  310.880005  314.869995  313.269989
# 5   2022-04-06  MSFT  291.947021  299.500000  307.000000  305.190002
# 6   2022-04-07  MSFT  293.769928  301.369995  303.649994  296.660004
# 7   2022-04-08  MSFT  289.480865  296.970001  301.119995  300.440002
# 10  2022-04-11  MSFT  278.066132  285.260010  292.609985  291.790009
# 11  2022-04-12  MSFT  274.946869  282.059998  290.739990  289.239990
# 12  2022-04-13  MSFT  280.366608  287.619995  288.579987  282.730011
# 13  2022-04-14  MSFT  272.773071  279.829987  288.309998  288.089996
# 17  2022-04-18  MSFT  273.445679  280.519989  282.459991  278.910004
# 18  2022-04-19  MSFT  278.105194  285.299988  286.170013  279.380005
# 19  2022-04-20  MSFT  279.138458  286.359985  289.700012  289.399994
# 20  2022-04-21  MSFT  273.728333  280.809998  293.299988  288.579987
# 21  2022-04-22  MSFT  267.119385  274.029999  283.200012  281.679993
# 24  2022-04-25  MSFT  273.640686  280.720001  281.109985  273.290009
# 25  2022-04-26  MSFT  263.405457  270.220001  278.359985  277.500000
# 26  2022-04-27  MSFT  276.077637  283.220001  290.970001  282.100006
# 27  2022-04-28  MSFT  282.325958  289.630005  290.980011  285.190002
# 28  2022-04-29  MSFT  270.521301  277.519989  289.880005  288.609985
# 31  2022-05-02  MSFT  277.296082  284.470001  284.940002  277.709991
# 32  2022-05-03  MSFT  274.673950  281.779999  284.130005  283.959991
# 33  2022-05-04  MSFT  282.667145  289.980011  290.880005  282.589996
# 34  2022-05-05  MSFT  270.355621  277.350006  286.350006  285.540009
# 35  2022-05-06  MSFT  267.801727  274.730011  279.250000  274.809998
# 38  2022-05-09  MSFT  257.907654  264.579987  272.359985  270.059998
# 39  2022-05-10  MSFT  262.703583  269.500000  273.750000  271.690002
# 40  2022-05-11  MSFT  253.979279  260.549988  271.359985  265.679993
# 41  2022-05-12  MSFT  248.910477  255.350006  259.880005  257.690002
# 42  2022-05-13  MSFT  254.534927  261.119995  263.040009  257.350006
#
#         volume  day      macd     boll_ub     boll_lb      rsi_30      cci_30  \
# 0   27110500.0  4.0  0.000000  310.748231  308.711760  100.000000   66.666667
# 3   24289600.0  0.0  0.016154  310.748231  308.711760  100.000000   66.666667
# 4   23156700.0  1.0  0.119195  315.060552  306.759435  100.000000   41.920397
# 5   40110400.0  2.0 -0.128586  316.128534  302.831458   31.680592 -126.214034
# 6   31411200.0  3.0 -0.599948  319.746977  294.085017   18.143475 -107.016473
# 7   24361900.0  4.0 -0.710388  318.472576  293.200754   31.551447  -89.269998
# 10  34569300.0  0.0 -1.160838  319.508104  288.151896   22.735607 -144.493872
# 11  30966700.0  1.0 -1.565492  319.814180  284.198317   20.950404 -126.098642
# 12  21907200.0  2.0 -2.144871  320.903119  278.825770   17.352135 -109.680613
# 13  28221600.0  3.0 -2.248573  319.874265  277.499734   27.899558  -96.403331
# 17  20778000.0  0.0 -2.781044  320.260850  273.517331   22.754560 -107.586056
# 18  22297700.0  1.0 -3.107772  319.899786  270.960215   23.501730  -78.758850
# 19  22906700.0  2.0 -2.742846  318.631759  271.300549   36.951447  -45.511698
# 20  29454600.0  3.0 -2.481594  317.501988  271.518009   36.409508  -48.995946
# 21  29405800.0  4.0 -2.662365  316.779715  270.529615   32.287513  -93.458644
# 24  35678900.0  0.0 -3.274920  316.933789  267.829959   28.262730  -94.511080
# 25  46518400.0  1.0 -3.440903  316.350632  266.662308   32.622524 -106.040546
# 26  63477700.0  2.0 -3.235749  315.490768  266.477008   36.953470  -40.562799
# 27  33646600.0  3.0 -2.840509  314.643262  266.714632   39.649184  -19.381745
# 28  37073900.0  4.0 -2.278672  313.918995  267.232003   42.465803  -41.130958
# 31  35151100.0  0.0 -2.538407  311.237710  266.747287   36.802749  -60.661864
# 32  25978600.0  1.0 -2.290023  307.668189  267.703808   41.435340  -52.859329
# 33  33599300.0  2.0 -2.163316  302.184750  270.119248   40.757856  -18.830249
# 34  43260400.0  3.0 -1.836567  298.464580  271.874419   42.839713  -54.676575
# 35  37780300.0  4.0 -2.306677  296.981690  271.172308   37.836686 -105.058174
# 38  47726000.0  0.0 -2.979129  294.466454  270.649543   35.915854 -155.006723
# 39  39336400.0  1.0 -3.352715  293.573039  269.532958   37.050312 -127.652155
# 40  48975900.0  2.0 -4.034677  293.763095  266.986902   34.706827 -161.276136
# 41  51033800.0  3.0 -5.095816  295.850587  262.395409   31.929325 -203.110917
# 42  34925100.0  4.0 -5.889758  296.367383  258.804614   31.817239 -168.628728
#
#          dx_30  close_30_sma  close_60_sma        vix
# 0   100.000000    309.369995    309.369995  20.620001
# 3   100.000000    309.729996    309.729996  20.750000
# 4    91.436533    310.909993    310.909993  18.790001
# 5    21.943103    309.479996    309.479996  21.270000
# 6    38.089303    306.915997    306.915997  21.969999
# 7    46.702491    305.836665    305.836665  21.250000
# 10   64.087552    303.830000    303.830000  23.090000
# 11   66.566593    302.006248    302.006248  24.940001
# 12   37.394624    299.864444    299.864444  23.520000
# 13   37.940608    298.687000    298.687000  21.719999
# 17   48.088299    296.889091    296.889091  24.520000
# 18   30.105762    295.430000    295.430000  22.549999
# 19   26.579663    294.966154    294.966154  21.129999
# 20   26.579663    294.509999    294.509999  20.240000
# 21   42.476342    293.654665    293.654665  22.709999
# 24   24.069316    292.381874    292.381874  30.040001
# 25   28.023538    291.506470    291.506470  27.379999
# 26    2.037624    290.983888    290.983888  31.110001
# 27    7.535654    290.678947    290.678947  29.910000
# 28    5.773925    290.575499    290.575499  28.969999
# 31   14.887592    289.962856    289.962856  33.349998
# 32   13.563307    289.689998    289.689998  31.760000
# 33   22.873640    289.381303    289.381303  29.120001
# 34   15.748564    289.221249    289.221249  25.969999
# 35    5.801256    288.644799    288.644799  32.230000
# 38    2.601591    287.929999    287.929999  31.900000
# 39    3.084308    287.328517    287.328517  33.660000
# 40    0.291340    286.555356    286.555356  32.869999
# 41   11.608661    285.559999    285.559999  33.740002
# 42    5.123223    284.619666    284.619666  31.090000

# %%
# Preparing the training and trade set according to the defined dates
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 584
# 143

# %%
# Saving the data
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Preparing the environment

# %% [markdown]
# stock_dimension represents the number of unique stocks in the dataset. This value is used to determine how many different stocks the model can trade.
#
# state_space denotes the total size of the state space that the model uses for decision-making. The state space includes current stock data (such as prices and technical indicators) and information about the current portfolio (such as the number of shares owned). The size of the state space is determined by a formula that takes into account the number of stocks and the number of technical indicators.

# %%
# Calculating the dimension (number of unique stocks) from the 'train' DataFrame.
stock_dimension = len(train.tic.unique())

# Calculating the state size based on the dimension and the number of technical indicators.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Creates lists of buy and sell costs for each stock.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Initializes the number of shares for each stock to 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym is an instance of the StockTradingEnv class, which represents the trading environment. This environment uses the data and parameters defined to simulate the stock market. The model learns how to trade within this environment, trying to maximize the total reward (profit) through a series of trading decisions.
#
# env_train is obtained by calling the get_sb_env() method on the e_train_gym instance. This method returns an environment compatible with the Stable Baselines 3 library, which is used for implementing reinforcement learning algorithms. The second return element, which is ignored here (_), can be used for additional information or functionalities provided by the environment.

# %%
# Define arguments for the trading environment.
env_kwargs = {
    "hmax": 1000,  # Maximum number of shares that can be bought or sold in a single transaction.
    "initial_amount": 100000,  # Initial amount of capital.
    "num_stock_shares": num_stock_shares,  # Initial number of shares for each stock in the portfolio, initially set to 0.
    "buy_cost_pct": buy_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "sell_cost_pct": sell_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "state_space": state_space,  # Previously defined sizes that affect the structure of the environment.
    "stock_dim": stock_dimension,  # Previously defined sizes that affect the structure of the environment.
    "tech_indicator_list": INDICATORS,  # List of technical indicators to be used for market state analysis.
    "action_space": stock_dimension,  # Size of the action space, i.e., the number of different actions the model can take.
    "reward_scaling": 1e-4  # Scaling factor for the reward, used to adjust the reward size to facilitate learning.
}

# Create the training environment.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Retrieve the environment suitable for Stable Baselines and an unused object.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Training DRL Agents

# %% [markdown]
# Here are the deep reinforcement learning (DRL) algorithms from the Stable Baselines 3 library. This is a library that has implemented popular DRL algorithms using PyTorch.
#
# As an alternative, the ElegantRL and Ray RLlib libraries can be used.

# %% [markdown]
# ### Training 5 different DRL agents (A2C, DDPG, PPO, TD3, SAC)

# %%
# Setting the appropriate values to 'True' for the algorithms you want to use
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# A new instance of the DRL agent is created with the given environment (it is not necessary to do this again, but for easier instructions, it remains)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Setting up the logger to monitor and record information during training
  tmp_path = RESULTS_DIR + '/a2c'
  # Configures a new logger that will print information to standard output, log to a CSV file, and TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Sets the new logger for the A2C model.
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Train the A2C model with the defined total number of time steps, only if if_using_a2c is set to True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Save the trained A2C model to the defined directory, only if if_using_a2c is set to True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_MSFT/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -------------------------------------
# | time/              |              |
# |    fps             | 3602         |
# |    iterations      | 1            |
# |    time_elapsed    | 0            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.106351785 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2854         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0055601727 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -3.72        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0422       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00696     |
# |    reward               | 0.0          |
# |    std                  | 1.02         |
# |    value_loss           | 0.148        |
# ------------------------------------------
# day: 583, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 102398.61
# total_reward: 2398.61
# total_cost: 0.00
# total_trades: 471
# Sharpe: 0.148
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2743         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0018534621 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0295      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0215       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | -0.4011343   |
# |    std                  | 1.02         |
# |    value_loss           | 0.0899       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2641        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.002686638 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.0259     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0223      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00355    |
# |    reward               | 0.0         |
# |    std                  | 1.02        |
# |    value_loss           | 0.115       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2598         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041438127 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0262      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0193       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00378     |
# |    reward               | 0.07508821   |
# |    std                  | 1.02         |
# |    value_loss           | 0.0978       |
# ------------------------------------------
# day: 583, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 101743.86
# total_reward: 1743.86
# total_cost: 0.00
# total_trades: 522
# Sharpe: 0.143
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2571         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0027680406 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0118      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0278       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00209     |
# |    reward               | -0.21138121  |
# |    std                  | 1.03         |
# |    value_loss           | 0.108        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2501         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0038541504 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.0039      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0463       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00496     |
# |    reward               | 0.0          |
# |    std                  | 1.03         |
# |    value_loss           | 0.127        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2455         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0031969626 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0511       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00502     |
# |    reward               | -0.12191143  |
# |    std                  | 1.03         |
# |    value_loss           | 0.137        |
# ------------------------------------------
# day: 583, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 133733.05
# total_reward: 33733.05
# total_cost: 0.00
# total_trades: 513
# Sharpe: 0.681
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2451         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0021608677 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.039       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0255       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00247     |
# |    reward               | 0.02847553   |
# |    std                  | 1.03         |
# |    value_loss           | 0.0858       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2450         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026690117 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0225       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0447       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00222     |
# |    reward               | 0.12716962   |
# |    std                  | 1.03         |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2447       |
# |    iterations           | 11         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00444278 |
# |    clip_fraction        | 0.0335     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | -0.0328    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0524     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00494   |
# |    reward               | 0.25578022 |
# |    std                  | 1.03       |
# |    value_loss           | 0.12       |
# ----------------------------------------
# day: 583, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 168147.01
# total_reward: 68147.01
# total_cost: 0.00
# total_trades: 555
# Sharpe: 1.124
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2440        |
# |    iterations           | 12          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004181914 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.00262     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0741      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00375    |
# |    reward               | 0.0         |
# |    std                  | 1.03        |
# |    value_loss           | 0.171       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2439         |
# |    iterations           | 13           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036505787 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0285      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0404       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00447     |
# |    reward               | -0.060060333 |
# |    std                  | 1.02         |
# |    value_loss           | 0.147        |
# ------------------------------------------
# day: 583, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 119305.37
# total_reward: 19305.37
# total_cost: 0.00
# total_trades: 547
# Sharpe: 0.456
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2441         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0032787803 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.00919      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0509       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00428     |
# |    reward               | 0.12659228   |
# |    std                  | 1.02         |
# |    value_loss           | 0.127        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2414        |
# |    iterations           | 15          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003234867 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0428      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0395      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00244    |
# |    reward               | 0.11396807  |
# |    std                  | 1.02        |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2419         |
# |    iterations           | 16           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0031367454 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.00596      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0513       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0034      |
# |    reward               | 0.2018939    |
# |    std                  | 1.03         |
# |    value_loss           | 0.14         |
# ------------------------------------------
# day: 583, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 148001.01
# total_reward: 48001.01
# total_cost: 0.00
# total_trades: 547
# Sharpe: 0.833
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2410         |
# |    iterations           | 17           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044947304 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0743       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0691       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00652     |
# |    reward               | -0.037080377 |
# |    std                  | 1.02         |
# |    value_loss           | 0.168        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2418         |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0043408433 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0176       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0773       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00454     |
# |    reward               | 0.12291496   |
# |    std                  | 1.02         |
# |    value_loss           | 0.147        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2414         |
# |    iterations           | 19           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0035398426 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0599       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00309     |
# |    reward               | 0.11355987   |
# |    std                  | 1.02         |
# |    value_loss           | 0.143        |
# ------------------------------------------
# day: 583, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 168572.37
# total_reward: 68572.37
# total_cost: 0.00
# total_trades: 563
# Sharpe: 1.082
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2413         |
# |    iterations           | 20           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0037613472 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0987       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0491       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00474     |
# |    reward               | 0.10307996   |
# |    std                  | 1.03         |
# |    value_loss           | 0.133        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2412        |
# |    iterations           | 21          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003548459 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0333      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0689      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00318    |
# |    reward               | 0.0         |
# |    std                  | 1.03        |
# |    value_loss           | 0.177       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2415         |
# |    iterations           | 22           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0055986256 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0614       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00428     |
# |    reward               | -0.13715017  |
# |    std                  | 1.02         |
# |    value_loss           | 0.168        |
# ------------------------------------------
# day: 583, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 181853.60
# total_reward: 81853.60
# total_cost: 0.00
# total_trades: 567
# Sharpe: 1.214
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2425        |
# |    iterations           | 23          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004833976 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | -0.0212     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0431      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00357    |
# |    reward               | 0.0         |
# |    std                  | 1.03        |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2432        |
# |    iterations           | 24          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005018524 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0173      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0407      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00428    |
# |    reward               | -0.0451503  |
# |    std                  | 1.04        |
# |    value_loss           | 0.182       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2438         |
# |    iterations           | 25           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0051446045 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0833       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0554       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00426     |
# |    reward               | 0.0          |
# |    std                  | 1.04         |
# |    value_loss           | 0.205        |
# ------------------------------------------
# day: 583, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 104204.25
# total_reward: 4204.25
# total_cost: 0.00
# total_trades: 564
# Sharpe: 0.193
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2443         |
# |    iterations           | 26           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.00451316   |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0801       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0831       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00522     |
# |    reward               | -0.038911965 |
# |    std                  | 1.04         |
# |    value_loss           | 0.201        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2441        |
# |    iterations           | 27          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003403985 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0899      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00319    |
# |    reward               | 0.08604053  |
# |    std                  | 1.04        |
# |    value_loss           | 0.182       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2445         |
# |    iterations           | 28           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0029858164 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0429       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00222     |
# |    reward               | 0.0          |
# |    std                  | 1.03         |
# |    value_loss           | 0.152        |
# ------------------------------------------
# day: 583, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 127759.47
# total_reward: 27759.47
# total_cost: 0.00
# total_trades: 554
# Sharpe: 0.572
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2450        |
# |    iterations           | 29          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005136774 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0888      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0368      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00611    |
# |    reward               | 0.010286582 |
# |    std                  | 1.03        |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2456        |
# |    iterations           | 30          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004575175 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0712      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.063       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00372    |
# |    reward               | 0.020206979 |
# |    std                  | 1.02        |
# |    value_loss           | 0.171       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2462        |
# |    iterations           | 31          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007538673 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0637      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00417    |
# |    reward               | 0.065940306 |
# |    std                  | 1.02        |
# |    value_loss           | 0.145       |
# -----------------------------------------
# day: 583, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 157249.05
# total_reward: 57249.05
# total_cost: 0.00
# total_trades: 564
# Sharpe: 0.936
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2467         |
# |    iterations           | 32           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0040900125 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00333     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0895       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00273     |
# |    reward               | 0.033030335  |
# |    std                  | 1.02         |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2467         |
# |    iterations           | 33           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0055882977 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.0794       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0702       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00525     |
# |    reward               | 0.03094304   |
# |    std                  | 1.02         |
# |    value_loss           | 0.198        |
# ------------------------------------------
# day: 583, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 119906.88
# total_reward: 19906.88
# total_cost: 0.00
# total_trades: 561
# Sharpe: 0.458
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2467         |
# |    iterations           | 34           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0053624036 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0499       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0057      |
# |    reward               | 0.007700386  |
# |    std                  | 1.03         |
# |    value_loss           | 0.185        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2471         |
# |    iterations           | 35           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0051155146 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.029       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0548       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00343     |
# |    reward               | 0.0723062    |
# |    std                  | 1.03         |
# |    value_loss           | 0.135        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2470         |
# |    iterations           | 36           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0077379523 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.142        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0799       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00645     |
# |    reward               | -0.003809143 |
# |    std                  | 1.02         |
# |    value_loss           | 0.169        |
# ------------------------------------------
# day: 583, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 114748.97
# total_reward: 14748.97
# total_cost: 0.00
# total_trades: 539
# Sharpe: 0.375
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2473         |
# |    iterations           | 37           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0065200077 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0632       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00382     |
# |    reward               | -0.13482933  |
# |    std                  | 1.01         |
# |    value_loss           | 0.17         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2476        |
# |    iterations           | 38          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008588713 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0294      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00731    |
# |    reward               | 0.25900567  |
# |    std                  | 1.02        |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2478        |
# |    iterations           | 39          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006286592 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0687      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00382    |
# |    reward               | 0.20996934  |
# |    std                  | 1.01        |
# |    value_loss           | 0.146       |
# -----------------------------------------
# day: 583, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 175369.06
# total_reward: 75369.06
# total_cost: 0.00
# total_trades: 554
# Sharpe: 1.147
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2480         |
# |    iterations           | 40           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0061898255 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0469       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00301     |
# |    reward               | 0.20685284   |
# |    std                  | 1.01         |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2484         |
# |    iterations           | 41           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0061989515 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0561       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00479     |
# |    reward               | 0.001584613  |
# |    std                  | 1.01         |
# |    value_loss           | 0.166        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2487        |
# |    iterations           | 42          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005883379 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.09        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0427      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00307    |
# |    reward               | 0.4402296   |
# |    std                  | 1.02        |
# |    value_loss           | 0.142       |
# -----------------------------------------
# day: 583, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 149243.27
# total_reward: 49243.27
# total_cost: 0.00
# total_trades: 554
# Sharpe: 0.880
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2489       |
# |    iterations           | 43         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00613873 |
# |    clip_fraction        | 0.0372     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.0773     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0831     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00275   |
# |    reward               | 0.04960792 |
# |    std                  | 1.02       |
# |    value_loss           | 0.193      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2490        |
# |    iterations           | 44          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007823794 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.0414      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0504      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0075     |
# |    reward               | 0.58953625  |
# |    std                  | 1.02        |
# |    value_loss           | 0.155       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2493         |
# |    iterations           | 45           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0039726207 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0819       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00411     |
# |    reward               | -0.22656006  |
# |    std                  | 1.03         |
# |    value_loss           | 0.157        |
# ------------------------------------------
# day: 583, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 131884.76
# total_reward: 31884.76
# total_cost: 0.00
# total_trades: 558
# Sharpe: 0.641
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2495        |
# |    iterations           | 46          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006663601 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.0745      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0596      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00507    |
# |    reward               | -0.16170982 |
# |    std                  | 1.03        |
# |    value_loss           | 0.187       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2496         |
# |    iterations           | 47           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0054688184 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.081        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0965       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0047      |
# |    reward               | 0.08994512   |
# |    std                  | 1.03         |
# |    value_loss           | 0.231        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2499         |
# |    iterations           | 48           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0050713206 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.081        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0402       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00573     |
# |    reward               | -0.12851991  |
# |    std                  | 1.03         |
# |    value_loss           | 0.127        |
# ------------------------------------------
# day: 583, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 119104.52
# total_reward: 19104.52
# total_cost: 0.00
# total_trades: 565
# Sharpe: 0.435
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2502        |
# |    iterations           | 49          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008076399 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0598      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00292    |
# |    reward               | 0.35527238  |
# |    std                  | 1.03        |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2504         |
# |    iterations           | 50           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0034580857 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0517       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00427     |
# |    reward               | 0.0          |
# |    std                  | 1.03         |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2505         |
# |    iterations           | 51           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0047850665 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.087        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0983       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00377     |
# |    reward               | -0.17394085  |
# |    std                  | 1.02         |
# |    value_loss           | 0.199        |
# ------------------------------------------
# day: 583, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 160741.92
# total_reward: 60741.92
# total_cost: 0.00
# total_trades: 568
# Sharpe: 0.966
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2507         |
# |    iterations           | 52           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0068909824 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0764       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00508     |
# |    reward               | -0.031269927 |
# |    std                  | 1.02         |
# |    value_loss           | 0.189        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2508         |
# |    iterations           | 53           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0044322163 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0737       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00444     |
# |    reward               | -0.16483736  |
# |    std                  | 1.02         |
# |    value_loss           | 0.179        |
# ------------------------------------------
# ...
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0728      |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00151    |
# |    reward               | 0.036278047 |
# |    std                  | 0.939       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# day: 583, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 196112.94
# total_reward: 96112.94
# total_cost: 0.00
# total_trades: 582
# Sharpe: 1.318
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2440       |
# |    iterations           | 180        |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.01609372 |
# |    clip_fraction        | 0.0949     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.53       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.071      |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | -0.00216   |
# |    reward               | 0.0        |
# |    std                  | 0.94       |
# |    value_loss           | 0.182      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2441         |
# |    iterations           | 181          |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0141336005 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.42         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.13         |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00175     |
# |    reward               | 0.1418044    |
# |    std                  | 0.936        |
# |    value_loss           | 0.218        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2442          |
# |    iterations           | 182           |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 372736        |
# | train/                  |               |
# |    approx_kl            | 0.016476844   |
# |    clip_fraction        | 0.0831        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.487         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.09          |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | -0.00228      |
# |    reward               | -0.0008710327 |
# |    std                  | 0.939         |
# |    value_loss           | 0.18          |
# -------------------------------------------
# day: 583, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 184993.29
# total_reward: 84993.29
# total_cost: 0.00
# total_trades: 577
# Sharpe: 1.198
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2442       |
# |    iterations           | 183        |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 374784     |
# | train/                  |            |
# |    approx_kl            | 0.01064926 |
# |    clip_fraction        | 0.0862     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0642     |
# |    n_updates            | 1820       |
# |    policy_gradient_loss | 0.000616   |
# |    reward               | -0.1784791 |
# |    std                  | 0.938      |
# |    value_loss           | 0.176      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2443        |
# |    iterations           | 184         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.015594393 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0654      |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00153     |
# |    reward               | 0.26907066  |
# |    std                  | 0.934       |
# |    value_loss           | 0.183       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2443         |
# |    iterations           | 185          |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0133679975 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0922       |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000845    |
# |    reward               | 0.26797643   |
# |    std                  | 0.931        |
# |    value_loss           | 0.202        |
# ------------------------------------------
# day: 583, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 141366.65
# total_reward: 41366.65
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.728
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2444        |
# |    iterations           | 186         |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.012531947 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0764      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00503    |
# |    reward               | 0.24925481  |
# |    std                  | 0.926       |
# |    value_loss           | 0.197       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2444         |
# |    iterations           | 187          |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.012055959  |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0483       |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00329     |
# |    reward               | 0.0016395996 |
# |    std                  | 0.927        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# day: 583, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 158067.37
# total_reward: 58067.37
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.934
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2445         |
# |    iterations           | 188          |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0052553276 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.289        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0899       |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00161     |
# |    reward               | 0.47613958   |
# |    std                  | 0.924        |
# |    value_loss           | 0.199        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2446        |
# |    iterations           | 189         |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.010053309 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.101       |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00349    |
# |    reward               | 0.05662791  |
# |    std                  | 0.924       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2447        |
# |    iterations           | 190         |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.009197773 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0552      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00136    |
# |    reward               | 0.5368482   |
# |    std                  | 0.919       |
# |    value_loss           | 0.188       |
# -----------------------------------------
# day: 583, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 178727.17
# total_reward: 78727.17
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.120
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2448        |
# |    iterations           | 191         |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.018518526 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0928      |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00244    |
# |    reward               | -0.20343205 |
# |    std                  | 0.926       |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2449        |
# |    iterations           | 192         |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.014798798 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0958      |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.000498   |
# |    reward               | 0.0         |
# |    std                  | 0.922       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2449        |
# |    iterations           | 193         |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.015607266 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0893      |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.000343    |
# |    reward               | 0.11124791  |
# |    std                  | 0.92        |
# |    value_loss           | 0.205       |
# -----------------------------------------
# day: 583, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 197252.76
# total_reward: 97252.76
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.306
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2450        |
# |    iterations           | 194         |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.013525578 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0395      |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.00425     |
# |    reward               | -0.16001989 |
# |    std                  | 0.917       |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2450        |
# |    iterations           | 195         |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.015401252 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0706      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00107    |
# |    reward               | 0.41291243  |
# |    std                  | 0.924       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2451        |
# |    iterations           | 196         |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014649836 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0651      |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00288    |
# |    reward               | -0.2726503  |
# |    std                  | 0.929       |
# |    value_loss           | 0.206       |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Preparation for backtest

# %%
# If necessary, we load the delayed data if we have restarted the process (not needed)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# If necessary, we load the delayed training data if we have restarted the process (not needed)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trading (data outside the training set)

# %% [markdown]
# Here we now use the trade dataset for trading, which has never been used for training. Additionally, with a similar approach, we could fine-tune the existing saved model.
#
# Numerous hyperparameters, such as the learning rate and the total number of training samples, affect the learning process and are usually determined by testing some variations.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# This section relates to the use of deep reinforcement learning (DRL) for simulating real-time trading using a previously trained model (in this case, A2C). StockTradingEnv is an environment that simulates the stock market based on historical data, a turbulence threshold (which is used to determine market volatility), and 'VIX' as a risk indicator. After initializing the environment, the get_sb_env() method is used to retrieve the environment and initial observations that are compatible with the Stable Baselines library.

# %%
# Initialization of the trading environment with the defined DataFrame 'trade', turbulence threshold, and risk indicator 'vix',
# along with other environment parameters ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Retrieving the environment compatible with Stable Baselines and initial observations.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# The DRL agent is then used to predict trading actions and changes in account value based on the trained model. This allows for the evaluation of the model's performance in an out-of-sample scenario, providing insight into how the model might perform in real trading conditions. If the use of the A2C algorithm is selected (as indicated by the variable if_using_a2c), predictions are made; otherwise, the result is set to None.

# %%
# Using the DRL agent for prediction using the trained model 'trained_a2c' and the defined trading environment 'e_trade_gym'.
# The results are two DataFrames: 'df_account_value_a2c' with account values and 'df_actions_a2c' with the actions taken,
# if 'if_using_a2c' is set to True; otherwise, it returns (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H for comparison

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['MSFT']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (144, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Backtesting models

# %%
# Setting the index of the account value DataFrames for each of the DRL strategies, if selected.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Creating an empty DataFrame for results.
result = pd.DataFrame()

# Merging the results of all DRL strategies into one DataFrame, if selected.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Merging the results of the mean variance optimization and the DJIA index with the main results.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Adding column names based on the selected strategies.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Displaying the results
result.head()
# Out:
#                      PPO            B&H
# date
# 2024-08-01  100000.00000  100000.000000
# 2024-08-02   98032.89566   98027.515354
# 2024-08-05   98032.89566   92485.564183
# 2024-08-06  100751.22229   95059.291304
# 2024-08-07  100751.22229   97112.575477

# %% [markdown]
# ### Here we plot a graph that shows the total portfolio value over time for each strategy and the benchmark

# %%
# Setting the figure size for the plots and drawing the performance charts of the trading strategies.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Based on the portfolio values, we calculate daily returns

# %%
from pyfolio import timeseries
import pandas as pd

# List of strategies for which you want to generate statistics
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Calculating daily returns from portfolio values
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_97364/597744444.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                      PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-08-01  100000.00000  100000.000000          NaN          NaN
# 2024-08-02   98032.89566   98027.515354    -0.019671    -0.019725
# 2024-08-05   98032.89566   92485.564183     0.000000    -0.056535
# 2024-08-06  100751.22229   95059.291304     0.027729     0.027828
# 2024-08-07  100751.22229   97112.575477     0.000000     0.021600

# %% [markdown]
# ### Calculating returns for the selected strategy

# %%
# We assume that the result DataFrame already contains portfolio values for each strategy
for strategy in strategies:
    # Check if the strategy exists in the DataFrame
    if f'{strategy}_returns' in result.columns:
        # Extract daily returns for the current strategy
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Calculate performance statistics for the current strategy
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Print performance statistics
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategy {strategy} was not found in the results.\n")
# Out:
# Strategy A2C was not found in the results.
#
# Strategy DDPG was not found in the results.
#
# ==============Strategy Stats (PPO)==============
# Annual return          0.004388
# Cumulative returns     0.002488
# Annual volatility      0.210380
# Sharpe ratio           0.126448
# Calmar ratio           0.046256
# Stability              0.137805
# Max drawdown          -0.094866
# Omega ratio            1.024507
# Sortino ratio          0.162845
# Skew                  -1.223267
# Kurtosis               4.587630
# Tail ratio             1.086830
# Daily value at risk   -0.026400
# dtype: float64
#
#
# Strategy TD3 was not found in the results.
#
# Strategy SAC was not found in the results.
#
# ==============Strategy Stats (B&H)==============
# Annual return         -0.080298
# Cumulative returns    -0.046389
# Annual volatility      0.236638
# Sharpe ratio          -0.234674
# Calmar ratio          -0.679797
# Stability              0.024638
# Max drawdown          -0.118120
# Omega ratio            0.959957
# Sortino ratio         -0.294803
# Skew                  -1.201677
# Kurtosis               3.320010
# Tail ratio             1.027307
# Daily value at risk   -0.030034
# dtype: float64

# %% [markdown]
# ### Plotting cumulative returns for each strategy

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Setting the figure size for the plot
plt.figure(figsize=(12, 6))

# Iterating through each strategy and plotting its cumulative returns
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Make sure dates are properly parsed
        result.index = pd.to_datetime(result.index)
        
        # Extracting daily returns for the current strategy and converting to decimal format if necessary
        returns = result[f'{strategy}_returns'].dropna() + 1  # Adds 1 for using cumprod()
        
        # Calculating cumulative returns and converting to percentage
        cumulative_returns = (returns.cumprod() - 1) * 100  # Convert to percentage
        
        # Plotting cumulative returns with original colors
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Format y-axis as percentages
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.ylabel('Cumulative Returns (%)')
plt.xlabel('Date')

# Format x-axis dates
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# Make sure dates are in the correct format and rotated
plt.gcf().autofmt_xdate()

# Adding title and legend
#plt.title('Cumulative Returns of DRL Strategies')
plt.legend(loc='upper right')

# Add grid with light gray color
plt.grid(True, linestyle='-', alpha=0.2)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# ### Saving results to CSV
# Needs to be changed for each agent

# %%
import pickle

# For df_account_value_ppo
with open('results/3. MSFT/msft_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)
    
# For df_actions_ppo
with open('results/3. MSFT/msft_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# For buy_and_hold
with open('results/3. MSFT/msft_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
