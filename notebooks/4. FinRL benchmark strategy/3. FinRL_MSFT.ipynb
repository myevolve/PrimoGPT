# %% [markdown]
# ## 1. Učitavanje potrebnih paketa

# %%
# Standardne biblioteke
import sys
sys.path.append('../../')

import itertools

# Analiza podataka
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL i stable_baselines3 za strojno učenje i trgovanje
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Konfiguracijski fajlovi i pomoćne funkcije iz FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Omogućavanje prikaza grafikona unutar Jupyter bilježnice
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_MSFT'
RESULTS_DIR = 'files/results_MSFT'
DATA_DIR = 'files/data_MSFT'

# Provjera i kreiranje direktorija
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Dohvaćanje podataka

# %% [markdown]
# Imamo klasu nazvanu YahooDownloader koja koristi yfinance za dohvaćanje podataka s Yahoo Finance.
#
# U YahooDownloader-u FinRL-a, modificirali smo okvir podataka u oblik koji je pogodan za daljnju obradu podataka. Koristimo prilagođenu zatvarajuću cijenu umjesto zatvarajuće cijene i dodajemo stupac koji predstavlja dan u tjednu (0-4 što odgovara ponedjeljku-petku).

# %%
# Intervali za trening i trgovanje
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2023-12-31'
TRADE_START_DATE = '2024-01-01'
TRADE_END_DATE = '2024-07-31'

# %%
# Preuzimamo sve podatke
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['MSFT']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (731, 8)

# %%
df_raw.head()
# Out:
#          date        open        high         low       close    volume   tic  \
# 0  2021-09-01  302.869995  305.190002  301.489990  294.780792  18983800  MSFT
# 1  2021-09-02  302.200012  303.359985  300.179993  294.116730  16285600  MSFT
# 2  2021-09-03  300.989990  302.600006  300.260010  294.106934  14747900  MSFT
# 3  2021-09-07  301.010010  301.089996  298.200012  293.169281  17180400  MSFT
# 4  2021-09-08  299.779999  300.609985  297.470001  293.198608  15046800  MSFT
#
#    day
# 0    2
# 1    3
# 2    4
# 3    1
# 4    2

# %% [markdown]
# ## 3. Procesiranje podataka

# %% [markdown]
# Koristimo definiranu klasu FeatureEngineer pomoću koje radimo procesiranje podataka i dodavanje tehničkih indikatora.
#
# Opcija use_vix uključuje VIX indeks, poznat kao "indeks straha", koji predstavlja očekivanu volatilnost tržišta dionica temeljenu na opcijama S&P 500 indeksa. VIX pomaže modelu da razumije tržišnu nesigurnost, s višim vrijednostima koje ukazuju na veću nesigurnost.
#
# Opcija use_turbulence uključuje indeks turbulencije, koji mjeri neobične tržišne fluktuacije i služi kao pokazatelj rizika i tržišnih šokova. Koristan je za identifikaciju perioda visoke volatilnosti, pomažući modelu da se prilagodi financijskim krizama.
#
# Inače dosta zgodna klasa koja sadrži korisne metode za obradu financijskih podataka i može se primjeniti u brojne druge svrhe.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (730, 8)
# Successfully added vix

# %%
# Stvara listu jedinstvenih oznaka dionica (tickers) iz stupca 'tic' DataFrame-a 'processed'.
list_ticker = processed["tic"].unique().tolist()

# Stvara listu datuma između najranijeg i najkasnijeg datuma u DataFrame-u 'processed', pretvara ih u stringove.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Stvara kombinacije svih datuma i oznaka dionica koristeći kartezijev produkt.
combination = list(itertools.product(list_date,list_ticker))

# Stvara novi DataFrame 'processed_full' s kolonama "date" i "tic", koji sadrži sve kombinacije datuma i oznaka dionica.
# Spaja taj DataFrame s originalnim DataFrame-om 'processed' na temelju kolona "date" i "tic", koristeći 'left' spajanje.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filtrira 'processed_full' DataFrame da sadrži samo one retke čiji su datumi prisutni u originalnom DataFrame-u 'processed'.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sortira 'processed_full' DataFrame po datumu i oznaci dionica.
processed_full = processed_full.sort_values(['date','tic'])

# Zamjenjuje sve nedostajuće vrijednosti (NaN) s 0 u DataFrame-u 'processed_full'.
processed_full = processed_full.fillna(0)

# %%
processed_full.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2021-09-01  MSFT  302.869995  305.190002  301.489990  294.780792
# 1  2021-09-02  MSFT  302.200012  303.359985  300.179993  294.116730
# 2  2021-09-03  MSFT  300.989990  302.600006  300.260010  294.106934
# 6  2021-09-07  MSFT  301.010010  301.089996  298.200012  293.169281
# 7  2021-09-08  MSFT  299.779999  300.609985  297.470001  293.198608
#
#        volume  day      macd     boll_ub     boll_lb    rsi_30      cci_30  \
# 0  18983800.0  2.0  0.000000  295.387887  293.509635  0.000000  -66.666667
# 1  16285600.0  3.0 -0.014899  295.387887  293.509635  0.000000  -66.666667
# 2  14747900.0  4.0 -0.019288  295.107330  293.562307  0.000000  -62.468647
# 6  17180400.0  1.0 -0.054665  295.368699  292.718169  0.000000 -128.683547
# 7  15046800.0  2.0 -0.071571  295.248598  292.500340  1.898552  -95.345378
#
#    dx_30  close_30_sma  close_60_sma        vix
# 0  100.0    294.780792    294.780792  16.110001
# 1  100.0    294.448761    294.448761  16.410000
# 2  100.0    294.334819    294.334819  16.410000
# 6  100.0    294.043434    294.043434  18.139999
# 7  100.0    293.874469    293.874469  17.959999

# %%
# Pripremamo trening i trade set sukladno definiranim datumima
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 586
# 144

# %%
# Spremamo podatke
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Priprema environmenta

# %% [markdown]
# stock_dimension predstavlja broj jedinstvenih dionica u skupu podataka. Ova vrijednost se koristi za određivanje koliko različitih dionica model može trgovati.
#
# state_space označava ukupnu veličinu prostora stanja koji model koristi za donošenje odluka. Prostor stanja uključuje trenutne podatke o dionicama (kao što su cijene i tehnički indikatori) i informacije o trenutnom portfelju (kao što su broj dionica koje posjeduje). Veličina prostora stanja određena je formulom koja uzima u obzir broj dionica i broj tehničkih indikatora.

# %%
# Izračunavamo dimenziju (broj jedinstvenih dionica) iz DataFrame-a 'train'.
stock_dimension = len(train.tic.unique())

# Izračunavamo veličinu stanja na temelju dimenzije i broja tehničkih indikatora.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Stvara liste troškova kupnje i prodaje za svaku dionicu.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Inicijalizira broj dionica za svaku dionicu na 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym je instanca klase StockTradingEnv, koja predstavlja okruženje za trgovanje. Ovo okruženje koristi podatke i parametre definirane za simulaciju tržišta dionica. Model uči kako trgovati unutar ovog okruženja, pokušavajući maksimizirati ukupnu nagradu (profit) kroz seriju trgovačkih odluka.
#
# env_train dobiva se pozivom metode get_sb_env() na instanci e_train_gym. Ova metoda vraća okruženje kompatibilno s bibliotekom Stable Baselines 3, koja se koristi za implementaciju algoritama pojačanog učenja. Drugi povratni element, koji se ovdje ignorira (_), može se koristiti za dodatne informacije ili funkcionalnosti koje pruža okruženje.

# %%
# Definira argumente za okruženje trgovanja.
env_kwargs = {
    "hmax": 1000,  # Maksimalni broj dionica koje se mogu kupiti ili prodati u jednoj transakciji.
    "initial_amount": 100000,  # Početni iznos kapitala.
    "num_stock_shares": num_stock_shares,  # Početni broj dionica svake dionice u portfelju, inicijalno postavljen na 0.
    "buy_cost_pct": buy_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "sell_cost_pct": sell_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "state_space": state_space,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "stock_dim": stock_dimension,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "tech_indicator_list": INDICATORS,  # Lista tehničkih indikatora koji će se koristiti za analizu stanja tržišta.
    "action_space": stock_dimension,  # Veličina prostora akcija, odnosno, broj različitih akcija koje model može izvršiti.
    "reward_scaling": 1e-4  # Faktor skaliranja za nagradu, koristi se za prilagodbu veličine nagrade kako bi se olakšalo učenje.
}

# Kreira okruženje za treniranje.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Dohvaća okruženje pogodno za Stable Baselines i neiskorišteni objekt.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Trening DRL agenata

# %% [markdown]
# Ovdje su algoritmi dubokog pojačanog učenja (DRL) iz biblioteke Stable Baselines 3. Radi se o biblioteci koja je implementirala popularne DRL algoritme koristeći PyTorch.
#
# Kao zamjena mogu se koristiti biblioteke ElegantRL i Ray RLlib.

# %% [markdown]
# ### Trening 5 različitih DRL agenata (A2C, DDPG, PPO, TD3, SAC)

# %%
# Postavljanje odgovarajućih vrijednosti na 'True' za algoritme koje želite koristiti
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# Ponovno se kreira instanca DRL agenta s predanim okruženjem (nije potrebno ponovno raditi, ali zbog lakših uputa neka stoji)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Postavljanje loggera za praćenje i zapisivanje informacija tijekom treniranja
  tmp_path = RESULTS_DIR + '/a2c'
  # Konfigurira novi logger koji će ispisivati informacije na standardni izlaz, zapisivati u CSV datoteku i TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Postavlja novi logger za model A2C.
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Trenira model A2C s definiranim ukupnim brojem vremenskih koraka, samo ako je if_using_a2c postavljen na True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Sprema trenirani model A2C u definirani direktorij, samo ako je if_using_a2c postavljen na True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_MSFT/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3663 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# | train/             |      |
# |    reward          | 0.0  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3120         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033569848 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -5.55        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0471       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00366     |
# |    reward               | 0.0954281    |
# |    std                  | 0.979        |
# |    value_loss           | 0.187        |
# ------------------------------------------
# day: 585, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 133628.36
# total_reward: 33628.36
# total_cost: 0.00
# total_trades: 475
# Sharpe: 0.756
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2987         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0044539627 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0547      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0501       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00434     |
# |    reward               | 0.021398878  |
# |    std                  | 0.972        |
# |    value_loss           | 0.128        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2923        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003693422 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0105     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0497      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00354    |
# |    reward               | 0.0         |
# |    std                  | 0.964       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2889        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.003198445 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.044       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00349    |
# |    reward               | -0.21131322 |
# |    std                  | 0.959       |
# |    value_loss           | 0.127       |
# -----------------------------------------
# day: 585, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 101815.13
# total_reward: 1815.13
# total_cost: 0.00
# total_trades: 520
# Sharpe: 0.146
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2824         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0042052553 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0235      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0397       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00404     |
# |    reward               | 0.14649257   |
# |    std                  | 0.953        |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2776         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0038975684 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0553       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.051        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00312     |
# |    reward               | 0.0          |
# |    std                  | 0.952        |
# |    value_loss           | 0.121        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2778         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0025000197 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0493      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0357       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00385     |
# |    reward               | 0.0          |
# |    std                  | 0.943        |
# |    value_loss           | 0.129        |
# ------------------------------------------
# day: 585, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 112204.93
# total_reward: 12204.93
# total_cost: 0.00
# total_trades: 472
# Sharpe: 0.341
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2780         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0032702289 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00295     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0214       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00327     |
# |    reward               | 0.0          |
# |    std                  | 0.939        |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2777         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026750667 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0379      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0395       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0049      |
# |    reward               | 0.16320398   |
# |    std                  | 0.925        |
# |    value_loss           | 0.114        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2778         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0038775906 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00286     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0294       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00634     |
# |    reward               | 0.009264534  |
# |    std                  | 0.923        |
# |    value_loss           | 0.109        |
# ------------------------------------------
# day: 585, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 142251.73
# total_reward: 42251.73
# total_cost: 0.00
# total_trades: 486
# Sharpe: 0.865
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2778         |
# |    iterations           | 12           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0041554575 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00465      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0316       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00711     |
# |    reward               | 0.021239014  |
# |    std                  | 0.93         |
# |    value_loss           | 0.134        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2779         |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0030717696 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00457     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0341       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00248     |
# |    reward               | 0.0          |
# |    std                  | 0.938        |
# |    value_loss           | 0.128        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2779         |
# |    iterations           | 14           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0046764286 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00163     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0431       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00336     |
# |    reward               | 0.021716364  |
# |    std                  | 0.937        |
# |    value_loss           | 0.0983       |
# ------------------------------------------
# day: 585, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 100947.54
# total_reward: 947.54
# total_cost: 0.00
# total_trades: 475
# Sharpe: 0.120
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2780         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0059225527 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00908      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0175       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00517     |
# |    reward               | 0.0          |
# |    std                  | 0.947        |
# |    value_loss           | 0.0984       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2773         |
# |    iterations           | 16           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0044379276 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00927     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0204       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00427     |
# |    reward               | 0.08247485   |
# |    std                  | 0.941        |
# |    value_loss           | 0.0742       |
# ------------------------------------------
# day: 585, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 115953.30
# total_reward: 15953.30
# total_cost: 0.00
# total_trades: 490
# Sharpe: 0.400
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2758       |
# |    iterations           | 17         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00435967 |
# |    clip_fraction        | 0.0286     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.0407     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.055      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00438   |
# |    reward               | 0.0        |
# |    std                  | 0.942      |
# |    value_loss           | 0.118      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 18          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004927564 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0503     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0331      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00485    |
# |    reward               | 0.0         |
# |    std                  | 0.946       |
# |    value_loss           | 0.11        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2760         |
# |    iterations           | 19           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0029327525 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000247    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.035        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00274     |
# |    reward               | 0.31685555   |
# |    std                  | 0.952        |
# |    value_loss           | 0.128        |
# ------------------------------------------
# day: 585, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 102694.75
# total_reward: 2694.75
# total_cost: 0.00
# total_trades: 509
# Sharpe: 0.158
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2761         |
# |    iterations           | 20           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0055688787 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0255       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0543       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00639     |
# |    reward               | 0.0          |
# |    std                  | 0.955        |
# |    value_loss           | 0.122        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2760         |
# |    iterations           | 21           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0050385506 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.127       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0219       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00763     |
# |    reward               | -0.08746422  |
# |    std                  | 0.954        |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2761        |
# |    iterations           | 22          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.003316306 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0115     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0364      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00397    |
# |    reward               | 0.0         |
# |    std                  | 0.955       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# day: 585, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 139588.95
# total_reward: 39588.95
# total_cost: 0.00
# total_trades: 515
# Sharpe: 0.761
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2762         |
# |    iterations           | 23           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043980842 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0254       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0399       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00446     |
# |    reward               | -0.046159618 |
# |    std                  | 0.965        |
# |    value_loss           | 0.115        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2763        |
# |    iterations           | 24          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004175498 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0183      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0423      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00313    |
# |    reward               | 0.0         |
# |    std                  | 0.964       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2763         |
# |    iterations           | 25           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0062842877 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0383       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0698       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00615     |
# |    reward               | 0.11208032   |
# |    std                  | 0.96         |
# |    value_loss           | 0.135        |
# ------------------------------------------
# day: 585, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 136060.85
# total_reward: 36060.85
# total_cost: 0.00
# total_trades: 525
# Sharpe: 0.732
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2763         |
# |    iterations           | 26           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0058007613 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0184      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0236       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00623     |
# |    reward               | 0.13465662   |
# |    std                  | 0.951        |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2762         |
# |    iterations           | 27           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0064187422 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0131      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0316       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.006       |
# |    reward               | 0.082428925  |
# |    std                  | 0.952        |
# |    value_loss           | 0.119        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2759        |
# |    iterations           | 28          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004598741 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0173      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0342      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00541    |
# |    reward               | 0.0         |
# |    std                  | 0.956       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# day: 585, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 84887.74
# total_reward: -15112.26
# total_cost: 0.00
# total_trades: 546
# Sharpe: -0.223
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2759         |
# |    iterations           | 29           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0056410683 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0383      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0401       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00676     |
# |    reward               | -0.28761667  |
# |    std                  | 0.951        |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 30          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004276987 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00916    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0513      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00385    |
# |    reward               | 0.0         |
# |    std                  | 0.943       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 31          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005358697 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0367      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00632    |
# |    reward               | 0.006320984 |
# |    std                  | 0.94        |
# |    value_loss           | 0.141       |
# -----------------------------------------
# day: 585, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 132146.26
# total_reward: 32146.26
# total_cost: 0.00
# total_trades: 530
# Sharpe: 0.656
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2761         |
# |    iterations           | 32           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0051656035 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00646     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0446       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00266     |
# |    reward               | 0.0          |
# |    std                  | 0.935        |
# |    value_loss           | 0.116        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 33          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007187118 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0198      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0535      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00415    |
# |    reward               | 0.0         |
# |    std                  | 0.935       |
# |    value_loss           | 0.161       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2759         |
# |    iterations           | 34           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0049090483 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0475       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0304       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00484     |
# |    reward               | 0.0691255    |
# |    std                  | 0.926        |
# |    value_loss           | 0.137        |
# ------------------------------------------
# day: 585, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 90466.60
# total_reward: -9533.40
# total_cost: 0.00
# total_trades: 548
# Sharpe: -0.075
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2759         |
# |    iterations           | 35           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0063486025 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0575      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0504       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00414     |
# |    reward               | 0.0          |
# |    std                  | 0.923        |
# |    value_loss           | 0.12         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2759        |
# |    iterations           | 36          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004913086 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0509      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0475      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00429    |
# |    reward               | 0.0         |
# |    std                  | 0.921       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# day: 585, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 170593.20
# total_reward: 70593.20
# total_cost: 0.00
# total_trades: 525
# Sharpe: 1.196
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2759        |
# |    iterations           | 37          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007673833 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0284      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0471      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00686    |
# |    reward               | 0.3005243   |
# |    std                  | 0.914       |
# |    value_loss           | 0.131       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2760         |
# |    iterations           | 38           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0045739026 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0541       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0558       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00674     |
# |    reward               | -0.3722832   |
# |    std                  | 0.907        |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2761       |
# |    iterations           | 39         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00572473 |
# |    clip_fraction        | 0.0616     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.0826     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0484     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00593   |
# |    reward               | 0.21214542 |
# |    std                  | 0.913      |
# |    value_loss           | 0.154      |
# ----------------------------------------
# day: 585, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 74416.71
# total_reward: -25583.29
# total_cost: 0.00
# total_trades: 536
# Sharpe: -0.463
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2760         |
# |    iterations           | 40           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0066183107 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0133      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00886      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00461     |
# |    reward               | 0.025812972  |
# |    std                  | 0.911        |
# |    value_loss           | 0.0997       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 41          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009157925 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0837      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0409      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00485    |
# |    reward               | 0.0         |
# |    std                  | 0.911       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2751        |
# |    iterations           | 42          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007579505 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0317      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0559      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00615    |
# |    reward               | -0.08501616 |
# |    std                  | 0.895       |
# |    value_loss           | 0.125       |
# -----------------------------------------
# day: 585, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 124551.54
# total_reward: 24551.54
# total_cost: 0.00
# total_trades: 538
# Sharpe: 0.529
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2752         |
# |    iterations           | 43           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0049397685 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0218       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0492       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0036      |
# |    reward               | 0.0          |
# |    std                  | 0.887        |
# |    value_loss           | 0.165        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2752         |
# |    iterations           | 44           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0064135166 |
# |    clip_fraction        | 0.065        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.039        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0227       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00765     |
# |    reward               | 0.0          |
# |    std                  | 0.883        |
# |    value_loss           | 0.136        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2750        |
# |    iterations           | 45          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006613664 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0722      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0398      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00753    |
# |    reward               | 0.16356073  |
# |    std                  | 0.888       |
# |    value_loss           | 0.137       |
# -----------------------------------------
# day: 585, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 168219.04
# total_reward: 68219.04
# total_cost: 0.00
# total_trades: 539
# Sharpe: 1.096
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2748         |
# |    iterations           | 46           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0040125344 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0881       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0456       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00297     |
# |    reward               | 0.07777685   |
# |    std                  | 0.889        |
# |    value_loss           | 0.15         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2740         |
# |    iterations           | 47           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0073220814 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0906       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00388     |
# |    reward               | -0.05953356  |
# |    std                  | 0.89         |
# |    value_loss           | 0.184        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2741         |
# |    iterations           | 48           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063567227 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0505       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.028        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00294     |
# |    reward               | -0.06436042  |
# |    std                  | 0.894        |
# |    value_loss           | 0.123        |
# ------------------------------------------
# day: 585, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 172209.66
# total_reward: 72209.66
# total_cost: 0.00
# total_trades: 525
# Sharpe: 1.122
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2740         |
# |    iterations           | 49           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0074076643 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.0392       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0608       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00427     |
# |    reward               | 0.0          |
# |    std                  | 0.893        |
# |    value_loss           | 0.152        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2739        |
# |    iterations           | 50          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004162642 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0972      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.047       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00525    |
# |    reward               | 0.0         |
# |    std                  | 0.887       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2738         |
# |    iterations           | 51           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.012229282  |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0968       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00671     |
# |    reward               | -0.024196014 |
# |    std                  | 0.888        |
# |    value_loss           | 0.206        |
# ------------------------------------------
# day: 585, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 139259.72
# total_reward: 39259.72
# total_cost: 0.00
# total_trades: 524
# Sharpe: 0.762
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2738        |
# |    iterations           | 52          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009930213 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0844      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0593      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00403    |
# |    reward               | 0.0946319   |
# |    std                  | 0.887       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2739         |
# |    iterations           | 53           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0066007734 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.0487       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0397       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0051      |
# |    reward               | 0.40847492   |
# |    std                  | 0.871        |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# ...
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.071       |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00318    |
# |    reward               | 0.2658503   |
# |    std                  | 0.717       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# day: 585, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 165145.03
# total_reward: 65145.03
# total_cost: 0.00
# total_trades: 528
# Sharpe: 0.958
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 180         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.021200042 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0504      |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00261    |
# |    reward               | -0.01236047 |
# |    std                  | 0.715       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2691         |
# |    iterations           | 181          |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.02666973   |
# |    clip_fraction        | 0.0874       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0817       |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | 0.00049      |
# |    reward               | -0.011755176 |
# |    std                  | 0.716        |
# |    value_loss           | 0.165        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 182         |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.011720417 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0858      |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00136    |
# |    reward               | 0.0         |
# |    std                  | 0.713       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# day: 585, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 174922.84
# total_reward: 74922.84
# total_cost: 0.00
# total_trades: 534
# Sharpe: 1.063
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 183         |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.01734071  |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0341      |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00208    |
# |    reward               | -0.26437545 |
# |    std                  | 0.706       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 184         |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.019831335 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0472      |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.0011     |
# |    reward               | 0.0         |
# |    std                  | 0.701       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2692         |
# |    iterations           | 185          |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.017098436  |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.451        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.044        |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000952    |
# |    reward               | 0.0014814758 |
# |    std                  | 0.696        |
# |    value_loss           | 0.145        |
# ------------------------------------------
# day: 585, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 114309.78
# total_reward: 14309.78
# total_cost: 0.00
# total_trades: 506
# Sharpe: 0.372
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2692         |
# |    iterations           | 186          |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.015994351  |
# |    clip_fraction        | 0.0933       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0333       |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.002       |
# |    reward               | -0.045489717 |
# |    std                  | 0.702        |
# |    value_loss           | 0.137        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2692        |
# |    iterations           | 187         |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.008936038 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0489      |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00117     |
# |    reward               | -0.23379283 |
# |    std                  | 0.703       |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 188         |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.014870792 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0477      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.00207     |
# |    reward               | -0.19714932 |
# |    std                  | 0.701       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# day: 585, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 145773.78
# total_reward: 45773.78
# total_cost: 0.00
# total_trades: 563
# Sharpe: 0.741
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2691        |
# |    iterations           | 189         |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.015660044 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0434      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.000471   |
# |    reward               | -0.2546528  |
# |    std                  | 0.701       |
# |    value_loss           | 0.173       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2691          |
# |    iterations           | 190           |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 389120        |
# | train/                  |               |
# |    approx_kl            | 0.014953938   |
# |    clip_fraction        | 0.0949        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.408         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.112         |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | 0.000407      |
# |    reward               | -0.0049423827 |
# |    std                  | 0.708         |
# |    value_loss           | 0.172         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2691          |
# |    iterations           | 191           |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 391168        |
# | train/                  |               |
# |    approx_kl            | 0.020415306   |
# |    clip_fraction        | 0.0951        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.617         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0755        |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.00119      |
# |    reward               | -0.0022121093 |
# |    std                  | 0.71          |
# |    value_loss           | 0.158         |
# -------------------------------------------
# day: 585, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 99517.88
# total_reward: -482.12
# total_cost: 0.00
# total_trades: 540
# Sharpe: 0.113
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2685         |
# |    iterations           | 192          |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.01507711   |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0294       |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00482     |
# |    reward               | 0.0008984375 |
# |    std                  | 0.719        |
# |    value_loss           | 0.14         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2684        |
# |    iterations           | 193         |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.019471943 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0668      |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00196    |
# |    reward               | -0.18291686 |
# |    std                  | 0.717       |
# |    value_loss           | 0.166       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2683         |
# |    iterations           | 194          |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.028284576  |
# |    clip_fraction        | 0.0995       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.386        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0636       |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 0.00104      |
# |    reward               | 0.0009971313 |
# |    std                  | 0.712        |
# |    value_loss           | 0.135        |
# ------------------------------------------
# day: 585, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 119212.07
# total_reward: 19212.07
# total_cost: 0.00
# total_trades: 541
# Sharpe: 0.422
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2683        |
# |    iterations           | 195         |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.012856959 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0426      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00228    |
# |    reward               | -0.1606766  |
# |    std                  | 0.706       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2683        |
# |    iterations           | 196         |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014859566 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0275      |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.000702    |
# |    reward               | 0.053044923 |
# |    std                  | 0.716       |
# |    value_loss           | 0.105       |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Priprema za backtest

# %%
# Po potrebi učitavamo sporemnjene podatke ako smo restrartali proces (nije potrebno)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# Po potrebi učitavamo sporemnjene podatke o treningu agenata ako smo restrartali proces (nije potrebno)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trgovanje (podatci izvan trening seta)

# %% [markdown]
# Ovdje sada za trgovanje koristimo trade skup podataka koji nikad nije bio korišten za trening. Dodatno sličnim pristupom bi mogli i dotrenirati postojeći spremljeni model.
#
# Brojni hiperparametri, na primjer, stopa učenja, ukupan broj uzoraka za trening – utječu na proces učenja i obično se određuju testiranjem nekih varijacija.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# Ovaj dio se odnosi se na korištenje dubokog pojačanog učenja (DRL) za simulaciju trgovanja u stvarnom vremenu koristeći prethodno trenirani model (u ovom slučaju, A2C). StockTradingEnv je okruženje koje simulira tržište dionica s obzirom na povijesne podatke, prag turbulencije (koji se koristi za određivanje volatilnosti tržišta), i 'VIX' kao pokazatelj rizika. Nakon inicijalizacije okruženja, koristi se metoda get_sb_env() za dohvaćanje okruženja i početne opservacije koje su kompatibilne sa Stable Baselines bibliotekom.

# %%
# Inicijalizacija okruženja za trgovanje s definiranim DataFrame-om 'trade', pragom turbulencije i pokazateljem rizika 'vix',
# zajedno s ostalim parametrima okruženja ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Dohvaćanje okruženja kompatibilnog sa Stable Baselines i početne opservacije.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# Zatim se DRL agent koristi za predviđanje akcija trgovanja i promjene u vrijednosti računa na temelju treniranog modela. To omogućuje evaluaciju performansi modela u scenariju izvan uzorka, pružajući uvid u to kako bi model mogao performirati u stvarnim trgovačkim uvjetima. Ako je odabrana upotreba A2C algoritma (kao što je indicirano varijablom if_using_a2c), provodi se predviđanje; u suprotnom, rezultat se postavlja na None.

# %%
# Korištenje DRL agenta za predviđanje koristeći trenirani model 'trained_a2c' i definirano okruženje trgovanja 'e_trade_gym'.
# Rezultati su dva DataFrame-a: 'df_account_value_a2c' s vrijednostima računa i 'df_actions_a2c' s akcijama koje su poduzete,
# ako je 'if_using_a2c' postavljen na True; inače se vraća (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H za usporedbu

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['MSFT']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (145, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Provodima backetinskg modela

# %%
# Postavljanje indeksa DataFrame-ova vrijednosti računa za svaku od DRL strategija, ako su odabrane.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Kreiranje praznog DataFrame-a za rezultate.
result = pd.DataFrame()

# Spajanje rezultata svih DRL strategija u jedan DataFrame, ako su odabrane.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Spajanje rezultata optimizacije srednje varijance i indeksa DJIA s glavnim rezultatima.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Dodavanje imena stupaca na temelju odabranih strategija.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Prikazivanje rezultata
result.head()
# Out:
#                       PPO            B&H
# date
# 2024-01-02  100000.000000  100000.000000
# 2024-01-03   99927.366638   99927.199276
# 2024-01-04   99927.366638   99209.961419
# 2024-01-05   99875.885193   99158.740761
# 2024-01-08  101756.684509  101030.012563

# %% [markdown]
# ### Ovdje plotiramo graf koji pokazuje ukupnu vrijednost portfolija korz vrijeme za pojedinu strategiju i benchmark

# %%
# Postavljanje veličine figure za grafikone i crtanje grafikona performansi strategija trgovanja.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Na temelju vrijednosti portfolija računamo dnevne povrate

# %%
from pyfolio import timeseries
import pandas as pd

# Lista strategija za koje želite generirati statistike
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Izračunavanje dnevnih povrata iz vrijednosti portfelja
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_9120/728507394.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                       PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-01-02  100000.000000  100000.000000          NaN          NaN
# 2024-01-03   99927.366638   99927.199276    -0.000726    -0.000728
# 2024-01-04   99927.366638   99209.961419     0.000000    -0.007178
# 2024-01-05   99875.885193   99158.740761    -0.000515    -0.000516
# 2024-01-08  101756.684509  101030.012563     0.018831     0.018871

# %% [markdown]
# ### Računamo povrate po odabranoj strategiji

# %%
# Pretpostavljamo da result DataFrame već sadrži vrijednosti portfelja za svaku strategiju
for strategy in strategies:
    # Provjerite postoji li strategija u DataFrame-u
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Izračunavanje statistika performansi za trenutnu strategiju
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Ispis statistika performansi
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategija {strategy} nije pronađena u rezultatima.\n")
# Out:
# Strategija A2C nije pronađena u rezultatima.
#
# Strategija DDPG nije pronađena u rezultatima.
#
# ==============Strategy Stats (PPO)==============
# Annual return          0.310952
# Cumulative returns     0.167327
# Annual volatility      0.149779
# Sharpe ratio           1.883313
# Calmar ratio           4.768797
# Stability              0.759140
# Max drawdown          -0.065206
# Omega ratio            1.495564
# Sortino ratio          2.712877
# Skew                  -0.757345
# Kurtosis               2.822306
# Tail ratio             1.336153
# Daily value at risk   -0.017751
# dtype: float64
#
#
# Strategija TD3 nije pronađena u rezultatima.
#
# Strategija SAC nije pronađena u rezultatima.
#
# ==============Strategy Stats (B&H)==============
# Annual return          0.266449
# Cumulative returns     0.144515
# Annual volatility      0.197844
# Sharpe ratio           1.293092
# Calmar ratio           2.534193
# Stability              0.638731
# Max drawdown          -0.105142
# Omega ratio            1.236995
# Sortino ratio          1.832478
# Skew                  -0.514466
# Kurtosis               0.366786
# Tail ratio             0.792548
# Daily value at risk   -0.023911
# dtype: float64

# %% [markdown]
# ### Plotiramo komulativne povrate za pojedinu strategiju

# %%
import matplotlib.pyplot as plt

# Postavljanje veličine figure za grafikon
plt.figure(figsize=(14, 7))

# Prolazak kroz svaku strategiju i crtanje njenih kumulativnih povrata
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju i pretvaranje u decimalni format ako je potrebno
        returns = result[f'{strategy}_returns'].dropna() + 1  # Dodaje 1 za korištenje cumprod()

        # Izračunavanje kumulativnih povrata
        cumulative_returns = returns.cumprod() - 1  # Oduzima 1 na kraju za prikazivanje pravog kumulativnog povrata

        # Plotiranje kumulativnih povrata
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Dodavanje naslova i legende na grafikon
plt.title('Kumulativni povrati DRL strategija')
plt.legend()

# Postavljanje oznaka za x i y osi
plt.xlabel('Datum')
plt.ylabel('Kumulativni povrati')

# Prikazivanje grafikona
plt.show()

# %% [markdown]
# ### Spremamo rezultate u CSV
# Potrebno promjeniti za svakog agenta

# %%
import pickle

# Za df_account_value_sac
with open('results/2. MSFT/msft_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)

# Za df_actions_sac
with open('results/2. MSFT/msft_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# Za buy_and_hold
with open('results/2. MSFT/msft_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
