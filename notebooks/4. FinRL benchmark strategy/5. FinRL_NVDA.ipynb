# %% [markdown]
# ## 1. Učitavanje potrebnih paketa

# %%
# Standardne biblioteke
import sys
sys.path.append('../../')

import itertools

# Analiza podataka
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL i stable_baselines3 za strojno učenje i trgovanje
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Konfiguracijski fajlovi i pomoćne funkcije iz FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Omogućavanje prikaza grafikona unutar Jupyter bilježnice
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_NFLX'
RESULTS_DIR = 'files/results_NFLX'
DATA_DIR = 'files/data_NFLX'

# Provjera i kreiranje direktorija
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Dohvaćanje podataka

# %% [markdown]
# Imamo klasu nazvanu YahooDownloader koja koristi yfinance za dohvaćanje podataka s Yahoo Finance.
#
# U YahooDownloader-u FinRL-a, modificirali smo okvir podataka u oblik koji je pogodan za daljnju obradu podataka. Koristimo prilagođenu zatvarajuću cijenu umjesto zatvarajuće cijene i dodajemo stupac koji predstavlja dan u tjednu (0-4 što odgovara ponedjeljku-petku).

# %%
# Intervali za trening i trgovanje
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2023-12-31'
TRADE_START_DATE = '2024-01-01'
TRADE_END_DATE = '2024-07-31'

# %%
# Preuzimamo sve podatke
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['NVDA']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (731, 8)

# %%
df_raw.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2021-09-01  22.485001  22.697001  22.357000  22.404453  201767000  NVDA
# 1  2021-09-02  22.518000  22.593000  22.295000  22.359528  187834000  NVDA
# 2  2021-09-03  22.325001  22.986000  22.200001  22.805805  280532000  NVDA
# 3  2021-09-07  22.833000  22.899000  22.521999  22.625099  198107000  NVDA
# 4  2021-09-08  22.513000  22.610001  21.976999  22.302624  254434000  NVDA
#
#    day
# 0    2
# 1    3
# 2    4
# 3    1
# 4    2

# %% [markdown]
# ## 3. Procesiranje podataka

# %% [markdown]
# Koristimo definiranu klasu FeatureEngineer pomoću koje radimo procesiranje podataka i dodavanje tehničkih indikatora.
#
# Opcija use_vix uključuje VIX indeks, poznat kao "indeks straha", koji predstavlja očekivanu volatilnost tržišta dionica temeljenu na opcijama S&P 500 indeksa. VIX pomaže modelu da razumije tržišnu nesigurnost, s višim vrijednostima koje ukazuju na veću nesigurnost.
#
# Opcija use_turbulence uključuje indeks turbulencije, koji mjeri neobične tržišne fluktuacije i služi kao pokazatelj rizika i tržišnih šokova. Koristan je za identifikaciju perioda visoke volatilnosti, pomažući modelu da se prilagodi financijskim krizama.
#
# Inače dosta zgodna klasa koja sadrži korisne metode za obradu financijskih podataka i može se primjeniti u brojne druge svrhe.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (730, 8)
# Successfully added vix

# %%
# Stvara listu jedinstvenih oznaka dionica (tickers) iz stupca 'tic' DataFrame-a 'processed'.
list_ticker = processed["tic"].unique().tolist()

# Stvara listu datuma između najranijeg i najkasnijeg datuma u DataFrame-u 'processed', pretvara ih u stringove.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Stvara kombinacije svih datuma i oznaka dionica koristeći kartezijev produkt.
combination = list(itertools.product(list_date,list_ticker))

# Stvara novi DataFrame 'processed_full' s kolonama "date" i "tic", koji sadrži sve kombinacije datuma i oznaka dionica.
# Spaja taj DataFrame s originalnim DataFrame-om 'processed' na temelju kolona "date" i "tic", koristeći 'left' spajanje.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filtrira 'processed_full' DataFrame da sadrži samo one retke čiji su datumi prisutni u originalnom DataFrame-u 'processed'.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sortira 'processed_full' DataFrame po datumu i oznaci dionica.
processed_full = processed_full.sort_values(['date','tic'])

# Zamjenjuje sve nedostajuće vrijednosti (NaN) s 0 u DataFrame-u 'processed_full'.
processed_full = processed_full.fillna(0)

# %%
processed_full.head()
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2021-09-01  NVDA  22.485001  22.697001  22.357000  22.404453  201767000.0
# 1  2021-09-02  NVDA  22.518000  22.593000  22.295000  22.359528  187834000.0
# 2  2021-09-03  NVDA  22.325001  22.986000  22.200001  22.805805  280532000.0
# 6  2021-09-07  NVDA  22.833000  22.899000  22.521999  22.625099  198107000.0
# 7  2021-09-08  NVDA  22.513000  22.610001  21.976999  22.302624  254434000.0
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30       dx_30  \
# 0  2.0  0.000000  22.445525  22.318456   0.000000  -66.666667  100.000000
# 1  3.0 -0.001008  22.445525  22.318456   0.000000  -66.666667  100.000000
# 2  4.0  0.012555  23.014699  22.031825  91.131784  100.000000   73.535350
# 6  1.0  0.011891  22.962699  22.134743  65.954659   72.101685   73.535350
# 7  2.0 -0.001552  22.920197  22.078807  43.678129 -107.851388   24.143612
#
#    close_30_sma  close_60_sma        vix
# 0     22.404453     22.404453  16.110001
# 1     22.381990     22.381990  16.410000
# 2     22.523262     22.523262  16.410000
# 6     22.548721     22.548721  18.139999
# 7     22.499502     22.499502  17.959999

# %%
# Pripremamo trening i trade set sukladno definiranim datumima
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 586
# 144

# %%
# Spremamo podatke
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Priprema environmenta

# %% [markdown]
# stock_dimension predstavlja broj jedinstvenih dionica u skupu podataka. Ova vrijednost se koristi za određivanje koliko različitih dionica model može trgovati.
#
# state_space označava ukupnu veličinu prostora stanja koji model koristi za donošenje odluka. Prostor stanja uključuje trenutne podatke o dionicama (kao što su cijene i tehnički indikatori) i informacije o trenutnom portfelju (kao što su broj dionica koje posjeduje). Veličina prostora stanja određena je formulom koja uzima u obzir broj dionica i broj tehničkih indikatora.

# %%
# Izračunavamo dimenziju (broj jedinstvenih dionica) iz DataFrame-a 'train'.
stock_dimension = len(train.tic.unique())

# Izračunavamo veličinu stanja na temelju dimenzije i broja tehničkih indikatora.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Stvara liste troškova kupnje i prodaje za svaku dionicu.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Inicijalizira broj dionica za svaku dionicu na 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym je instanca klase StockTradingEnv, koja predstavlja okruženje za trgovanje. Ovo okruženje koristi podatke i parametre definirane za simulaciju tržišta dionica. Model uči kako trgovati unutar ovog okruženja, pokušavajući maksimizirati ukupnu nagradu (profit) kroz seriju trgovačkih odluka.
#
# env_train dobiva se pozivom metode get_sb_env() na instanci e_train_gym. Ova metoda vraća okruženje kompatibilno s bibliotekom Stable Baselines 3, koja se koristi za implementaciju algoritama pojačanog učenja. Drugi povratni element, koji se ovdje ignorira (_), može se koristiti za dodatne informacije ili funkcionalnosti koje pruža okruženje.

# %%
# Definira argumente za okruženje trgovanja.
env_kwargs = {
    "hmax": 1000,  # Maksimalni broj dionica koje se mogu kupiti ili prodati u jednoj transakciji.
    "initial_amount": 100000,  # Početni iznos kapitala.
    "num_stock_shares": num_stock_shares,  # Početni broj dionica svake dionice u portfelju, inicijalno postavljen na 0.
    "buy_cost_pct": buy_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "sell_cost_pct": sell_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "state_space": state_space,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "stock_dim": stock_dimension,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "tech_indicator_list": INDICATORS,  # Lista tehničkih indikatora koji će se koristiti za analizu stanja tržišta.
    "action_space": stock_dimension,  # Veličina prostora akcija, odnosno, broj različitih akcija koje model može izvršiti.
    "reward_scaling": 1e-4  # Faktor skaliranja za nagradu, koristi se za prilagodbu veličine nagrade kako bi se olakšalo učenje.
}

# Kreira okruženje za treniranje.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Dohvaća okruženje pogodno za Stable Baselines i neiskorišteni objekt.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Trening DRL agenata

# %% [markdown]
# Ovdje su algoritmi dubokog pojačanog učenja (DRL) iz biblioteke Stable Baselines 3. Radi se o biblioteci koja je implementirala popularne DRL algoritme koristeći PyTorch.
#
# Kao zamjena mogu se koristiti biblioteke ElegantRL i Ray RLlib.

# %% [markdown]
# ### Trening 5 različitih DRL agenata (A2C, DDPG, PPO, TD3, SAC)

# %%
# Postavljanje odgovarajućih vrijednosti na 'True' za algoritme koje želite koristiti
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# Ponovno se kreira instanca DRL agenta s predanim okruženjem (nije potrebno ponovno raditi, ali zbog lakših uputa neka stoji)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Postavljanje loggera za praćenje i zapisivanje informacija tijekom treniranja
  tmp_path = RESULTS_DIR + '/a2c'
  # Konfigurira novi logger koji će ispisivati informacije na standardni izlaz, zapisivati u CSV datoteku i TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Postavlja novi logger za model A2C.
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Trenira model A2C s definiranim ukupnim brojem vremenskih koraka, samo ako je if_using_a2c postavljen na True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Sprema trenirani model A2C u definirani direktorij, samo ako je if_using_a2c postavljen na True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_NFLX/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3688 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# | train/             |      |
# |    reward          | 0.0  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2692         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0023719855 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.11        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.149        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00227     |
# |    reward               | 0.1757782    |
# |    std                  | 1            |
# |    value_loss           | 0.498        |
# ------------------------------------------
# day: 585, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 219716.29
# total_reward: 119716.29
# total_cost: 0.00
# total_trades: 554
# Sharpe: 1.144
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2666         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0008564355 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0276      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.203        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000554    |
# |    reward               | 0.0          |
# |    std                  | 1            |
# |    value_loss           | 0.453        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2674         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0057024173 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00369     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.223        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.004       |
# |    reward               | 0.27623662   |
# |    std                  | 1            |
# |    value_loss           | 0.434        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2604        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.001731453 |
# |    clip_fraction        | 0.00117     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.00819     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.735       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00165    |
# |    reward               | -0.17658532 |
# |    std                  | 0.998       |
# |    value_loss           | 1.27        |
# -----------------------------------------
# day: 585, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 270265.61
# total_reward: 170265.61
# total_cost: 0.00
# total_trades: 574
# Sharpe: 1.176
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2586          |
# |    iterations           | 6             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00032360852 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.00385      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.616         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000555     |
# |    reward               | 0.4394212     |
# |    std                  | 0.996         |
# |    value_loss           | 0.962         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2543         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.003987375  |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00193     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.525        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00333     |
# |    reward               | -0.033255212 |
# |    std                  | 0.996        |
# |    value_loss           | 1.16         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2570         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0042586755 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0308       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.424        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00172     |
# |    reward               | 0.25708175   |
# |    std                  | 0.994        |
# |    value_loss           | 0.929        |
# ------------------------------------------
# day: 585, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 219647.15
# total_reward: 119647.15
# total_cost: 0.00
# total_trades: 583
# Sharpe: 0.915
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2589        |
# |    iterations           | 9           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006275524 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0468      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.503       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0039     |
# |    reward               | -0.2984429  |
# |    std                  | 0.992       |
# |    value_loss           | 1.28        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2600         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0009539591 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0607       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.654        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000468    |
# |    reward               | 0.22621393   |
# |    std                  | 0.993        |
# |    value_loss           | 1.19         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2606          |
# |    iterations           | 11            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.0004745058  |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.0783        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.42          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000377     |
# |    reward               | -0.0013368876 |
# |    std                  | 0.994         |
# |    value_loss           | 1.09          |
# -------------------------------------------
# day: 585, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 180571.41
# total_reward: 80571.41
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.755
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2617         |
# |    iterations           | 12           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0051240018 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.079        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.436        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00425     |
# |    reward               | 0.29018447   |
# |    std                  | 0.992        |
# |    value_loss           | 1.02         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2588         |
# |    iterations           | 13           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0017232526 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.072        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.481        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00132     |
# |    reward               | -0.08626223  |
# |    std                  | 0.993        |
# |    value_loss           | 1.2          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2574          |
# |    iterations           | 14            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00021515708 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.0927        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.676         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 8.65e-05      |
# |    reward               | -0.14886221   |
# |    std                  | 0.992         |
# |    value_loss           | 1.35          |
# -------------------------------------------
# day: 585, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 233983.17
# total_reward: 133983.17
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.956
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2572         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0010129098 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.602        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00205     |
# |    reward               | -0.56155276  |
# |    std                  | 0.995        |
# |    value_loss           | 1.18         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2582         |
# |    iterations           | 16           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0005484413 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.611        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | 0.56790525   |
# |    std                  | 0.996        |
# |    value_loss           | 1.31         |
# ------------------------------------------
# day: 585, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 214400.26
# total_reward: 114400.26
# total_cost: 0.00
# total_trades: 583
# Sharpe: 0.894
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2580        |
# |    iterations           | 17          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002192148 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.574       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00163    |
# |    reward               | 0.21556188  |
# |    std                  | 0.998       |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2578          |
# |    iterations           | 18            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00070216996 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.142         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.915         |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00127      |
# |    reward               | -0.5989619    |
# |    std                  | 0.996         |
# |    value_loss           | 1.41          |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2586       |
# |    iterations           | 19         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00347216 |
# |    clip_fraction        | 0.0295     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.415      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00334   |
# |    reward               | 0.4356565  |
# |    std                  | 0.994      |
# |    value_loss           | 1.05       |
# ----------------------------------------
# day: 585, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 226943.00
# total_reward: 126943.00
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.930
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2594          |
# |    iterations           | 20            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00030079338 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.169         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.477         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000114      |
# |    reward               | 0.30240622    |
# |    std                  | 0.994         |
# |    value_loss           | 1.24          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2602        |
# |    iterations           | 21          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005760818 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.589       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00501    |
# |    reward               | 0.036924627 |
# |    std                  | 0.991       |
# |    value_loss           | 1.31        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2608         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0021002046 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.641        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00123     |
# |    reward               | 0.2556066    |
# |    std                  | 0.991        |
# |    value_loss           | 1.19         |
# ------------------------------------------
# day: 585, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 229452.50
# total_reward: 129452.50
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.934
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2609         |
# |    iterations           | 23           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0044180783 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.676        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00303     |
# |    reward               | -0.07502155  |
# |    std                  | 0.991        |
# |    value_loss           | 1.26         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2617         |
# |    iterations           | 24           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0030472705 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.571        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000974    |
# |    reward               | -0.19918351  |
# |    std                  | 0.992        |
# |    value_loss           | 1.3          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2622        |
# |    iterations           | 25          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004789401 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.525       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00206    |
# |    reward               | 0.1822365   |
# |    std                  | 0.989       |
# |    value_loss           | 1.26        |
# -----------------------------------------
# day: 585, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 225742.81
# total_reward: 125742.81
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.924
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2628          |
# |    iterations           | 26            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00015480645 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.242         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.592         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000411     |
# |    reward               | -0.1581577    |
# |    std                  | 0.989         |
# |    value_loss           | 1.38          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2632        |
# |    iterations           | 27          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003996213 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.569       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00402    |
# |    reward               | 0.2684023   |
# |    std                  | 0.989       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2636          |
# |    iterations           | 28            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 9.5633586e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.339         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.524         |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000525     |
# |    reward               | 0.043730672   |
# |    std                  | 0.988         |
# |    value_loss           | 1.28          |
# -------------------------------------------
# day: 585, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 168899.16
# total_reward: 68899.16
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.691
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2638          |
# |    iterations           | 29            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00042049063 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.385         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.641         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00033      |
# |    reward               | -0.3926755    |
# |    std                  | 0.988         |
# |    value_loss           | 1.38          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2641          |
# |    iterations           | 30            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00014276401 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.432         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.667         |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -4.62e-05     |
# |    reward               | 0.62940377    |
# |    std                  | 0.989         |
# |    value_loss           | 1.26          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2645         |
# |    iterations           | 31           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0051324526 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.792        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00307     |
# |    reward               | 0.11456803   |
# |    std                  | 0.989        |
# |    value_loss           | 1.4          |
# ------------------------------------------
# day: 585, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 196110.88
# total_reward: 96110.88
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.808
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2649         |
# |    iterations           | 32           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0012559325 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.451        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.57         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00106     |
# |    reward               | 0.08274099   |
# |    std                  | 0.989        |
# |    value_loss           | 1.34         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2651        |
# |    iterations           | 33          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002492433 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.488       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00179    |
# |    reward               | -0.26280576 |
# |    std                  | 0.989       |
# |    value_loss           | 1.28        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2654         |
# |    iterations           | 34           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0030004578 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.76         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00185     |
# |    reward               | 0.31180456   |
# |    std                  | 0.989        |
# |    value_loss           | 1.36         |
# ------------------------------------------
# day: 585, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 212994.71
# total_reward: 112994.71
# total_cost: 0.00
# total_trades: 583
# Sharpe: 0.881
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2655          |
# |    iterations           | 35            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00089010684 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.427         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.787         |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00152      |
# |    reward               | -0.1541451    |
# |    std                  | 0.99          |
# |    value_loss           | 1.32          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2655         |
# |    iterations           | 36           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0030055735 |
# |    clip_fraction        | 0.00464      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.733        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00148     |
# |    reward               | 0.3662392    |
# |    std                  | 0.99         |
# |    value_loss           | 1.1          |
# ------------------------------------------
# day: 585, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 213711.08
# total_reward: 113711.08
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.872
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2656          |
# |    iterations           | 37            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00036564388 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.376         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.683         |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.001        |
# |    reward               | 0.0907208     |
# |    std                  | 0.991         |
# |    value_loss           | 1.2           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2656          |
# |    iterations           | 38            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00067118154 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.447         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.67          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.00044      |
# |    reward               | -0.6685313    |
# |    std                  | 0.991         |
# |    value_loss           | 1.33          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2656          |
# |    iterations           | 39            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00047319796 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.501         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.466         |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000395     |
# |    reward               | 0.6956739     |
# |    std                  | 0.992         |
# |    value_loss           | 1.15          |
# -------------------------------------------
# day: 585, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 205698.28
# total_reward: 105698.28
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.838
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2644         |
# |    iterations           | 40           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0054816906 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.477        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00334     |
# |    reward               | 0.6379799    |
# |    std                  | 0.992        |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2640        |
# |    iterations           | 41          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.002237973 |
# |    clip_fraction        | 0.000781    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.653       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00118    |
# |    reward               | -0.65888846 |
# |    std                  | 0.991       |
# |    value_loss           | 1.25        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2636         |
# |    iterations           | 42           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0034242815 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.472        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0013      |
# |    reward               | 0.050944366  |
# |    std                  | 0.992        |
# |    value_loss           | 1.36         |
# ------------------------------------------
# day: 585, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 195287.58
# total_reward: 95287.58
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.798
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2640         |
# |    iterations           | 43           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0018808438 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.562        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | -0.16349253  |
# |    std                  | 0.993        |
# |    value_loss           | 1.28         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2643          |
# |    iterations           | 44            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00034049895 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.497         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.742         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000201     |
# |    reward               | -0.34123307   |
# |    std                  | 0.996         |
# |    value_loss           | 1.24          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2645         |
# |    iterations           | 45           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0014065228 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.462        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000482    |
# |    reward               | 0.17510258   |
# |    std                  | 0.999        |
# |    value_loss           | 1.09         |
# ------------------------------------------
# day: 585, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 206928.29
# total_reward: 106928.29
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.844
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2648         |
# |    iterations           | 46           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0017633236 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.484        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000702    |
# |    reward               | 0.82214314   |
# |    std                  | 0.996        |
# |    value_loss           | 1.09         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2646          |
# |    iterations           | 47            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00024838911 |
# |    clip_fraction        | 0.002         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.549         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.634         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000923     |
# |    reward               | -0.47971627   |
# |    std                  | 0.997         |
# |    value_loss           | 1.15          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2648         |
# |    iterations           | 48           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0014271259 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.655        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000783    |
# |    reward               | -0.25782576  |
# |    std                  | 1            |
# |    value_loss           | 1.3          |
# ------------------------------------------
# day: 585, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 208445.03
# total_reward: 108445.03
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.851
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2650        |
# |    iterations           | 49          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002207513 |
# |    clip_fraction        | 0.0085      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.388       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000934   |
# |    reward               | -0.16957486 |
# |    std                  | 0.999       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2654         |
# |    iterations           | 50           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0014061216 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.777        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000384    |
# |    reward               | 0.3963831    |
# |    std                  | 1            |
# |    value_loss           | 1.19         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2657         |
# |    iterations           | 51           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0024843477 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.408        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000765    |
# |    reward               | -0.39703107  |
# |    std                  | 1            |
# |    value_loss           | 1.23         |
# ------------------------------------------
# day: 585, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 233759.33
# total_reward: 133759.33
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.940
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2656        |
# |    iterations           | 52          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.003366394 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.651       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00148    |
# |    reward               | 0.62554693  |
# |    std                  | 0.999       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2651         |
# |    iterations           | 53           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0016751706 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# ...
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.569       |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00333    |
# |    reward               | 0.043242037 |
# |    std                  | 0.915       |
# |    value_loss           | 0.959       |
# -----------------------------------------
# day: 585, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 213505.04
# total_reward: 113505.04
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.875
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2679         |
# |    iterations           | 180          |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.004016751  |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.478        |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00282     |
# |    reward               | -0.016926209 |
# |    std                  | 0.91         |
# |    value_loss           | 1.1          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2680         |
# |    iterations           | 181          |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0034994697 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.688        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.665        |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | 0.00132      |
# |    reward               | -0.14050853  |
# |    std                  | 0.912        |
# |    value_loss           | 1.03         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2681        |
# |    iterations           | 182         |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.001598347 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.624       |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.000413   |
# |    reward               | 0.21226332  |
# |    std                  | 0.902       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# day: 585, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 222757.18
# total_reward: 122757.18
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.911
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2681         |
# |    iterations           | 183          |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0026554787 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.445        |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.000481    |
# |    reward               | -0.48857284  |
# |    std                  | 0.902        |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2681         |
# |    iterations           | 184          |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0054325787 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.673        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.575        |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.00212     |
# |    reward               | -0.08272629  |
# |    std                  | 0.896        |
# |    value_loss           | 1.06         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2682        |
# |    iterations           | 185         |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.004922872 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.34        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00192    |
# |    reward               | -0.17498067 |
# |    std                  | 0.895       |
# |    value_loss           | 0.95        |
# -----------------------------------------
# day: 585, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 213671.85
# total_reward: 113671.85
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.879
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2683         |
# |    iterations           | 186          |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0042767203 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.433        |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00441     |
# |    reward               | -0.008220061 |
# |    std                  | 0.899        |
# |    value_loss           | 1.13         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2683         |
# |    iterations           | 187          |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0011939688 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.688        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.563        |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.000783    |
# |    reward               | -0.2603907   |
# |    std                  | 0.903        |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2684         |
# |    iterations           | 188          |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0076516084 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.494        |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00134     |
# |    reward               | -0.45265105  |
# |    std                  | 0.898        |
# |    value_loss           | 1.07         |
# ------------------------------------------
# day: 585, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 194145.53
# total_reward: 94145.53
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.803
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2682         |
# |    iterations           | 189          |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0027777483 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.486        |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00218     |
# |    reward               | -0.1925899   |
# |    std                  | 0.897        |
# |    value_loss           | 1.08         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2683        |
# |    iterations           | 190         |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.006444578 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.429       |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00283    |
# |    reward               | -0.1640621  |
# |    std                  | 0.898       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2683         |
# |    iterations           | 191          |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0052235057 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.502        |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00202     |
# |    reward               | -0.11423801  |
# |    std                  | 0.894        |
# |    value_loss           | 0.967        |
# ------------------------------------------
# day: 585, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 191792.51
# total_reward: 91792.51
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.790
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2684         |
# |    iterations           | 192          |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0072872965 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.384        |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00118     |
# |    reward               | -0.043855626 |
# |    std                  | 0.894        |
# |    value_loss           | 0.996        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2684         |
# |    iterations           | 193          |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0024722458 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.59         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00273     |
# |    reward               | -0.32773355  |
# |    std                  | 0.89         |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2685         |
# |    iterations           | 194          |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0031821732 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.526        |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00134     |
# |    reward               | -0.12899017  |
# |    std                  | 0.894        |
# |    value_loss           | 1.04         |
# ------------------------------------------
# day: 585, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 186008.53
# total_reward: 86008.53
# total_cost: 0.00
# total_trades: 585
# Sharpe: 0.768
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2685        |
# |    iterations           | 195         |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.005428306 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.41        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.00018     |
# |    reward               | 0.022457195 |
# |    std                  | 0.902       |
# |    value_loss           | 1.03        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2686         |
# |    iterations           | 196          |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0043687187 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.513        |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00419     |
# |    reward               | 0.04523937   |
# |    std                  | 0.901        |
# |    value_loss           | 1.02         |
# ------------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Priprema za backtest

# %%
# Po potrebi učitavamo sporemnjene podatke ako smo restrartali proces (nije potrebno)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# Po potrebi učitavamo sporemnjene podatke o treningu agenata ako smo restrartali proces (nije potrebno)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trgovanje (podatci izvan trening seta)

# %% [markdown]
# Ovdje sada za trgovanje koristimo trade skup podataka koji nikad nije bio korišten za trening. Dodatno sličnim pristupom bi mogli i dotrenirati postojeći spremljeni model.
#
# Brojni hiperparametri, na primjer, stopa učenja, ukupan broj uzoraka za trening – utječu na proces učenja i obično se određuju testiranjem nekih varijacija.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# Ovaj dio se odnosi se na korištenje dubokog pojačanog učenja (DRL) za simulaciju trgovanja u stvarnom vremenu koristeći prethodno trenirani model (u ovom slučaju, A2C). StockTradingEnv je okruženje koje simulira tržište dionica s obzirom na povijesne podatke, prag turbulencije (koji se koristi za određivanje volatilnosti tržišta), i 'VIX' kao pokazatelj rizika. Nakon inicijalizacije okruženja, koristi se metoda get_sb_env() za dohvaćanje okruženja i početne opservacije koje su kompatibilne sa Stable Baselines bibliotekom.

# %%
# Inicijalizacija okruženja za trgovanje s definiranim DataFrame-om 'trade', pragom turbulencije i pokazateljem rizika 'vix',
# zajedno s ostalim parametrima okruženja ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Dohvaćanje okruženja kompatibilnog sa Stable Baselines i početne opservacije.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# Zatim se DRL agent koristi za predviđanje akcija trgovanja i promjene u vrijednosti računa na temelju treniranog modela. To omogućuje evaluaciju performansi modela u scenariju izvan uzorka, pružajući uvid u to kako bi model mogao performirati u stvarnim trgovačkim uvjetima. Ako je odabrana upotreba A2C algoritma (kao što je indicirano varijablom if_using_a2c), provodi se predviđanje; u suprotnom, rezultat se postavlja na None.

# %%
# Korištenje DRL agenta za predviđanje koristeći trenirani model 'trained_a2c' i definirano okruženje trgovanja 'e_trade_gym'.
# Rezultati su dva DataFrame-a: 'df_account_value_a2c' s vrijednostima računa i 'df_actions_a2c' s akcijama koje su poduzete,
# ako je 'if_using_a2c' postavljen na True; inače se vraća (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H za usporedbu

# %% [markdown]
# Dodajemo DJI indeks koji koristimo kao benchmark za usporedbu s našim DRL modelima

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['NVDA']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (145, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Provodima backetinskg modela

# %%
# Postavljanje indeksa DataFrame-ova vrijednosti računa za svaku od DRL strategija, ako su odabrane.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Kreiranje praznog DataFrame-a za rezultate.
result = pd.DataFrame()

# Spajanje rezultata svih DRL strategija u jedan DataFrame, ako su odabrane.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Spajanje rezultata optimizacije srednje varijance i indeksa DJIA s glavnim rezultatima.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Dodavanje imena stupaca na temelju odabranih strategija.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Prikazivanje rezultata
result.head()
# Out:
#                       PPO            B&H
# date
# 2024-01-02  100000.000000  100000.000000
# 2024-01-03   99401.077271   98756.435776
# 2024-01-04  100258.972168   99647.074376
# 2024-01-05  102554.478310  101928.663528
# 2024-01-08  108048.360600  108480.725602

# %% [markdown]
# ### Ovdje plotiramo graf koji pokazuje ukupnu vrijednost portfolija korz vrijeme za pojedinu strategiju i benchmark

# %%
# Postavljanje veličine figure za grafikone i crtanje grafikona performansi strategija trgovanja.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Na temelju vrijednosti portfolija računamo dnevne povrate

# %%
from pyfolio import timeseries
import pandas as pd

# Lista strategija za koje želite generirati statistike
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Izračunavanje dnevnih povrata iz vrijednosti portfelja
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_20219/728507394.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                       PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-01-02  100000.000000  100000.000000          NaN          NaN
# 2024-01-03   99401.077271   98756.435776    -0.005989    -0.012436
# 2024-01-04  100258.972168   99647.074376     0.008631     0.009019
# 2024-01-05  102554.478310  101928.663528     0.022896     0.022897
# 2024-01-08  108048.360600  108480.725602     0.053570     0.064281

# %% [markdown]
# ### Računamo povrate po odabranoj strategiji

# %%
# Pretpostavljamo da result DataFrame već sadrži vrijednosti portfelja za svaku strategiju
for strategy in strategies:
    # Provjerite postoji li strategija u DataFrame-u
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Izračunavanje statistika performansi za trenutnu strategiju
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Ispis statistika performansi
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategija {strategy} nije pronađena u rezultatima.\n")
# Out:
# Strategija A2C nije pronađena u rezultatima.
#
# Strategija DDPG nije pronađena u rezultatima.
#
# ==============Strategy Stats (PPO)==============
# Annual return           2.450547
# Cumulative returns      1.029385
# Annual volatility       0.482842
# Sharpe ratio            2.807210
# Calmar ratio           12.185563
# Stability               0.830689
# Max drawdown           -0.201102
# Omega ratio             1.654169
# Sortino ratio           4.859721
# Skew                    0.716647
# Kurtosis                5.167608
# Tail ratio              1.255545
# Daily value at risk    -0.055454
# dtype: float64
#
#
# Strategija TD3 nije pronađena u rezultatima.
#
# Strategija SAC nije pronađena u rezultatima.
#
# ==============Strategy Stats (B&H)==============
# Annual return           2.829157
# Cumulative returns      1.153782
# Annual volatility       0.534299
# Sharpe ratio            2.781408
# Calmar ratio           12.043238
# Stability               0.865308
# Max drawdown           -0.234917
# Omega ratio             1.613801
# Sortino ratio           4.719053
# Skew                    0.464176
# Kurtosis                3.091514
# Tail ratio              1.197062
# Daily value at risk    -0.061418
# dtype: float64

# %% [markdown]
# ### Plotiramo komulativne povrate za pojedinu strategiju

# %%
import matplotlib.pyplot as plt

# Postavljanje veličine figure za grafikon
plt.figure(figsize=(14, 7))

# Prolazak kroz svaku strategiju i crtanje njenih kumulativnih povrata
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju i pretvaranje u decimalni format ako je potrebno
        returns = result[f'{strategy}_returns'].dropna() + 1  # Dodaje 1 za korištenje cumprod()

        # Izračunavanje kumulativnih povrata
        cumulative_returns = returns.cumprod() - 1  # Oduzima 1 na kraju za prikazivanje pravog kumulativnog povrata

        # Plotiranje kumulativnih povrata
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Dodavanje naslova i legende na grafikon
plt.title('Kumulativni povrati DRL strategija')
plt.legend()

# Postavljanje oznaka za x i y osi
plt.xlabel('Datum')
plt.ylabel('Kumulativni povrati')

# Prikazivanje grafikona
plt.show()

# %% [markdown]
# ### Spremamo rezultate u CSV
# Potrebno promjeniti za svakog agenta

# %%
import pickle

# Za df_account_value_sac
with open('results/5. NVDA/nvda_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)

# Za df_actions_sac
with open('results/5. NVDA/nvda_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# Za buy_and_hold
with open('results/5. NVDA/nvda_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
