# %% [markdown]
# ## 1. Loading Required Packages

# %%
# Standard libraries
import sys
sys.path.append('../../')

import itertools

# Data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL and stable_baselines3 for machine learning and trading
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Configuration files and helper functions from FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Enabling chart display within Jupyter notebook
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_NFLX'
RESULTS_DIR = 'files/results_NFLX'
DATA_DIR = 'files/data_NFLX'

# Checking and creating directories
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Data Retrieval

# %% [markdown]
# We have a class called YahooDownloader that uses yfinance to fetch data from Yahoo Finance.
#
# In the YahooDownloader of FinRL, we modified the data frame into a format suitable for further data processing. We use a custom closing price instead of the regular closing price and add a column that represents the day of the week (0-4 corresponding to Monday-Friday).

# %%
# Training and trading intervals
TRAIN_START_DATE = '2022-04-01'
TRAIN_END_DATE = '2024-07-31'
TRADE_START_DATE = '2024-08-01'
TRADE_END_DATE = '2025-02-28'

# %%
# Fetching all data
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['NFLX']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (729, 8)

# %%
df_raw.head()
# Out:
#          date        open        high         low       close   volume   tic  \
# 0  2022-04-01  373.470001  373.470001  380.869995  376.799988  4644200  NFLX
# 1  2022-04-04  391.500000  391.500000  396.019989  373.549988  7001800  NFLX
# 2  2022-04-05  380.149994  380.149994  390.000000  389.299988  4234500  NFLX
# 3  2022-04-06  368.350006  368.350006  376.470001  374.149994  4354900  NFLX
# 4  2022-04-07  362.149994  362.149994  368.540009  365.000000  4948900  NFLX
#
#    day
# 0    4
# 1    0
# 2    1
# 3    2
# 4    3

# %% [markdown]
# ## 3. Data Processing

# %% [markdown]
# We use the defined class FeatureEngineer to process data and add technical indicators.
#
# The use_vix option includes the VIX index, known as the "fear index," which represents the expected volatility of the stock market based on S&P 500 options. The VIX helps the model understand market uncertainty, with higher values indicating greater uncertainty.
#
# The use_turbulence option includes the turbulence index, which measures unusual market fluctuations and serves as an indicator of risk and market shocks. It is useful for identifying periods of high volatility, helping the model to adapt to financial crises.
#
# Overall, a quite handy class that contains useful methods for processing financial data and can be applied to numerous other purposes.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (728, 8)
# Successfully added vix

# %%
# Creates a list of unique stock tickers from the 'tic' column of the 'processed' DataFrame.
list_ticker = processed["tic"].unique().tolist()

# Creates a list of dates between the earliest and latest dates in the 'processed' DataFrame, converting them to strings.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Creates combinations of all dates and stock tickers using the Cartesian product.
combination = list(itertools.product(list_date,list_ticker))

# Creates a new DataFrame 'processed_full' with columns "date" and "tic", containing all combinations of dates and stock tickers.
# Merges this DataFrame with the original 'processed' DataFrame based on the "date" and "tic" columns, using a 'left' join.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filters the 'processed_full' DataFrame to only include rows where the dates are present in the original 'processed' DataFrame.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sorts the 'processed_full' DataFrame by date and stock ticker.
processed_full = processed_full.sort_values(['date','tic'])

# Replaces all missing values (NaN) with 0 in the 'processed_full' DataFrame.
processed_full = processed_full.fillna(0)

# %%
processed_full.head(30)
# Out:
#           date   tic        open        high         low       close  \
# 0   2022-04-01  NFLX  373.470001  373.470001  380.869995  376.799988
# 3   2022-04-04  NFLX  391.500000  391.500000  396.019989  373.549988
# 4   2022-04-05  NFLX  380.149994  380.149994  390.000000  389.299988
# 5   2022-04-06  NFLX  368.350006  368.350006  376.470001  374.149994
# 6   2022-04-07  NFLX  362.149994  362.149994  368.540009  365.000000
# 7   2022-04-08  NFLX  355.880005  355.880005  362.500000  361.959991
# 10  2022-04-11  NFLX  348.000000  348.000000  354.779999  350.000000
# 11  2022-04-12  NFLX  344.100006  344.100006  359.410004  355.910004
# 12  2022-04-13  NFLX  350.429993  350.429993  352.000000  343.920013
# 13  2022-04-14  NFLX  341.130005  341.130005  352.000000  350.950012
# 17  2022-04-18  NFLX  337.859985  337.859985  342.359985  340.000000
# 18  2022-04-19  NFLX  348.609985  348.609985  351.679993  333.220001
# 19  2022-04-20  NFLX  226.190002  226.190002  248.699997  245.199997
# 20  2022-04-21  NFLX  218.220001  218.220001  227.679993  220.000000
# 21  2022-04-22  NFLX  215.520004  215.520004  226.270004  220.179993
# 24  2022-04-25  NFLX  209.910004  209.910004  216.660004  213.809998
# 25  2022-04-26  NFLX  198.399994  198.399994  209.149994  208.800003
# 26  2022-04-27  NFLX  188.539993  188.539993  200.190002  194.009995
# 27  2022-04-28  NFLX  199.520004  199.520004  201.479996  191.559998
# 28  2022-04-29  NFLX  190.360001  190.360001  204.710007  198.679993
# 31  2022-05-02  NFLX  199.460007  199.460007  200.210007  191.710007
# 32  2022-05-03  NFLX  199.869995  199.869995  203.199997  198.289993
# 33  2022-05-04  NFLX  204.009995  204.009995  204.380005  197.649994
# 34  2022-05-05  NFLX  188.320007  188.320007  200.710007  200.449997
# 35  2022-05-06  NFLX  180.970001  180.970001  187.210007  186.750000
# 38  2022-05-09  NFLX  173.100006  173.100006  183.199997  177.660004
# 39  2022-05-10  NFLX  177.660004  177.660004  181.869995  176.009995
# 40  2022-05-11  NFLX  166.369995  166.369995  180.919998  176.089996
# 41  2022-05-12  NFLX  174.309998  174.309998  177.580002  163.960007
# 42  2022-05-13  NFLX  187.639999  187.639999  187.770004  177.160004
#
#          volume  day       macd     boll_ub     boll_lb     rsi_30  \
# 0     4644200.0  4.0   0.000000  379.771182  370.578794   0.000000
# 3     7001800.0  0.0  -0.072917  379.771182  370.578794   0.000000
# 4     4234500.0  1.0   0.395496  396.514116  363.252526  83.370093
# 5     4354900.0  2.0   0.051862  393.189729  363.710249  45.567545
# 6     4948900.0  3.0  -0.500054  393.300422  358.219561  35.508176
# 7     4025200.0  4.0  -0.952424  392.775617  354.144366  33.004031
# 10    3777100.0  0.0  -1.767936  395.116742  345.100386  25.643784
# 11    3824300.0  1.0  -2.005257  393.569916  343.097572  33.252959
# 12    3231000.0  2.0  -2.733954  394.294417  336.947798  27.373861
# 13    4343800.0  3.0  -2.848985  392.735532  335.572463  34.407708
# 17    5105000.0  0.0  -3.475522  392.737472  331.178887  29.762992
# 18   20906900.0  1.0  -4.260016  393.275867  325.850796  27.394334
# 19  133387500.0  2.0  -9.757395  421.942855  279.589449  13.241585
# 20   53501600.0  3.0 -15.206024  439.211573  243.639852  11.484353
# 21   37515100.0  4.0 -19.110414  446.476254  220.209075  11.571062
# 24   28152000.0  0.0 -22.219181  450.442909  201.300837  11.170454
# 25   20318100.0  1.0 -24.624353  452.300599  185.669985  10.864417
# 26   22298400.0  2.0 -27.096540  454.163127  169.921313  10.025599
# 27   21363200.0  3.0 -28.824022  454.470047  156.932054   9.894685
# 28   16391900.0  4.0 -29.343535  452.855940  147.844056  13.298286
# 31   14591600.0  0.0 -29.854360  446.503910  135.687087  12.808331
# 32   11839400.0  1.0 -29.452759  437.929308  126.735690  15.836638
# 33   12218800.0  2.0 -28.835612  424.158711  121.341287  15.781487
# 34   13971300.0  3.0 -27.823442  410.839863  117.290136  17.088278
# 35   17185500.0  4.0 -27.661414  397.707877  112.597122  15.843918
# 38   14031300.0  0.0 -27.849382  383.149278  108.725722  15.089703
# 39   13883900.0  1.0 -27.787366  368.607961  105.868038  14.956014
# 40   12665500.0  2.0 -27.409416  349.655479  106.838520  14.993789
# 41   17662100.0  3.0 -27.670183  330.838831  107.659167  14.017220
# 42   13136300.0  4.0 -26.593888  304.664209  116.454788  19.890898
#
#         cci_30       dx_30  close_30_sma  close_60_sma        vix
# 0    66.666667  100.000000    376.799988    376.799988  20.620001
# 3    66.666667  100.000000    375.174988    375.174988  20.750000
# 4    45.827622   48.654594    379.883321    379.883321  18.790001
# 5   -89.712612    6.910144    378.449989    378.449989  21.270000
# 6  -115.986321   24.109321    375.759991    375.759991  21.969999
# 7  -112.609073   33.753325    373.459991    373.459991  21.250000
# 10 -125.938210   43.283136    370.108564    370.108564  23.090000
# 11  -90.533508   43.283136    368.333744    368.333744  24.940001
# 12  -96.656394   50.584894    365.621107    365.621107  23.520000
# 13  -88.429185   50.584894    364.153998    364.153998  21.719999
# 17 -110.369237   58.095599    361.958180    361.958180  24.520000
# 18  -80.637725   34.510802    359.563332    359.563332  22.549999
# 19 -348.916337   73.575585    350.766152    350.766152  21.129999
# 20 -249.398961   76.531574    341.425713    341.425713  20.240000
# 21 -177.414201   76.712345    333.342665    333.342665  22.709999
# 24 -147.030644   77.911939    325.871873    325.871873  30.040001
# 25 -130.271469   78.794992    318.985292    318.985292  27.379999
# 26 -122.435620   79.792097    312.042220    312.042220  31.110001
# 27 -105.796234   69.677573    305.701051    305.701051  29.910000
# 28  -95.840882   69.677573    300.349998    300.349998  28.969999
# 31  -89.190452   61.613792    295.176665    295.176665  33.349998
# 32  -80.773818   61.256614    290.772725    290.772725  31.760000
# 33  -75.151664   57.617768    286.723911    286.723911  29.120001
# 34  -76.008866   58.477025    283.129164    283.129164  25.969999
# 35  -81.766915   61.451042    279.273998    279.273998  32.230000
# 38  -83.696621   62.281176    275.365767    275.365767  31.900000
# 39  -79.839922   58.271759    271.685924    271.685924  33.660000
# 40  -80.099172   58.492772    268.271784    268.271784  32.869999
# 41  -79.329491   51.552562    264.674826    264.674826  33.740002
# 42  -67.073687   40.841636    261.757665    261.757665  31.090000

# %%
# Preparing the training and trade set according to the defined dates
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 584
# 143

# %%
# Saving the data
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Preparing the environment

# %% [markdown]
# stock_dimension represents the number of unique stocks in the dataset. This value is used to determine how many different stocks the model can trade.
#
# state_space denotes the total size of the state space that the model uses for decision-making. The state space includes current stock data (such as prices and technical indicators) and information about the current portfolio (such as the number of shares owned). The size of the state space is determined by a formula that takes into account the number of stocks and the number of technical indicators.

# %%
# Calculating the dimension (number of unique stocks) from the 'train' DataFrame.
stock_dimension = len(train.tic.unique())

# Calculating the state size based on the dimension and the number of technical indicators.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Creates lists of buy and sell costs for each stock.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Initializes the number of shares for each stock to 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym is an instance of the StockTradingEnv class, which represents the trading environment. This environment uses the data and parameters defined to simulate the stock market. The model learns how to trade within this environment, trying to maximize the total reward (profit) through a series of trading decisions.
#
# env_train is obtained by calling the get_sb_env() method on the e_train_gym instance. This method returns an environment compatible with the Stable Baselines 3 library, which is used for implementing reinforcement learning algorithms. The second return element, which is ignored here (_), can be used for additional information or functionalities provided by the environment.

# %%
# Define arguments for the trading environment.
env_kwargs = {
    "hmax": 1000,  # Maximum number of shares that can be bought or sold in a single transaction.
    "initial_amount": 100000,  # Initial amount of capital.
    "num_stock_shares": num_stock_shares,  # Initial number of shares for each stock in the portfolio, initially set to 0.
    "buy_cost_pct": buy_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "sell_cost_pct": sell_cost_list,  # Percentages of costs for buying and selling stocks, simulating actual transaction costs.
    "state_space": state_space,  # Previously defined sizes that affect the structure of the environment.
    "stock_dim": stock_dimension,  # Previously defined sizes that affect the structure of the environment.
    "tech_indicator_list": INDICATORS,  # List of technical indicators to be used for market state analysis.
    "action_space": stock_dimension,  # Size of the action space, i.e., the number of different actions the model can take.
    "reward_scaling": 1e-4  # Scaling factor for the reward, used to adjust the reward size to facilitate learning.
}

# Create the training environment.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Retrieve the environment suitable for Stable Baselines and an unused object.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Training DRL Agents

# %% [markdown]
# Here are the deep reinforcement learning (DRL) algorithms from the Stable Baselines 3 library. This is a library that has implemented popular DRL algorithms using PyTorch.
#
# As an alternative, the ElegantRL and Ray RLlib libraries can be used.

# %% [markdown]
# ### Training 5 different DRL agents (A2C, DDPG, PPO, TD3, SAC)

# %%
# Setting the appropriate values to 'True' for the algorithms you want to use
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# A new instance of the DRL agent is created with the given environment (it is not necessary to do this again, but for easier instructions, it remains)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Setting up the logger to monitor and record information during training
  tmp_path = RESULTS_DIR + '/a2c'
  # Configures a new logger that will print information to standard output, log to a CSV file, and TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Sets the new logger for the A2C model.
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Train the A2C model with the defined total number of time steps, only if if_using_a2c is set to True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Save the trained A2C model to the defined directory, only if if_using_a2c is set to True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_NFLX/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 3590       |
# |    iterations      | 1          |
# |    time_elapsed    | 0          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.18353376 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2540         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0018786187 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.284       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.198        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0013      |
# |    reward               | -0.30694374  |
# |    std                  | 0.991        |
# |    value_loss           | 0.546        |
# ------------------------------------------
# day: 583, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 133232.76
# total_reward: 33232.76
# total_cost: 0.00
# total_trades: 435
# Sharpe: 0.546
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2599        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002441728 |
# |    clip_fraction        | 0.00679     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0262      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.147       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00163    |
# |    reward               | 0.0         |
# |    std                  | 0.994       |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2325        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005796358 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0624      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.148       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0026     |
# |    reward               | 0.0         |
# |    std                  | 0.991       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2348        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004171764 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.000861    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.14        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00417    |
# |    reward               | -0.07202856 |
# |    std                  | 0.983       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# day: 583, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 148396.19
# total_reward: 48396.19
# total_cost: 0.00
# total_trades: 476
# Sharpe: 0.710
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2259         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0021869647 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.12         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00259     |
# |    reward               | 0.0          |
# |    std                  | 0.971        |
# |    value_loss           | 0.268        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2246        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003966788 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0254      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.144       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00329    |
# |    reward               | 0.07325537  |
# |    std                  | 0.973       |
# |    value_loss           | 0.369       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2260         |
# |    iterations           | 8            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0041591516 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0783       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.152        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00504     |
# |    reward               | -0.10289987  |
# |    std                  | 0.963        |
# |    value_loss           | 0.389        |
# ------------------------------------------
# day: 583, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 158034.23
# total_reward: 58034.23
# total_cost: 0.00
# total_trades: 487
# Sharpe: 0.805
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2291        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004714039 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0609      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.115       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0038     |
# |    reward               | 0.0         |
# |    std                  | 0.952       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2324         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0051553017 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.042        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0536       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00556     |
# |    reward               | 0.07624475   |
# |    std                  | 0.949        |
# |    value_loss           | 0.239        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2347         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031482785 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0494       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.166        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00373     |
# |    reward               | 0.0          |
# |    std                  | 0.945        |
# |    value_loss           | 0.324        |
# ------------------------------------------
# day: 583, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 133045.80
# total_reward: 33045.80
# total_cost: 0.00
# total_trades: 466
# Sharpe: 0.552
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2368         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0042065033 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0144       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.207        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00312     |
# |    reward               | -0.83926576  |
# |    std                  | 0.945        |
# |    value_loss           | 0.498        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2391         |
# |    iterations           | 13           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0018021606 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.228        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00166     |
# |    reward               | -0.017407812 |
# |    std                  | 0.944        |
# |    value_loss           | 0.377        |
# ------------------------------------------
# day: 583, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 170702.24
# total_reward: 70702.24
# total_cost: 0.00
# total_trades: 471
# Sharpe: 0.934
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2399        |
# |    iterations           | 14          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003160858 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0989      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.27        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000787   |
# |    reward               | 0.36075     |
# |    std                  | 0.943       |
# |    value_loss           | 0.457       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2383         |
# |    iterations           | 15           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0035337226 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0997       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.271        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000756    |
# |    reward               | 0.0          |
# |    std                  | 0.94         |
# |    value_loss           | 0.465        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2386         |
# |    iterations           | 16           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0060286447 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.18         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00364     |
# |    reward               | 0.3915879    |
# |    std                  | 0.941        |
# |    value_loss           | 0.414        |
# ------------------------------------------
# day: 583, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 149420.42
# total_reward: 49420.42
# total_cost: 0.00
# total_trades: 482
# Sharpe: 0.726
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2397        |
# |    iterations           | 17          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003463918 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.289       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00302    |
# |    reward               | 0.0         |
# |    std                  | 0.935       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2361         |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044273622 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0974       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.104        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00382     |
# |    reward               | 0.0          |
# |    std                  | 0.932        |
# |    value_loss           | 0.345        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2375       |
# |    iterations           | 19         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.0040379  |
# |    clip_fraction        | 0.0253     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.084      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.289      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00271   |
# |    reward               | 0.13303573 |
# |    std                  | 0.926      |
# |    value_loss           | 0.468      |
# ----------------------------------------
# day: 583, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 325498.40
# total_reward: 225498.40
# total_cost: 0.00
# total_trades: 499
# Sharpe: 1.878
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2376         |
# |    iterations           | 20           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0040065404 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.26         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00462     |
# |    reward               | 0.26227632   |
# |    std                  | 0.92         |
# |    value_loss           | 0.438        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2368         |
# |    iterations           | 21           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0033297255 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.306        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00276     |
# |    reward               | 0.0          |
# |    std                  | 0.918        |
# |    value_loss           | 0.537        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2370         |
# |    iterations           | 22           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0032154329 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0397       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.182        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000817    |
# |    reward               | 0.023127941  |
# |    std                  | 0.92         |
# |    value_loss           | 0.35         |
# ------------------------------------------
# day: 583, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 181697.89
# total_reward: 81697.89
# total_cost: 0.00
# total_trades: 465
# Sharpe: 0.909
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2376        |
# |    iterations           | 23          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008961747 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.174       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00942    |
# |    reward               | 0.0         |
# |    std                  | 0.915       |
# |    value_loss           | 0.507       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2371         |
# |    iterations           | 24           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0034293626 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.045        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.164        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00351     |
# |    reward               | -0.021513209 |
# |    std                  | 0.916        |
# |    value_loss           | 0.438        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2380       |
# |    iterations           | 25         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00389469 |
# |    clip_fraction        | 0.0355     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.0618     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.227      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0037    |
# |    reward               | 0.10366776 |
# |    std                  | 0.912      |
# |    value_loss           | 0.544      |
# ----------------------------------------
# day: 583, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 210944.22
# total_reward: 110944.22
# total_cost: 0.00
# total_trades: 481
# Sharpe: 1.086
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2383        |
# |    iterations           | 26          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004906208 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0742      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.269       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00434    |
# |    reward               | 0.0         |
# |    std                  | 0.92        |
# |    value_loss           | 0.671       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2380         |
# |    iterations           | 27           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0074250735 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.228        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00771     |
# |    reward               | 0.2322539    |
# |    std                  | 0.916        |
# |    value_loss           | 0.623        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2372        |
# |    iterations           | 28          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005296431 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.256       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00415    |
# |    reward               | -0.28653303 |
# |    std                  | 0.916       |
# |    value_loss           | 0.485       |
# -----------------------------------------
# day: 583, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 169437.01
# total_reward: 69437.01
# total_cost: 0.00
# total_trades: 516
# Sharpe: 0.812
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2339         |
# |    iterations           | 29           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0025198506 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.327        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00142     |
# |    reward               | 0.10800397   |
# |    std                  | 0.907        |
# |    value_loss           | 0.666        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2322          |
# |    iterations           | 30            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.006760542   |
# |    clip_fraction        | 0.0618        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0.112         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.147         |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.00444      |
# |    reward               | -0.0064262054 |
# |    std                  | 0.902         |
# |    value_loss           | 0.362         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2328         |
# |    iterations           | 31           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0054364544 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.263        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00225     |
# |    reward               | -0.031096455 |
# |    std                  | 0.897        |
# |    value_loss           | 0.452        |
# ------------------------------------------
# day: 583, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 164668.62
# total_reward: 64668.62
# total_cost: 0.00
# total_trades: 524
# Sharpe: 0.790
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2334        |
# |    iterations           | 32          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008889288 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.176       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00245    |
# |    reward               | -0.2815041  |
# |    std                  | 0.896       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2344          |
# |    iterations           | 33            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.0046645897  |
# |    clip_fraction        | 0.0462        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.171         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.232         |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00447      |
# |    reward               | -0.0020789155 |
# |    std                  | 0.893         |
# |    value_loss           | 0.553         |
# -------------------------------------------
# day: 583, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 171185.54
# total_reward: 71185.54
# total_cost: 0.00
# total_trades: 544
# Sharpe: 0.846
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2345         |
# |    iterations           | 34           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0066902344 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.248        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00415     |
# |    reward               | -0.11864998  |
# |    std                  | 0.889        |
# |    value_loss           | 0.41         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2334        |
# |    iterations           | 35          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003015171 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.298       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00182    |
# |    reward               | 0.0         |
# |    std                  | 0.893       |
# |    value_loss           | 0.578       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2342         |
# |    iterations           | 36           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0075519513 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.44         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00392     |
# |    reward               | 0.32496715   |
# |    std                  | 0.888        |
# |    value_loss           | 0.67         |
# ------------------------------------------
# day: 583, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 206209.22
# total_reward: 106209.22
# total_cost: 0.00
# total_trades: 540
# Sharpe: 1.005
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2335        |
# |    iterations           | 37          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005692655 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.378       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00351    |
# |    reward               | -0.53799284 |
# |    std                  | 0.892       |
# |    value_loss           | 0.79        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2337         |
# |    iterations           | 38           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0069995504 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.193        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00285     |
# |    reward               | -0.039785445 |
# |    std                  | 0.892        |
# |    value_loss           | 0.495        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2323         |
# |    iterations           | 39           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0057183993 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.302        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00245     |
# |    reward               | -0.13032413  |
# |    std                  | 0.886        |
# |    value_loss           | 0.525        |
# ------------------------------------------
# day: 583, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 141626.11
# total_reward: 41626.11
# total_cost: 0.00
# total_trades: 509
# Sharpe: 0.598
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2328        |
# |    iterations           | 40          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005016475 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.274       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00174    |
# |    reward               | 0.0         |
# |    std                  | 0.883       |
# |    value_loss           | 0.699       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2318         |
# |    iterations           | 41           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0048118243 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.238        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000327    |
# |    reward               | 0.57680917   |
# |    std                  | 0.878        |
# |    value_loss           | 0.497        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2306         |
# |    iterations           | 42           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0055868016 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.3          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00375     |
# |    reward               | 0.7939618    |
# |    std                  | 0.878        |
# |    value_loss           | 0.658        |
# ------------------------------------------
# day: 583, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 275213.61
# total_reward: 175213.61
# total_cost: 0.00
# total_trades: 547
# Sharpe: 1.501
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2297         |
# |    iterations           | 43           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.00639492   |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.306        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00513     |
# |    reward               | -0.076884285 |
# |    std                  | 0.876        |
# |    value_loss           | 0.814        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2302        |
# |    iterations           | 44          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006085291 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.301       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00144    |
# |    reward               | 0.324       |
# |    std                  | 0.88        |
# |    value_loss           | 0.573       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2308        |
# |    iterations           | 45          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010576885 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.168       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00286    |
# |    reward               | -0.55676466 |
# |    std                  | 0.883       |
# |    value_loss           | 0.418       |
# -----------------------------------------
# day: 583, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 126833.45
# total_reward: 26833.45
# total_cost: 0.00
# total_trades: 517
# Sharpe: 0.469
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2315        |
# |    iterations           | 46          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008581047 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.369       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00513    |
# |    reward               | -0.07850115 |
# |    std                  | 0.875       |
# |    value_loss           | 0.789       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2322        |
# |    iterations           | 47          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008964617 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.25        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00238    |
# |    reward               | 0.0         |
# |    std                  | 0.875       |
# |    value_loss           | 0.514       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2328         |
# |    iterations           | 48           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0102251405 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.318        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0043      |
# |    reward               | 0.14349823   |
# |    std                  | 0.864        |
# |    value_loss           | 0.557        |
# ------------------------------------------
# day: 583, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 134993.66
# total_reward: 34993.66
# total_cost: 0.00
# total_trades: 515
# Sharpe: 0.541
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2331         |
# |    iterations           | 49           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0069324104 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.283        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00536     |
# |    reward               | 0.489551     |
# |    std                  | 0.864        |
# |    value_loss           | 0.638        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2329        |
# |    iterations           | 50          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010833697 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.269       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00616    |
# |    reward               | -0.14713575 |
# |    std                  | 0.865       |
# |    value_loss           | 0.66        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2330        |
# |    iterations           | 51          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.006700595 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.211       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00241    |
# |    reward               | 0.06432888  |
# |    std                  | 0.866       |
# |    value_loss           | 0.542       |
# -----------------------------------------
# day: 583, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 111696.72
# total_reward: 11696.72
# total_cost: 0.00
# total_trades: 509
# Sharpe: 0.309
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2331        |
# |    iterations           | 52          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011172545 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.305       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00515    |
# |    reward               | -0.35701165 |
# |    std                  | 0.86        |
# |    value_loss           | 0.577       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2332        |
# |    iterations           | 53          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010228494 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.245       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00319    |
# |    reward               | -0.18238086 |
# |    std                  | 0.862       |
# |    value_loss           | 0.57        |
# -----------------------------------------
# day: 583, episode: 190
# begin_total_asset: 100000.00
# end_total_asset: 247183.72
# total_reward: 147183.72
# ...
# |    approx_kl            | 0.01580679    |
# |    clip_fraction        | 0.064         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | 0.731         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.213         |
# |    n_updates            | 1780          |
# |    policy_gradient_loss | 0.00125       |
# |    reward               | -0.0039418396 |
# |    std                  | 0.747         |
# |    value_loss           | 0.456         |
# -------------------------------------------
# day: 583, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 247589.67
# total_reward: 147589.67
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.161
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2445        |
# |    iterations           | 180         |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.012327466 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.23        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00448    |
# |    reward               | -0.14237997 |
# |    std                  | 0.743       |
# |    value_loss           | 0.452       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2446        |
# |    iterations           | 181         |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.019778203 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.395       |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00731     |
# |    reward               | 0.13176022  |
# |    std                  | 0.748       |
# |    value_loss           | 0.605       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2446        |
# |    iterations           | 182         |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.019385338 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.264       |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0015      |
# |    reward               | 0.35066608  |
# |    std                  | 0.752       |
# |    value_loss           | 0.764       |
# -----------------------------------------
# day: 583, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 314554.29
# total_reward: 214554.29
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.416
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2448        |
# |    iterations           | 183         |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.021228116 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.224       |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0043     |
# |    reward               | -0.7204978  |
# |    std                  | 0.746       |
# |    value_loss           | 0.593       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2449         |
# |    iterations           | 184          |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.014065681  |
# |    clip_fraction        | 0.093        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.705        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.299        |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | 0.00159      |
# |    reward               | -0.047537338 |
# |    std                  | 0.749        |
# |    value_loss           | 0.477        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2451        |
# |    iterations           | 185         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.008460343 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.198       |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00175    |
# |    reward               | -0.4603384  |
# |    std                  | 0.753       |
# |    value_loss           | 0.577       |
# -----------------------------------------
# day: 583, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 266084.27
# total_reward: 166084.27
# total_cost: 0.00
# total_trades: 582
# Sharpe: 1.241
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2451        |
# |    iterations           | 186         |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.019172197 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.195       |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.000452   |
# |    reward               | 0.09970144  |
# |    std                  | 0.756       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2452       |
# |    iterations           | 187        |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 382976     |
# | train/                  |            |
# |    approx_kl            | 0.0131725  |
# |    clip_fraction        | 0.0772     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.447      |
# |    n_updates            | 1860       |
# |    policy_gradient_loss | -0.00247   |
# |    reward               | 0.42989537 |
# |    std                  | 0.762      |
# |    value_loss           | 0.68       |
# ----------------------------------------
# day: 583, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 281016.36
# total_reward: 181016.36
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.301
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2453       |
# |    iterations           | 188        |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.02305772 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.759      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.271      |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | -0.00174   |
# |    reward               | 0.9319438  |
# |    std                  | 0.758      |
# |    value_loss           | 0.462      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2455         |
# |    iterations           | 189          |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0133576915 |
# |    clip_fraction        | 0.0899       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.218        |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | 0.000529     |
# |    reward               | -0.21098478  |
# |    std                  | 0.756        |
# |    value_loss           | 0.451        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2456        |
# |    iterations           | 190         |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.024352051 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.301       |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.000713    |
# |    reward               | 0.3248      |
# |    std                  | 0.759       |
# |    value_loss           | 0.547       |
# -----------------------------------------
# day: 583, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 263197.23
# total_reward: 163197.23
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.223
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2455        |
# |    iterations           | 191         |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.021755654 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.166       |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.000102    |
# |    reward               | -0.7093718  |
# |    std                  | 0.765       |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2451        |
# |    iterations           | 192         |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.018082794 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.177       |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.00141     |
# |    reward               | -0.08041115 |
# |    std                  | 0.761       |
# |    value_loss           | 0.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2452        |
# |    iterations           | 193         |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.011191869 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.192       |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00107    |
# |    reward               | -0.20512812 |
# |    std                  | 0.756       |
# |    value_loss           | 0.467       |
# -----------------------------------------
# day: 583, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 305896.51
# total_reward: 205896.51
# total_cost: 0.00
# total_trades: 583
# Sharpe: 1.391
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2452        |
# |    iterations           | 194         |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.010753772 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.148       |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.00135     |
# |    reward               | 0.1846283   |
# |    std                  | 0.754       |
# |    value_loss           | 0.527       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2453        |
# |    iterations           | 195         |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.012765817 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.228       |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.000674    |
# |    reward               | 0.5803548   |
# |    std                  | 0.742       |
# |    value_loss           | 0.446       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2453        |
# |    iterations           | 196         |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.012305733 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.182       |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.000993    |
# |    reward               | -0.1747237  |
# |    std                  | 0.74        |
# |    value_loss           | 0.509       |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Preparation for backtest

# %%
# If necessary, we load the delayed data if we have restarted the process (not needed)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# If necessary, we load the delayed training data if we have restarted the process (not needed)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trading (data outside the training set)

# %% [markdown]
# Here we now use the trade dataset for trading, which has never been used for training. Additionally, with a similar approach, we could fine-tune the existing saved model.
#
# Numerous hyperparameters, such as the learning rate and the total number of training samples, affect the learning process and are usually determined by testing some variations.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# This section relates to the use of deep reinforcement learning (DRL) for simulating real-time trading using a previously trained model (in this case, A2C). StockTradingEnv is an environment that simulates the stock market based on historical data, a turbulence threshold (which is used to determine market volatility), and 'VIX' as a risk indicator. After initializing the environment, the get_sb_env() method is used to retrieve the environment and initial observations that are compatible with the Stable Baselines library.

# %%
# Initialization of the trading environment with the defined DataFrame 'trade', turbulence threshold, and risk indicator 'vix',
# along with other environment parameters ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Retrieving the environment compatible with Stable Baselines and initial observations.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# The DRL agent is then used to predict trading actions and changes in account value based on the trained model. This allows for the evaluation of the model's performance in an out-of-sample scenario, providing insight into how the model might perform in real trading conditions. If the use of the A2C algorithm is selected (as indicated by the variable if_using_a2c), predictions are made; otherwise, the result is set to None.

# %%
# Using the DRL agent for prediction using the trained model 'trained_a2c' and the defined trading environment 'e_trade_gym'.
# The results are two DataFrames: 'df_account_value_a2c' with account values and 'df_actions_a2c' with the actions taken,
# if 'if_using_a2c' is set to True; otherwise, it returns (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H for comparison

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['NFLX']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (144, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Backtesting models

# %%
# Setting the index of the account value DataFrames for each of the DRL strategies, if selected.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Creating an empty DataFrame for results.
result = pd.DataFrame()

# Merging the results of all DRL strategies into one DataFrame, if selected.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Merging the results of the mean variance optimization and the DJIA index with the main results.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Adding column names based on the selected strategies.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Displaying the results
result.head()
# Out:
#                       PPO            B&H
# date
# 2024-08-01  100000.000000  100000.000000
# 2024-08-02   98693.336914   98685.733885
# 2024-08-05   98693.336914   93292.010811
# 2024-08-06  100974.779785   95450.138278
# 2024-08-07  100974.779785   97905.444152

# %% [markdown]
# ### Here we plot a graph that shows the total portfolio value over time for each strategy and the benchmark

# %%
# Setting the figure size for the plots and drawing the performance charts of the trading strategies.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Based on the portfolio values, we calculate daily returns

# %%
from pyfolio import timeseries
import pandas as pd

# List of strategies for which you want to generate statistics
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Calculating daily returns from portfolio values
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/miniconda3/lib/python3.12/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_87447/597744444.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                       PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-08-01  100000.000000  100000.000000          NaN          NaN
# 2024-08-02   98693.336914   98685.733885    -0.013067    -0.013143
# 2024-08-05   98693.336914   93292.010811     0.000000    -0.054656
# 2024-08-06  100974.779785   95450.138278     0.023116     0.023133
# 2024-08-07  100974.779785   97905.444152     0.000000     0.025723

# %% [markdown]
# ### Calculating returns for the selected strategy

# %%
# We assume that the result DataFrame already contains portfolio values for each strategy
for strategy in strategies:
    # Check if the strategy exists in the DataFrame
    if f'{strategy}_returns' in result.columns:
        # Extract daily returns for the current strategy
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Calculate performance statistics for the current strategy
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Print performance statistics
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategy {strategy} was not found in the results.\n")
# Out:
# Strategy A2C was not found in the results.
#
# Strategy DDPG was not found in the results.
#
# ==============Strategy Stats (PPO)==============
# Annual return          0.464000
# Cumulative returns     0.241475
# Annual volatility      0.207733
# Sharpe ratio           1.939100
# Calmar ratio           4.819612
# Stability              0.773863
# Max drawdown          -0.096273
# Omega ratio            1.486541
# Sortino ratio          3.106442
# Skew                   0.245574
# Kurtosis               2.752738
# Tail ratio             1.325961
# Daily value at risk   -0.024573
# dtype: float64
#
#
# Strategy TD3 was not found in the results.
#
# Strategy SAC was not found in the results.
#
# ==============Strategy Stats (B&H)==============
# Annual return           1.242255
# Cumulative returns      0.581248
# Annual volatility       0.328203
# Sharpe ratio            2.621622
# Calmar ratio           11.387346
# Stability               0.929403
# Max drawdown           -0.109091
# Omega ratio             1.672645
# Sortino ratio           5.051193
# Skew                    2.571647
# Kurtosis               19.541229
# Tail ratio              1.301240
# Daily value at risk    -0.037935
# dtype: float64

# %% [markdown]
# ### Plotting cumulative returns for each strategy

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Setting the figure size for the plot
plt.figure(figsize=(12, 6))

# Iterating through each strategy and plotting its cumulative returns
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Make sure dates are properly parsed
        result.index = pd.to_datetime(result.index)
        
        # Extracting daily returns for the current strategy and converting to decimal format if necessary
        returns = result[f'{strategy}_returns'].dropna() + 1  # Adds 1 for using cumprod()
        
        # Calculating cumulative returns and converting to percentage
        cumulative_returns = (returns.cumprod() - 1) * 100  # Convert to percentage
        
        # Plotting cumulative returns with original colors
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Format y-axis as percentages
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0f}%'.format(y)))
plt.ylabel('Cumulative Returns (%)')
plt.xlabel('Date')

# Format x-axis dates
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# Make sure dates are in the correct format and rotated
plt.gcf().autofmt_xdate()

# Adding title and legend
#plt.title('Cumulative Returns of DRL Strategies')
plt.legend(loc='upper right')

# Add grid with light gray color
plt.grid(True, linestyle='-', alpha=0.2)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# ### Saving results to CSV
# Needs to be changed for each agent

# %%
import pickle

# For df_account_value_ppo
with open('results/2. NFLX/nflx_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)
    
# For df_actions_ppo
with open('results/2. NFLX/nflx_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# For buy_and_hold
with open('results/2. NFLX/nflx_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
