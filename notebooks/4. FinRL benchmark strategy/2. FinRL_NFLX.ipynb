# %% [markdown]
# ## 1. Učitavanje potrebnih paketa

# %%
# Standardne biblioteke
import sys
sys.path.append('../../')

import itertools

# Analiza podataka
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# FinRL i stable_baselines3 za strojno učenje i trgovanje
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_primo_trading.env_primo_default import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from stable_baselines3.common.logger import configure

# Konfiguracijski fajlovi i pomoćne funkcije iz FinRL
from finrl.config import INDICATORS
from finrl.main import check_and_make_directories

# Omogućavanje prikaza grafikona unutar Jupyter bilježnice
# %matplotlib inline

TRAINED_MODEL_DIR = 'files/models_NFLX'
RESULTS_DIR = 'files/results_NFLX'
DATA_DIR = 'files/data_NFLX'

# Provjera i kreiranje direktorija
check_and_make_directories([TRAINED_MODEL_DIR, DATA_DIR])

# %% [markdown]
# ## 2. Dohvaćanje podataka

# %% [markdown]
# Imamo klasu nazvanu YahooDownloader koja koristi yfinance za dohvaćanje podataka s Yahoo Finance.
#
# U YahooDownloader-u FinRL-a, modificirali smo okvir podataka u oblik koji je pogodan za daljnju obradu podataka. Koristimo prilagođenu zatvarajuću cijenu umjesto zatvarajuće cijene i dodajemo stupac koji predstavlja dan u tjednu (0-4 što odgovara ponedjeljku-petku).

# %%
# Intervali za trening i trgovanje
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2023-12-31'
TRADE_START_DATE = '2024-01-01'
TRADE_END_DATE = '2024-07-31'

# %%
# Preuzimamo sve podatke
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                         end_date = TRADE_END_DATE,
                         ticker_list = ['NFLX']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (731, 8)

# %%
df_raw.head()
# Out:
#          date        open        high         low       close   volume   tic  \
# 0  2021-09-01  569.000000  591.000000  569.000000  582.070007  5626200  NFLX
# 1  2021-09-02  583.679993  598.760010  583.679993  588.549988  6179900  NFLX
# 2  2021-09-03  585.799988  591.880005  583.140015  590.530029  2681200  NFLX
# 3  2021-09-07  594.690002  613.849976  593.989990  606.710022  5821400  NFLX
# 4  2021-09-08  603.840027  615.599976  595.710022  606.049988  5424500  NFLX
#
#    day
# 0    2
# 1    3
# 2    4
# 3    1
# 4    2

# %% [markdown]
# ## 3. Procesiranje podataka

# %% [markdown]
# Koristimo definiranu klasu FeatureEngineer pomoću koje radimo procesiranje podataka i dodavanje tehničkih indikatora.
#
# Opcija use_vix uključuje VIX indeks, poznat kao "indeks straha", koji predstavlja očekivanu volatilnost tržišta dionica temeljenu na opcijama S&P 500 indeksa. VIX pomaže modelu da razumije tržišnu nesigurnost, s višim vrijednostima koje ukazuju na veću nesigurnost.
#
# Opcija use_turbulence uključuje indeks turbulencije, koji mjeri neobične tržišne fluktuacije i služi kao pokazatelj rizika i tržišnih šokova. Koristan je za identifikaciju perioda visoke volatilnosti, pomažući modelu da se prilagodi financijskim krizama.
#
# Inače dosta zgodna klasa koja sadrži korisne metode za obradu financijskih podataka i može se primjeniti u brojne druge svrhe.

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=False,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Successfully added technical indicators
# Shape of DataFrame:  (730, 8)
# Successfully added vix

# %%
# Stvara listu jedinstvenih oznaka dionica (tickers) iz stupca 'tic' DataFrame-a 'processed'.
list_ticker = processed["tic"].unique().tolist()

# Stvara listu datuma između najranijeg i najkasnijeg datuma u DataFrame-u 'processed', pretvara ih u stringove.
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))

# Stvara kombinacije svih datuma i oznaka dionica koristeći kartezijev produkt.
combination = list(itertools.product(list_date,list_ticker))

# Stvara novi DataFrame 'processed_full' s kolonama "date" i "tic", koji sadrži sve kombinacije datuma i oznaka dionica.
# Spaja taj DataFrame s originalnim DataFrame-om 'processed' na temelju kolona "date" i "tic", koristeći 'left' spajanje.
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")

# Filtrira 'processed_full' DataFrame da sadrži samo one retke čiji su datumi prisutni u originalnom DataFrame-u 'processed'.
processed_full = processed_full[processed_full['date'].isin(processed['date'])]

# Sortira 'processed_full' DataFrame po datumu i oznaci dionica.
processed_full = processed_full.sort_values(['date','tic'])

# Zamjenjuje sve nedostajuće vrijednosti (NaN) s 0 u DataFrame-u 'processed_full'.
processed_full = processed_full.fillna(0)

# %%
processed_full.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2021-09-01  NFLX  569.000000  591.000000  569.000000  582.070007
# 1  2021-09-02  NFLX  583.679993  598.760010  583.679993  588.549988
# 2  2021-09-03  NFLX  585.799988  591.880005  583.140015  590.530029
# 6  2021-09-07  NFLX  594.690002  613.849976  593.989990  606.710022
# 7  2021-09-08  NFLX  603.840027  615.599976  595.710022  606.049988
#
#       volume  day      macd     boll_ub     boll_lb      rsi_30      cci_30  \
# 0  5626200.0  2.0  0.000000  594.474074  576.145921  100.000000   66.666667
# 1  6179900.0  3.0  0.145384  594.474074  576.145921  100.000000   66.666667
# 2  2681200.0  4.0  0.246649  595.899968  578.200048  100.000000   34.427656
# 6  5821400.0  1.0  0.870834  612.910910  571.019113  100.000000  133.333333
# 7  5424500.0  2.0  1.165410  616.867234  572.696780   97.250347   86.792117
#
#         dx_30  close_30_sma  close_60_sma        vix
# 0  100.000000    582.070007    582.070007  16.110001
# 1  100.000000    585.309998    585.309998  16.410000
# 2   86.569917    587.050008    587.050008  16.410000
# 6   96.490102    591.965012    591.965012  18.139999
# 7   96.691478    594.782007    594.782007  17.959999

# %%
# Pripremamo trening i trade set sukladno definiranim datumima
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 586
# 144

# %%
# Spremamo podatke
train.to_csv(DATA_DIR + '/train_data.csv')
trade.to_csv(DATA_DIR + '/trade_data.csv')

# %% [markdown]
# ## 4. Priprema environmenta

# %% [markdown]
# stock_dimension predstavlja broj jedinstvenih dionica u skupu podataka. Ova vrijednost se koristi za određivanje koliko različitih dionica model može trgovati.
#
# state_space označava ukupnu veličinu prostora stanja koji model koristi za donošenje odluka. Prostor stanja uključuje trenutne podatke o dionicama (kao što su cijene i tehnički indikatori) i informacije o trenutnom portfelju (kao što su broj dionica koje posjeduje). Veličina prostora stanja određena je formulom koja uzima u obzir broj dionica i broj tehničkih indikatora.

# %%
# Izračunavamo dimenziju (broj jedinstvenih dionica) iz DataFrame-a 'train'.
stock_dimension = len(train.tic.unique())

# Izračunavamo veličinu stanja na temelju dimenzije i broja tehničkih indikatora.
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
# Stvara liste troškova kupnje i prodaje za svaku dionicu.
buy_cost_list = sell_cost_list = [0] * stock_dimension

# Inicijalizira broj dionica za svaku dionicu na 0.
num_stock_shares = [0] * stock_dimension

# %% [markdown]
# e_train_gym je instanca klase StockTradingEnv, koja predstavlja okruženje za trgovanje. Ovo okruženje koristi podatke i parametre definirane za simulaciju tržišta dionica. Model uči kako trgovati unutar ovog okruženja, pokušavajući maksimizirati ukupnu nagradu (profit) kroz seriju trgovačkih odluka.
#
# env_train dobiva se pozivom metode get_sb_env() na instanci e_train_gym. Ova metoda vraća okruženje kompatibilno s bibliotekom Stable Baselines 3, koja se koristi za implementaciju algoritama pojačanog učenja. Drugi povratni element, koji se ovdje ignorira (_), može se koristiti za dodatne informacije ili funkcionalnosti koje pruža okruženje.

# %%
# Definira argumente za okruženje trgovanja.
env_kwargs = {
    "hmax": 1000,  # Maksimalni broj dionica koje se mogu kupiti ili prodati u jednoj transakciji.
    "initial_amount": 100000,  # Početni iznos kapitala.
    "num_stock_shares": num_stock_shares,  # Početni broj dionica svake dionice u portfelju, inicijalno postavljen na 0.
    "buy_cost_pct": buy_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "sell_cost_pct": sell_cost_list,  # Postotci troškova za kupnju i prodaju dionica, odnosno, koji simuliraju stvarne troškove transakcija.
    "state_space": state_space,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "stock_dim": stock_dimension,  # Prije definirane veličine koje utječu na strukturu okruženja.
    "tech_indicator_list": INDICATORS,  # Lista tehničkih indikatora koji će se koristiti za analizu stanja tržišta.
    "action_space": stock_dimension,  # Veličina prostora akcija, odnosno, broj različitih akcija koje model može izvršiti.
    "reward_scaling": 1e-4  # Faktor skaliranja za nagradu, koristi se za prilagodbu veličine nagrade kako bi se olakšalo učenje.
}

# Kreira okruženje za treniranje.
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# Dohvaća okruženje pogodno za Stable Baselines i neiskorišteni objekt.
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ## 5. Trening DRL agenata

# %% [markdown]
# Ovdje su algoritmi dubokog pojačanog učenja (DRL) iz biblioteke Stable Baselines 3. Radi se o biblioteci koja je implementirala popularne DRL algoritme koristeći PyTorch.
#
# Kao zamjena mogu se koristiti biblioteke ElegantRL i Ray RLlib.

# %% [markdown]
# ### Trening 5 različitih DRL agenata (A2C, DDPG, PPO, TD3, SAC)

# %%
# Postavljanje odgovarajućih vrijednosti na 'True' za algoritme koje želite koristiti
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# #### Agent 1: A2C

# %%
# Ponovno se kreira instanca DRL agenta s predanim okruženjem (nije potrebno ponovno raditi, ali zbog lakših uputa neka stoji)
agent = DRLAgent(env = env_train)
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.00025}
model_a2c = agent.get_model("a2c", model_kwargs = A2C_PARAMS)

if if_using_a2c:
  # Postavljanje loggera za praćenje i zapisivanje informacija tijekom treniranja
  tmp_path = RESULTS_DIR + '/a2c'
  # Konfigurira novi logger koji će ispisivati informacije na standardni izlaz, zapisivati u CSV datoteku i TensorBoard
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Postavlja novi logger za model A2C.
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.00025}
# Using cpu device

# %%
# Trenira model A2C s definiranim ukupnim brojem vremenskih koraka, samo ako je if_using_a2c postavljen na True.
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) if if_using_a2c else None

# %%
# Sprema trenirani model A2C u definirani direktorij, samo ako je if_using_a2c postavljen na True.
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# #### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.00025}
model_ddpg = agent.get_model("ddpg", model_kwargs = DDPG_PARAMS)

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.00025}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# #### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
       "n_steps": 2048,
       "ent_coef": 0.01,
       "learning_rate": 0.00025,
       "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to files/results_NFLX/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=400000) if if_using_ppo else None
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3754 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# | train/             |      |
# |    reward          | 0.0  |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3130         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0034396548 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.551       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.254        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00238     |
# |    reward               | 0.0021059967 |
# |    std                  | 0.998        |
# |    value_loss           | 0.418        |
# ------------------------------------------
# day: 585, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 102161.88
# total_reward: 2161.88
# total_cost: 0.00
# total_trades: 434
# Sharpe: 0.206
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2993        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003262018 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0777      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.119       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00264    |
# |    reward               | -0.06190408 |
# |    std                  | 1           |
# |    value_loss           | 0.3         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2933         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0047291815 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.115        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00437     |
# |    reward               | 0.0          |
# |    std                  | 0.997        |
# |    value_loss           | 0.347        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2893        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004201375 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0942      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0051     |
# |    reward               | 0.22698182  |
# |    std                  | 0.99        |
# |    value_loss           | 0.292       |
# -----------------------------------------
# day: 585, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 170310.44
# total_reward: 70310.44
# total_cost: 0.00
# total_trades: 499
# Sharpe: 0.853
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2870        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005324661 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0626      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.167       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0042     |
# |    reward               | 0.019       |
# |    std                  | 0.983       |
# |    value_loss           | 0.324       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2849         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0018341971 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.168        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00298     |
# |    reward               | 0.0          |
# |    std                  | 0.994        |
# |    value_loss           | 0.393        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2822         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0054417565 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.163        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00556     |
# |    reward               | 0.0          |
# |    std                  | 0.987        |
# |    value_loss           | 0.456        |
# ------------------------------------------
# day: 585, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 135224.30
# total_reward: 35224.30
# total_cost: 0.00
# total_trades: 496
# Sharpe: 0.547
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2790        |
# |    iterations           | 9           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007496617 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.214       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00731    |
# |    reward               | 0.010026442 |
# |    std                  | 0.984       |
# |    value_loss           | 0.597       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2795        |
# |    iterations           | 10          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004499479 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.168       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00369    |
# |    reward               | 0.0         |
# |    std                  | 0.983       |
# |    value_loss           | 0.403       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2794         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0043190015 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.256        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00379     |
# |    reward               | 0.21623865   |
# |    std                  | 0.976        |
# |    value_loss           | 0.44         |
# ------------------------------------------
# day: 585, episode: 40
# begin_total_asset: 100000.00
# end_total_asset: 86243.93
# total_reward: -13756.07
# total_cost: 0.00
# total_trades: 524
# Sharpe: 0.030
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2792         |
# |    iterations           | 12           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0059417505 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.21         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0023      |
# |    reward               | 0.06303626   |
# |    std                  | 0.974        |
# |    value_loss           | 0.475        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2788         |
# |    iterations           | 13           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0050190943 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.124        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00385     |
# |    reward               | -0.14204802  |
# |    std                  | 0.973        |
# |    value_loss           | 0.442        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2790         |
# |    iterations           | 14           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0042824056 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.179        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0033      |
# |    reward               | 0.025760254  |
# |    std                  | 0.969        |
# |    value_loss           | 0.416        |
# ------------------------------------------
# day: 585, episode: 50
# begin_total_asset: 100000.00
# end_total_asset: 73551.28
# total_reward: -26448.72
# total_cost: 0.00
# total_trades: 509
# Sharpe: -0.067
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2792         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053344225 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.141        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00524     |
# |    reward               | -0.27177992  |
# |    std                  | 0.961        |
# |    value_loss           | 0.408        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2797       |
# |    iterations           | 16         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00682507 |
# |    clip_fraction        | 0.0655     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.372      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.202      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00709   |
# |    reward               | 0.25930822 |
# |    std                  | 0.963      |
# |    value_loss           | 0.563      |
# ----------------------------------------
# day: 585, episode: 60
# begin_total_asset: 100000.00
# end_total_asset: 133748.82
# total_reward: 33748.82
# total_cost: 0.00
# total_trades: 548
# Sharpe: 0.511
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2800         |
# |    iterations           | 17           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0057471907 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.197        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00422     |
# |    reward               | 0.08562609   |
# |    std                  | 0.963        |
# |    value_loss           | 0.517        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2802         |
# |    iterations           | 18           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0050736167 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.189        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00334     |
# |    reward               | -0.0855603   |
# |    std                  | 0.963        |
# |    value_loss           | 0.36         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2805        |
# |    iterations           | 19          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005296768 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.303       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00554    |
# |    reward               | 0.0         |
# |    std                  | 0.953       |
# |    value_loss           | 0.567       |
# -----------------------------------------
# day: 585, episode: 70
# begin_total_asset: 100000.00
# end_total_asset: 124743.99
# total_reward: 24743.99
# total_cost: 0.00
# total_trades: 553
# Sharpe: 0.438
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2806        |
# |    iterations           | 20          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006325641 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.223       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00404    |
# |    reward               | -0.08576895 |
# |    std                  | 0.952       |
# |    value_loss           | 0.55        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2807        |
# |    iterations           | 21          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003701774 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.259       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00373    |
# |    reward               | 0.0         |
# |    std                  | 0.951       |
# |    value_loss           | 0.57        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2808         |
# |    iterations           | 22           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0077244244 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.155        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00298     |
# |    reward               | 0.0          |
# |    std                  | 0.95         |
# |    value_loss           | 0.397        |
# ------------------------------------------
# day: 585, episode: 80
# begin_total_asset: 100000.00
# end_total_asset: 185161.27
# total_reward: 85161.27
# total_cost: 0.00
# total_trades: 566
# Sharpe: 0.872
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2798       |
# |    iterations           | 23         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00653168 |
# |    clip_fraction        | 0.053      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.396      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.166      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00513   |
# |    reward               | 0.0        |
# |    std                  | 0.941      |
# |    value_loss           | 0.398      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2799        |
# |    iterations           | 24          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007377741 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.187       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00705    |
# |    reward               | 0.085500866 |
# |    std                  | 0.935       |
# |    value_loss           | 0.504       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2801        |
# |    iterations           | 25          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006646991 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.233       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00208    |
# |    reward               | 0.52161205  |
# |    std                  | 0.931       |
# |    value_loss           | 0.493       |
# -----------------------------------------
# day: 585, episode: 90
# begin_total_asset: 100000.00
# end_total_asset: 152951.39
# total_reward: 52951.39
# total_cost: 0.00
# total_trades: 565
# Sharpe: 0.638
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2802        |
# |    iterations           | 26          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009171674 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.169       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00779    |
# |    reward               | 0.04198396  |
# |    std                  | 0.929       |
# |    value_loss           | 0.486       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2803         |
# |    iterations           | 27           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0081969695 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.2          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00266     |
# |    reward               | 0.12035116   |
# |    std                  | 0.924        |
# |    value_loss           | 0.461        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2803         |
# |    iterations           | 28           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.010193226  |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.232        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0065      |
# |    reward               | -0.007821164 |
# |    std                  | 0.916        |
# |    value_loss           | 0.449        |
# ------------------------------------------
# day: 585, episode: 100
# begin_total_asset: 100000.00
# end_total_asset: 124287.77
# total_reward: 24287.77
# total_cost: 0.00
# total_trades: 567
# Sharpe: 0.450
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2803        |
# |    iterations           | 29          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010059808 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.116       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.007      |
# |    reward               | -0.35393375 |
# |    std                  | 0.919       |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2798        |
# |    iterations           | 30          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009014062 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.159       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00239    |
# |    reward               | 0.45584518  |
# |    std                  | 0.924       |
# |    value_loss           | 0.398       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2792         |
# |    iterations           | 31           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0069196895 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.199        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00359     |
# |    reward               | 0.08747953   |
# |    std                  | 0.931        |
# |    value_loss           | 0.439        |
# ------------------------------------------
# day: 585, episode: 110
# begin_total_asset: 100000.00
# end_total_asset: 143236.04
# total_reward: 43236.04
# total_cost: 0.00
# total_trades: 574
# Sharpe: 0.574
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2793        |
# |    iterations           | 32          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007438949 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.179       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00514    |
# |    reward               | -0.10567165 |
# |    std                  | 0.919       |
# |    value_loss           | 0.461       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2792         |
# |    iterations           | 33           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0059442436 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.188        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00353     |
# |    reward               | 0.0          |
# |    std                  | 0.92         |
# |    value_loss           | 0.439        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2765         |
# |    iterations           | 34           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0063402373 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.159        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00589     |
# |    reward               | 0.0          |
# |    std                  | 0.916        |
# |    value_loss           | 0.418        |
# ------------------------------------------
# day: 585, episode: 120
# begin_total_asset: 100000.00
# end_total_asset: 89350.24
# total_reward: -10649.76
# total_cost: 0.00
# total_trades: 569
# Sharpe: 0.133
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2756         |
# |    iterations           | 35           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0074089924 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.159        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00494     |
# |    reward               | -0.11506197  |
# |    std                  | 0.911        |
# |    value_loss           | 0.417        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2756         |
# |    iterations           | 36           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0048611807 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.144        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00282     |
# |    reward               | 0.23832873   |
# |    std                  | 0.905        |
# |    value_loss           | 0.372        |
# ------------------------------------------
# day: 585, episode: 130
# begin_total_asset: 100000.00
# end_total_asset: 149693.34
# total_reward: 49693.34
# total_cost: 0.00
# total_trades: 572
# Sharpe: 0.621
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2758        |
# |    iterations           | 37          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011780559 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.147       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00453    |
# |    reward               | 0.037386876 |
# |    std                  | 0.907       |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2760        |
# |    iterations           | 38          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008995529 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.22        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00691    |
# |    reward               | -1.8237172  |
# |    std                  | 0.907       |
# |    value_loss           | 0.465       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2762        |
# |    iterations           | 39          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009831432 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.202       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00773    |
# |    reward               | 0.46521705  |
# |    std                  | 0.907       |
# |    value_loss           | 0.437       |
# -----------------------------------------
# day: 585, episode: 140
# begin_total_asset: 100000.00
# end_total_asset: 159532.64
# total_reward: 59532.64
# total_cost: 0.00
# total_trades: 572
# Sharpe: 0.687
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2764       |
# |    iterations           | 40         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.0104849  |
# |    clip_fraction        | 0.0893     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.504      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.15       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00409   |
# |    reward               | 0.13363187 |
# |    std                  | 0.906      |
# |    value_loss           | 0.429      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2767        |
# |    iterations           | 41          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014117707 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.252       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00794    |
# |    reward               | -0.53032154 |
# |    std                  | 0.9         |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2768        |
# |    iterations           | 42          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005528655 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0892      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00219    |
# |    reward               | 0.0         |
# |    std                  | 0.9         |
# |    value_loss           | 0.365       |
# -----------------------------------------
# day: 585, episode: 150
# begin_total_asset: 100000.00
# end_total_asset: 43465.23
# total_reward: -56534.77
# total_cost: 0.00
# total_trades: 575
# Sharpe: -0.632
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2769        |
# |    iterations           | 43          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008537192 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.183       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00636    |
# |    reward               | -0.13902602 |
# |    std                  | 0.896       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2770        |
# |    iterations           | 44          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010106954 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0945      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0055     |
# |    reward               | 0.04635334  |
# |    std                  | 0.901       |
# |    value_loss           | 0.373       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2771         |
# |    iterations           | 45           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0085113365 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.135        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00397     |
# |    reward               | 0.0          |
# |    std                  | 0.892        |
# |    value_loss           | 0.282        |
# ------------------------------------------
# day: 585, episode: 160
# begin_total_asset: 100000.00
# end_total_asset: 210255.59
# total_reward: 110255.59
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.962
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2772        |
# |    iterations           | 46          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011193117 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.179       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00384    |
# |    reward               | 0.19083504  |
# |    std                  | 0.893       |
# |    value_loss           | 0.326       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2772        |
# |    iterations           | 47          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006345953 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.165       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00312    |
# |    reward               | 0.0         |
# |    std                  | 0.892       |
# |    value_loss           | 0.345       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2773        |
# |    iterations           | 48          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013402232 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.159       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00329    |
# |    reward               | -0.1207     |
# |    std                  | 0.889       |
# |    value_loss           | 0.368       |
# -----------------------------------------
# day: 585, episode: 170
# begin_total_asset: 100000.00
# end_total_asset: 194828.06
# total_reward: 94828.06
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.877
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2772        |
# |    iterations           | 49          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014697717 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.17        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00624    |
# |    reward               | 0.0         |
# |    std                  | 0.887       |
# |    value_loss           | 0.407       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2766         |
# |    iterations           | 50           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0073726294 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.135        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00263     |
# |    reward               | 0.61628014   |
# |    std                  | 0.886        |
# |    value_loss           | 0.344        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2762        |
# |    iterations           | 51          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008971276 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.173       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00339    |
# |    reward               | -0.24362767 |
# |    std                  | 0.891       |
# |    value_loss           | 0.378       |
# -----------------------------------------
# day: 585, episode: 180
# begin_total_asset: 100000.00
# end_total_asset: 177465.92
# total_reward: 77465.92
# total_cost: 0.00
# total_trades: 583
# Sharpe: 0.764
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2756        |
# |    iterations           | 52          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013637933 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.162       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.004      |
# |    reward               | 0.46681726  |
# |    std                  | 0.898       |
# |    value_loss           | 0.406       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2758        |
# |    iterations           | 53          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.012810808 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.218       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00458    |
# |    reward               | 0.32996574  |
# |    std                  | 0.899       |
# |    value_loss           | 0.406       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2754        |
# |    iterations           | 54          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.008839307 |
# ...
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.102        |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00259     |
# |    reward               | -0.010079956 |
# |    std                  | 0.847        |
# |    value_loss           | 0.236        |
# ------------------------------------------
# day: 585, episode: 630
# begin_total_asset: 100000.00
# end_total_asset: 172260.70
# total_reward: 72260.70
# total_cost: 0.00
# total_trades: 582
# Sharpe: 0.742
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2700        |
# |    iterations           | 180         |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.021004349 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0705      |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00189    |
# |    reward               | -0.3832929  |
# |    std                  | 0.842       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2701        |
# |    iterations           | 181         |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.013668649 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0905      |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00174    |
# |    reward               | 0.001883197 |
# |    std                  | 0.838       |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2702        |
# |    iterations           | 182         |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.010738963 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.098       |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00294    |
# |    reward               | 0.0         |
# |    std                  | 0.842       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# day: 585, episode: 640
# begin_total_asset: 100000.00
# end_total_asset: 164566.00
# total_reward: 64566.00
# total_cost: 0.00
# total_trades: 581
# Sharpe: 0.714
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2703          |
# |    iterations           | 183           |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 374784        |
# | train/                  |               |
# |    approx_kl            | 0.011728622   |
# |    clip_fraction        | 0.0988        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | 0.877         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0797        |
# |    n_updates            | 1820          |
# |    policy_gradient_loss | -0.00241      |
# |    reward               | -0.0014489411 |
# |    std                  | 0.836         |
# |    value_loss           | 0.234         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2703        |
# |    iterations           | 184         |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.010709671 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.208       |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00218    |
# |    reward               | -0.23423375 |
# |    std                  | 0.847       |
# |    value_loss           | 0.297       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2703        |
# |    iterations           | 185         |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.008728918 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0686      |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.00212    |
# |    reward               | -0.05672622 |
# |    std                  | 0.852       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# day: 585, episode: 650
# begin_total_asset: 100000.00
# end_total_asset: 150149.49
# total_reward: 50149.49
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.615
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2703        |
# |    iterations           | 186         |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.009573091 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0672      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00315    |
# |    reward               | -0.03632958 |
# |    std                  | 0.844       |
# |    value_loss           | 0.204       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2704        |
# |    iterations           | 187         |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.012338096 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.108       |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00431    |
# |    reward               | -0.18840396 |
# |    std                  | 0.856       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2704        |
# |    iterations           | 188         |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.015619602 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0813      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00289    |
# |    reward               | -0.16464081 |
# |    std                  | 0.849       |
# |    value_loss           | 0.27        |
# -----------------------------------------
# day: 585, episode: 660
# begin_total_asset: 100000.00
# end_total_asset: 141864.94
# total_reward: 41864.94
# total_cost: 0.00
# total_trades: 580
# Sharpe: 0.569
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2705         |
# |    iterations           | 189          |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0137362825 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0879       |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00422     |
# |    reward               | -0.119300865 |
# |    std                  | 0.845        |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2705        |
# |    iterations           | 190         |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.012896741 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0639      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00507    |
# |    reward               | 0.0         |
# |    std                  | 0.842       |
# |    value_loss           | 0.307       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2706        |
# |    iterations           | 191         |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.020186312 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.12        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00174    |
# |    reward               | -0.28138775 |
# |    std                  | 0.831       |
# |    value_loss           | 0.293       |
# -----------------------------------------
# day: 585, episode: 670
# begin_total_asset: 100000.00
# end_total_asset: 144734.68
# total_reward: 44734.68
# total_cost: 0.00
# total_trades: 584
# Sharpe: 0.584
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2706        |
# |    iterations           | 192         |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.017194659 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0702      |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.00339    |
# |    reward               | 0.0         |
# |    std                  | 0.836       |
# |    value_loss           | 0.273       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2707        |
# |    iterations           | 193         |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.013952422 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.116       |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00195    |
# |    reward               | -0.33703953 |
# |    std                  | 0.848       |
# |    value_loss           | 0.299       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2706         |
# |    iterations           | 194          |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.009662248  |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0686       |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00319     |
# |    reward               | -0.010890564 |
# |    std                  | 0.835        |
# |    value_loss           | 0.246        |
# ------------------------------------------
# day: 585, episode: 680
# begin_total_asset: 100000.00
# end_total_asset: 139924.67
# total_reward: 39924.67
# total_cost: 0.00
# total_trades: 578
# Sharpe: 0.557
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2706        |
# |    iterations           | 195         |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.01917552  |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.161       |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00237    |
# |    reward               | -0.13081512 |
# |    std                  | 0.828       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2706        |
# |    iterations           | 196         |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014507438 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.207       |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00232    |
# |    reward               | -0.04223996 |
# |    std                  | 0.825       |
# |    value_loss           | 0.323       |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# #### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# #### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.00025,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.00025, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 6. Priprema za backtest

# %%
# Po potrebi učitavamo sporemnjene podatke ako smo restrartali proces (nije potrebno)
train = pd.read_csv(DATA_DIR + '/train_data.csv')
trade = pd.read_csv(DATA_DIR + '/trade_data.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
# Po potrebi učitavamo sporemnjene podatke o treningu agenata ako smo restrartali proces (nije potrebno)
if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## 7. Trgovanje (podatci izvan trening seta)

# %% [markdown]
# Ovdje sada za trgovanje koristimo trade skup podataka koji nikad nije bio korišten za trening. Dodatno sličnim pristupom bi mogli i dotrenirati postojeći spremljeni model.
#
# Brojni hiperparametri, na primjer, stopa učenja, ukupan broj uzoraka za trening – utječu na proces učenja i obično se određuju testiranjem nekih varijacija.

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 11

# %%
buy_cost_list = sell_cost_list = [0] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 1000,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %% [markdown]
# Ovaj dio se odnosi se na korištenje dubokog pojačanog učenja (DRL) za simulaciju trgovanja u stvarnom vremenu koristeći prethodno trenirani model (u ovom slučaju, A2C). StockTradingEnv je okruženje koje simulira tržište dionica s obzirom na povijesne podatke, prag turbulencije (koji se koristi za određivanje volatilnosti tržišta), i 'VIX' kao pokazatelj rizika. Nakon inicijalizacije okruženja, koristi se metoda get_sb_env() za dohvaćanje okruženja i početne opservacije koje su kompatibilne sa Stable Baselines bibliotekom.

# %%
# Inicijalizacija okruženja za trgovanje s definiranim DataFrame-om 'trade', pragom turbulencije i pokazateljem rizika 'vix',
# zajedno s ostalim parametrima okruženja ('env_kwargs').
e_trade_gym = StockTradingEnv(df = trade, **env_kwargs)

# Dohvaćanje okruženja kompatibilnog sa Stable Baselines i početne opservacije.
env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# Zatim se DRL agent koristi za predviđanje akcija trgovanja i promjene u vrijednosti računa na temelju treniranog modela. To omogućuje evaluaciju performansi modela u scenariju izvan uzorka, pružajući uvid u to kako bi model mogao performirati u stvarnim trgovačkim uvjetima. Ako je odabrana upotreba A2C algoritma (kao što je indicirano varijablom if_using_a2c), provodi se predviđanje; u suprotnom, rezultat se postavlja na None.

# %%
# Korištenje DRL agenta za predviđanje koristeći trenirani model 'trained_a2c' i definirano okruženje trgovanja 'e_trade_gym'.
# Rezultati su dva DataFrame-a: 'df_account_value_a2c' s vrijednostima računa i 'df_actions_a2c' s akcijama koje su poduzete,
# ako je 'if_using_a2c' postavljen na True; inače se vraća (None, None).
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, 
    environment = e_trade_gym) if if_using_a2c else (None, None)

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg, 
    environment = e_trade_gym) if if_using_ddpg else (None, None)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3, 
    environment = e_trade_gym) if if_using_td3 else (None, None)

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym) if if_using_sac else (None, None)

# %% [markdown]
# ## 8. B&H za usporedbu

# %%
df_aapl = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['NFLX']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (145, 8)

# %%
df_aapl = df_aapl[['date','close']]
fst_day = df_aapl['close'].iloc[0]
buy_and_hold = pd.merge(df_aapl['date'], df_aapl['close'].div(fst_day).mul(100000), 
                        how='outer', left_index=True, right_index=True).set_index('date')

# %% [markdown]
# ## 10. Provodima backetinskg modela

# %%
# Postavljanje indeksa DataFrame-ova vrijednosti računa za svaku od DRL strategija, ako su odabrane.
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0]) if if_using_a2c else None
df_result_ddpg = df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0]) if if_using_ddpg else None
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0]) if if_using_ppo else None
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0]) if if_using_td3 else None
df_result_sac = df_account_value_sac.set_index(df_account_value_sac.columns[0]) if if_using_sac else None

# Kreiranje praznog DataFrame-a za rezultate.
result = pd.DataFrame()

# Spajanje rezultata svih DRL strategija u jedan DataFrame, ako su odabrane.
if if_using_a2c: result = pd.merge(result, df_result_a2c, how='outer', left_index=True, right_index=True)
if if_using_ddpg: result = pd.merge(result, df_result_ddpg, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_ppo: result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_td3: result = pd.merge(result, df_result_td3, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))
if if_using_sac: result = pd.merge(result, df_result_sac, how='outer', left_index=True, right_index=True, suffixes=('', '_drop'))

# Spajanje rezultata optimizacije srednje varijance i indeksa DJIA s glavnim rezultatima.
result = pd.merge(result, buy_and_hold, how='outer', left_index=True, right_index=True)

# %%
# Dodavanje imena stupaca na temelju odabranih strategija.
col_name = []
col_name.append('A2C') if if_using_a2c else None
col_name.append('DDPG') if if_using_ddpg else None
col_name.append('PPO') if if_using_ppo else None
col_name.append('TD3') if if_using_td3 else None
col_name.append('SAC') if if_using_sac else None
col_name.append('B&H')
result.columns = col_name

# %%
# Prikazivanje rezultata
result.head()
# Out:
#                       PPO            B&H
# date
# 2024-01-02  100000.000000  100000.000000
# 2024-01-03  100374.882080  100375.669107
# 2024-01-04  100374.882080  101316.971916
# 2024-01-05  100246.168732  101186.765754
# 2024-01-08  100246.168732  103528.281490

# %% [markdown]
# ### Ovdje plotiramo graf koji pokazuje ukupnu vrijednost portfolija korz vrijeme za pojedinu strategiju i benchmark

# %%
# Postavljanje veličine figure za grafikone i crtanje grafikona performansi strategija trgovanja.
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Na temelju vrijednosti portfolija računamo dnevne povrate

# %%
from pyfolio import timeseries
import pandas as pd

# Lista strategija za koje želite generirati statistike
strategies = ['A2C', 'DDPG', 'PPO', 'TD3', 'SAC', "B&H"]

for strategy in strategies:
    column_name = f'{strategy}'
    if column_name in result.columns:
        # Izračunavanje dnevnih povrata iz vrijednosti portfelja
        result[f'{strategy}_returns'] = result[column_name].pct_change()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/28/0nrxt8bn57bdz8wy1xv7fb6m0000gn/T/ipykernel_20018/728507394.py:11: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   result[f'{strategy}_returns'] = result[column_name].pct_change()

# %%
result.head()
# Out:
#                       PPO            B&H  PPO_returns  B&H_returns
# date
# 2024-01-02  100000.000000  100000.000000          NaN          NaN
# 2024-01-03  100374.882080  100375.669107     0.003749     0.003757
# 2024-01-04  100374.882080  101316.971916     0.000000     0.009378
# 2024-01-05  100246.168732  101186.765754    -0.001282    -0.001285
# 2024-01-08  100246.168732  103528.281490     0.000000     0.023141

# %% [markdown]
# ### Računamo povrate po odabranoj strategiji

# %%
# Pretpostavljamo da result DataFrame već sadrži vrijednosti portfelja za svaku strategiju
for strategy in strategies:
    # Provjerite postoji li strategija u DataFrame-u
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju
        returns = result[f'{strategy}_returns'].dropna()
        returns.index = pd.to_datetime(returns.index)

        # Izračunavanje statistika performansi za trenutnu strategiju
        perf_stats = timeseries.perf_stats(returns=returns, factor_returns=None, positions=None, transactions=None, turnover_denom="AGB")

        # Ispis statistika performansi
        print(f"==============Strategy Stats ({strategy})==============")
        print(perf_stats)
        print("\n")
    else:
        print(f"Strategija {strategy} nije pronađena u rezultatima.\n")
# Out:
# Strategija A2C nije pronađena u rezultatima.
#
# Strategija DDPG nije pronađena u rezultatima.
#
# ==============Strategy Stats (PPO)==============
# Annual return           0.304386
# Cumulative returns      0.163982
# Annual volatility       0.259718
# Sharpe ratio            1.151780
# Calmar ratio            2.557932
# Stability               0.401845
# Max drawdown           -0.118997
# Omega ratio             1.354823
# Sortino ratio           1.822559
# Skew                    0.754487
# Kurtosis               17.363250
# Tail ratio              1.233982
# Daily value at risk    -0.031534
# dtype: float64
#
#
# Strategija TD3 nije pronađena u rezultatima.
#
# Strategija SAC nije pronađena u rezultatima.
#
# ==============Strategy Stats (B&H)==============
# Annual return          0.644750
# Cumulative returns     0.328879
# Annual volatility      0.301629
# Sharpe ratio           1.800183
# Calmar ratio           4.795147
# Stability              0.649909
# Max drawdown          -0.134459
# Omega ratio            1.396892
# Sortino ratio          2.927352
# Skew                   0.454650
# Kurtosis               8.830069
# Tail ratio             1.313253
# Daily value at risk   -0.035847
# dtype: float64

# %% [markdown]
# ### Plotiramo komulativne povrate za pojedinu strategiju

# %%
import matplotlib.pyplot as plt

# Postavljanje veličine figure za grafikon
plt.figure(figsize=(14, 7))

# Prolazak kroz svaku strategiju i crtanje njenih kumulativnih povrata
for strategy in strategies:
    if f'{strategy}_returns' in result.columns:
        # Izvlačenje dnevnih povrata za trenutnu strategiju i pretvaranje u decimalni format ako je potrebno
        returns = result[f'{strategy}_returns'].dropna() + 1  # Dodaje 1 za korištenje cumprod()

        # Izračunavanje kumulativnih povrata
        cumulative_returns = returns.cumprod() - 1  # Oduzima 1 na kraju za prikazivanje pravog kumulativnog povrata

        # Plotiranje kumulativnih povrata
        plt.plot(cumulative_returns.index, cumulative_returns, label=strategy)

# Dodavanje naslova i legende na grafikon
plt.title('Kumulativni povrati DRL strategija')
plt.legend()

# Postavljanje oznaka za x i y osi
plt.xlabel('Datum')
plt.ylabel('Kumulativni povrati')

# Prikazivanje grafikona
plt.show()

# %% [markdown]
# ### Spremamo rezultate u CSV
# Potrebno promjeniti za svakog agenta

# %%
import pickle

# Za df_account_value_sac
with open('results/4. NFLX/nflx_finrl_df_account_value_ppo.pkl', 'wb') as f:
    pickle.dump(df_account_value_ppo, f)

# Za df_actions_sac
with open('results/4. NFLX/nflx_finrl_df_actions_ppo.pkl', 'wb') as f:
    pickle.dump(df_actions_ppo, f)

# Za buy_and_hold
with open('results/4. NFLX/nflx_finrl_buy_and_hold.pkl', 'wb') as f:
    pickle.dump(buy_and_hold, f)
